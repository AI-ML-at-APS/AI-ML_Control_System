# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from beamline34IDC.simulation.facade.focusing_optics_interface import Movement

from beamline34IDC.util.shadow.common import \
    plot_shadow_beam_spatial_distribution, get_shadow_beam_spatial_distribution,\
    load_shadow_beam, PreProcessorFiles, EmptyBeamException
import beamline34IDC.optimization.common as opt_common
import beamline34IDC.optimization.movers as movers
from beamline34IDC.util import clean_up
import matplotlib.pyplot as plt
import numpy as np
import scipy
from tqdm import tqdm
import shutil
import glob

# %%
# %matplotlib inline

# %%
DEFAULT_RANDOM_SEED = np.random.randint(100000)
print(DEFAULT_RANDOM_SEED)
# Out:
# 513

# %%
base_dir = '/gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/'
orig_work_dir = f'{base_dir}/work_directory'
temp_work_dir = f'{base_dir}/tmp_work_dir_{DEFAULT_RANDOM_SEED}'

# %%
os.mkdir(temp_work_dir)

# %%
dat_files = glob.glob(f'{orig_work_dir}/*.dat')
for df in dat_files:
    shutil.copy(df, temp_work_dir)

# %%
os.chdir(temp_work_dir)

# %%
input_beam_path = "primary_optics_system_beam.dat"

# %%
move_motors = ['hkb_q']

# %%
motors_str = move_motors[0] if len(move_motors) == 1 else '_'.join(move_motors)
fig_save_path = f'{orig_work_dir}/figures/{motors_str}/'
if not os.path.isdir(fig_save_path):
    os.mkdir(fig_save_path)

# %%
# Focusing Optics System -------------------------
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path)

# %%
centroid, out_beam, hist, dw = opt_common.get_centroid_distance(focusing_system=focusing_system, 
                                                                random_seed=DEFAULT_RANDOM_SEED)
print(centroid)
_ = plot_shadow_beam_spatial_distribution(out_beam)
# Out:
# 9.594192371755397e-05

# %%
initial_absolute_positions = np.array(movers.get_absolute_positions(focusing_system, move_motors))
print(initial_absolute_positions)
# Out:
# [120.]

# %%
# check positive and negative movement
movers.move_motors(focusing_system, move_motors, -100, movement='relative')
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')

# %%
# check positive and negative movement
movers.move_motors(focusing_system, move_motors, 100, movement='relative')
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')

# %%
# Plotting the loss function for a grid of values

# %%
test_values = np.linspace(-100, 100, 100)
fwhm_values = []
for v in tqdm(test_values):
    focusing_system = movers.move_motors(focusing_system, move_motors, v, movement='relative')
    fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system=focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    focusing_system = movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')
    fwhm_values.append(fwhm)
# Out:
# 100%|██████████| 100/100 [02:37<00:00,  1.57s/it]

# %%
plt.plot(test_values + initial_absolute_positions[0], fwhm_values)
plt.xlabel('Position')
plt.ylabel('FWHM')
plt.show()

# %%
initial_losses = []
initial_out_beams = []
absolute_movements = []

start_guesses = []
overall_successes = []
final_losses = []
final_out_beams = []

min_trans = -100
max_trans = 100

for outer in tqdm(range(10)):
    translations = np.random.uniform(min_trans, max_trans, size=1)
    test_absolute_movements = initial_absolute_positions + translations
    print("Initial motor positions are", test_absolute_movements)
    absolute_movements.append(test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    fwhm, out_beam, hist, dw = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    initial_losses.append(fwhm)
    initial_out_beams.append(out_beam)
    
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='fwhm')
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=True, guess_min=min_trans, guess_max=max_trans)
    focusing_system = opt_trial.focusing_system
    
    start_guesses.append(guesses)
    overall_successes.append(success)
    fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    final_losses.append(fwhm)
    final_out_beams.append(out_beam)
    print(f'Test {outer} success {success}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initial motor positions are [172.63922161]
# motors ['hkb_q'] trans [0.] current loss 0.008781736262744404
# Initial loss is 0.008781736262744404
# motors ['hkb_q'] trans [15.05488302] current loss 0.010609085090026704
# motors ['hkb_q'] trans [15.80762717] current loss 0.010282041371382392
# motors ['hkb_q'] trans [16.56037132] current loss 0.010684182758811358
# motors ['hkb_q'] trans [15.61944114] current loss 0.01063738663126806
# motors ['hkb_q'] trans [15.80762717] current loss 0.010282041371382392
# motors ['hkb_q'] trans [0.] current loss 0.008781736262744404
# Initial loss is 0.008781736262744404
# motors ['hkb_q'] trans [-71.57856164] current loss 0.00557643728195292
# motors ['hkb_q'] trans [-75.15748972] current loss 0.006648942661780651
# motors ['hkb_q'] trans [-67.99963355] current loss 0.004563739619248416
# motors ['hkb_q'] trans [-60.84177739] current loss 0.002211804414170159
# motors ['hkb_q'] trans [-50.10499314] current loss 0.0012849579855259924
# motors ['hkb_q'] trans [-28.63142465] current loss 0.004591822965523598
# motors ['hkb_q'] trans [-39.3682089] current loss 0.0026834547925938613
# motors ['hkb_q'] trans [-52.78918921] current loss 0.0011214617823025056
# motors ['hkb_q'] trans [-55.47338527] current loss 0.0012178434146650624
# motors ['hkb_q'] trans [-53.46023822] current loss 0.0012410164058461782
# motors ['hkb_q'] trans [-52.78918921] current loss 0.0011214617823025056
#  10%|█         | 1/10 [00:34<05:06, 34.02s/it]
# Test 0 success True
# Initial motor positions are [40.93458753]
# motors ['hkb_q'] trans [0.] current loss 0.05663034713479838
# Initial loss is 0.05663034713479838
# motors ['hkb_q'] trans [43.90964578] current loss 0.012114090513936918
# motors ['hkb_q'] trans [46.10512807] current loss 0.011208659539903257
# motors ['hkb_q'] trans [48.30061036] current loss 0.01011453650128507
# motors ['hkb_q'] trans [52.69157494] current loss 0.00831545173207884
# motors ['hkb_q'] trans [59.27802181] current loss 0.005869868615270078
# motors ['hkb_q'] trans [72.45091554] current loss 0.0019735957093399027
# motors ['hkb_q'] trans [92.21025614] current loss 0.0026790830864190152
# motors ['hkb_q'] trans [77.39075069] current loss 0.0012312352234994455
# motors ['hkb_q'] trans [82.33058584] current loss 0.001449040199813564
# motors ['hkb_q'] trans [78.62570948] current loss 0.001245350011762789
# motors ['hkb_q'] trans [76.1557919] current loss 0.001347247640294945
# motors ['hkb_q'] trans [77.69949039] current loss 0.0012347760968753718
# motors ['hkb_q'] trans [77.082011] current loss 0.0012276740241968533
# motors ['hkb_q'] trans [76.4645316] current loss 0.0012205434087876916
# motors ['hkb_q'] trans [75.53831251] current loss 0.0013378962338223596
# motors ['hkb_q'] trans [76.69608637] current loss 0.0012232210236130844
# motors ['hkb_q'] trans [76.23297683] current loss 0.0012178637851866941
# motors ['hkb_q'] trans [75.76986728] current loss 0.0013414061493923915
# motors ['hkb_q'] trans [76.00142206] current loss 0.0013449124863935693
# motors ['hkb_q'] trans [76.29086552] current loss 0.001218534355938279
# motors ['hkb_q'] trans [76.17508814] current loss 0.001347540413818663
# motors ['hkb_q'] trans [76.247449] current loss 0.0012180307093629511
# motors ['hkb_q'] trans [76.21850466] current loss 0.0012176960387017847
# motors ['hkb_q'] trans [76.18956031] current loss 0.0013477587576745398
# motors ['hkb_q'] trans [76.20403248] current loss 0.0013479773992864017
# motors ['hkb_q'] trans [76.2221227] current loss 0.0012177379861309267
# motors ['hkb_q'] trans [76.21488661] current loss 0.0013481379713150535
# motors ['hkb_q'] trans [76.21940917] current loss 0.0012177062899005823
# motors ['hkb_q'] trans [76.21760014] current loss 0.0012176855333211878
# motors ['hkb_q'] trans [76.21579112] current loss 0.0013481519106972038
# motors ['hkb_q'] trans [76.21669563] current loss 0.0012176750476476975
# motors ['hkb_q'] trans [76.21488661] current loss 0.0013481379713150535
# motors ['hkb_q'] trans [76.21579112] current loss 0.0013481519106972038
# motors ['hkb_q'] trans [76.21692176] current loss 0.0012176776684361403
# motors ['hkb_q'] trans [76.21646951] current loss 0.0012176721852506995
# motors ['hkb_q'] trans [76.21601725] current loss 0.001348155319380074
# motors ['hkb_q'] trans [76.21624338] current loss 0.0012176698035256319
# motors ['hkb_q'] trans [76.21579112] current loss 0.001348151910697236
# motors ['hkb_q'] trans [76.21601725] current loss 0.001348155319380074
# motors ['hkb_q'] trans [76.21629991] current loss 0.0012176704587174333
#  20%|██        | 2/10 [01:44<07:24, 55.62s/it]
# Test 1 success True
# Initial motor positions are [184.8920379]
# motors ['hkb_q'] trans [0.] current loss 0.009749207839011908
# Initial loss is 0.009749207839011908
# motors ['hkb_q'] trans [-52.0372486] current loss 0.0026690151801249556
# motors ['hkb_q'] trans [-54.63911103] current loss 0.0023695974609190414
# motors ['hkb_q'] trans [-57.24097346] current loss 0.0018970480698829535
# motors ['hkb_q'] trans [-62.44469832] current loss 0.001283676784389006
# motors ['hkb_q'] trans [-70.25028561] current loss 0.00157759463296905
# motors ['hkb_q'] trans [-64.39609514] current loss 0.0011266618329449454
# motors ['hkb_q'] trans [-66.34749197] current loss 0.0012337523558893068
# motors ['hkb_q'] trans [-64.88394435] current loss 0.0011227376494696037
# motors ['hkb_q'] trans [-65.37179355] current loss 0.0012448949835173453
# motors ['hkb_q'] trans [-64.76198205] current loss 0.0011237208775280957
# motors ['hkb_q'] trans [-65.00590665] current loss 0.0012490550497798187
# motors ['hkb_q'] trans [-64.85345377] current loss 0.001122984017642687
# motors ['hkb_q'] trans [-64.91443492] current loss 0.0011224905517844496
# motors ['hkb_q'] trans [-64.97541607] current loss 0.00124939880364963
# motors ['hkb_q'] trans [-64.9449255] current loss 0.001249744245628544
# motors ['hkb_q'] trans [-64.90681228] current loss 0.0011225520209188033
# motors ['hkb_q'] trans [-64.92205757] current loss 0.0011224290805681519
# motors ['hkb_q'] trans [-64.93730286] current loss 0.0012498307925914334
# motors ['hkb_q'] trans [-64.92968021] current loss 0.0011223675951546603
# motors ['hkb_q'] trans [-64.9449255] current loss 0.0012497442456284424
# motors ['hkb_q'] trans [-64.93730286] current loss 0.0012498307925914334
# motors ['hkb_q'] trans [-64.92777455] current loss 0.0011223829816450763
# motors ['hkb_q'] trans [-64.93158587] current loss 0.0011223522085923592
# motors ['hkb_q'] trans [-64.93539719] current loss 0.0011223215547942146
# motors ['hkb_q'] trans [-64.94111418] current loss 0.0012497874380246914
# motors ['hkb_q'] trans [-64.93396795] current loss 0.0011223330991137468
# motors ['hkb_q'] trans [-64.93682644] current loss 0.001122310014657493
# motors ['hkb_q'] trans [-64.93968493] current loss 0.0012498036302553942
# motors ['hkb_q'] trans [-64.93825569] current loss 0.0012498199976728784
# motors ['hkb_q'] trans [-64.93646913] current loss 0.0011223128997551195
# motors ['hkb_q'] trans [-64.93718375] current loss 0.0012498319671546227
# motors ['hkb_q'] trans [-64.93673711] current loss 0.0011223107358427904
#  30%|███       | 3/10 [02:42<06:36, 56.64s/it]
# Test 2 success True
# Initial motor positions are [76.49895013]
# motors ['hkb_q'] trans [0.] current loss 0.016564190923985655
# Initial loss is 0.016564190923985655
# motors ['hkb_q'] trans [58.94949811] current loss 0.003214500935632905
# motors ['hkb_q'] trans [61.89697302] current loss 0.0035762890199463344
# motors ['hkb_q'] trans [56.00202321] current loss 0.002656776097361689
# motors ['hkb_q'] trans [50.10707339] current loss 0.0016870894963137923
# motors ['hkb_q'] trans [41.26464868] current loss 0.0012247543375337676
# motors ['hkb_q'] trans [23.57979924] current loss 0.005856063759227888
# motors ['hkb_q'] trans [32.42222396] current loss 0.0030780823497210544
# motors ['hkb_q'] trans [43.47525486] current loss 0.001122463143667698
# motors ['hkb_q'] trans [45.68586104] current loss 0.0012798156250068559
# motors ['hkb_q'] trans [42.92260331] current loss 0.0012437710397794925
# motors ['hkb_q'] trans [43.47525486] current loss 0.001122463143667698
#  40%|████      | 4/10 [03:07<04:23, 43.99s/it]
# Test 3 success True
# Initial motor positions are [96.76869326]
# motors ['hkb_q'] trans [0.] current loss 0.007141419987330542
# Initial loss is 0.007141419987330542
# motors ['hkb_q'] trans [-9.85752476] current loss 0.011194449886445638
# motors ['hkb_q'] trans [-10.35040099] current loss 0.011478879639297767
# motors ['hkb_q'] trans [-9.36464852] current loss 0.01094868815888282
# motors ['hkb_q'] trans [-8.37889604] current loss 0.010444061616195825
# motors ['hkb_q'] trans [-6.90026733] current loss 0.009863186965841465
# motors ['hkb_q'] trans [-3.9430099] current loss 0.0085898441769617
# motors ['hkb_q'] trans [0.49287624] current loss 0.006975352884943664
# motors ['hkb_q'] trans [9.36464852] current loss 0.0038467380256256957
# motors ['hkb_q'] trans [22.67230694] current loss 0.0012439922588829264
# motors ['hkb_q'] trans [49.28762378] current loss 0.004959036348755818
# motors ['hkb_q'] trans [35.97996536] current loss 0.002665350542709258
# motors ['hkb_q'] trans [25.99922154] current loss 0.0012883620609945576
# motors ['hkb_q'] trans [19.34539233] current loss 0.0014682871221388344
# motors ['hkb_q'] trans [23.50403559] current loss 0.0011248656132799525
# motors ['hkb_q'] trans [24.33576424] current loss 0.0011323155750773593
# motors ['hkb_q'] trans [23.71196775] current loss 0.0011265394361185499
# motors ['hkb_q'] trans [23.29610342] current loss 0.0011231946675570373
# motors ['hkb_q'] trans [22.8802391] current loss 0.0012463595710507003
# motors ['hkb_q'] trans [23.08817126] current loss 0.0011215163668389589
# motors ['hkb_q'] trans [22.67230694] current loss 0.0012439922588829264
# motors ['hkb_q'] trans [22.8802391] current loss 0.0012463595710507003
# motors ['hkb_q'] trans [23.1401543] current loss 0.0012493111387275086
# motors ['hkb_q'] trans [23.08817126] current loss 0.0011215163668389589
#  50%|█████     | 5/10 [03:50<03:39, 43.90s/it]
# Test 4 success True
# Initial motor positions are [169.54974334]
# motors ['hkb_q'] trans [0.] current loss 0.008286240108979308
# Initial loss is 0.008286240108979308
# motors ['hkb_q'] trans [78.08382496] current loss 0.014663917390331686
# motors ['hkb_q'] trans [81.9880162] current loss 0.014790394060248298
# motors ['hkb_q'] trans [74.17963371] current loss 0.014533175074994065
# motors ['hkb_q'] trans [66.37125121] current loss 0.0138288566483181
# motors ['hkb_q'] trans [54.65867747] current loss 0.013396173255373033
# motors ['hkb_q'] trans [31.23352998] current loss 0.01122458101685391
# motors ['hkb_q'] trans [-3.90419125] current loss 0.00807416602956195
# motors ['hkb_q'] trans [-74.17963371] current loss 0.007619659802978764
# motors ['hkb_q'] trans [-179.5927974] current loss inf
# motors ['hkb_q'] trans [-47.82634279] current loss 0.0011388545768633808
# motors ['hkb_q'] trans [-21.47305186] current loss 0.005608176809004636
# motors ['hkb_q'] trans [-41.23802006] current loss 0.0019140349751605823
# motors ['hkb_q'] trans [-54.41466552] current loss 0.001449773675266295
# motors ['hkb_q'] trans [-49.47342347] current loss 0.0011232876450503158
# motors ['hkb_q'] trans [-51.12050415] current loss 0.0012324260361641236
# motors ['hkb_q'] trans [-49.0616533] current loss 0.001126598467803826
# motors ['hkb_q'] trans [-49.88519364] current loss 0.0012465370438163842
# motors ['hkb_q'] trans [-49.37048093] current loss 0.0011241171940793563
# motors ['hkb_q'] trans [-49.57636601] current loss 0.001122456461407269
# motors ['hkb_q'] trans [-49.7822511] current loss 0.0011207932248755435
# motors ['hkb_q'] trans [-50.09107872] current loss 0.0012441918064531245
# motors ['hkb_q'] trans [-49.70504419] current loss 0.0012485856019969711
# motors ['hkb_q'] trans [-49.7822511] current loss 0.0011207932248755435
#  60%|██████    | 6/10 [04:33<02:53, 43.29s/it]
# Test 5 success True
# Initial motor positions are [146.26027381]
# motors ['hkb_q'] trans [0.] current loss 0.004969422184267713
# Initial loss is 0.004969422184267713
# motors ['hkb_q'] trans [-36.92410253] current loss 0.00310407604467221
# motors ['hkb_q'] trans [-38.77030765] current loss 0.003539902360386342
# motors ['hkb_q'] trans [-35.0778974] current loss 0.002332565398909688
# motors ['hkb_q'] trans [-31.38548715] current loss 0.0015828943100318332
# motors ['hkb_q'] trans [-25.84687177] current loss 0.0011259983806765253
# motors ['hkb_q'] trans [-14.76964101] current loss 0.00240921336489157
# motors ['hkb_q'] trans [-20.30825639] current loss 0.0016725472763754422
# motors ['hkb_q'] trans [-27.23152561] current loss 0.001239301926149814
# motors ['hkb_q'] trans [-24.46221792] current loss 0.0012741102019338574
# motors ['hkb_q'] trans [-26.19303523] current loss 0.0011232143696950974
# motors ['hkb_q'] trans [-26.53919869] current loss 0.0012471795320958532
# motors ['hkb_q'] trans [-26.10649436] current loss 0.0011239118532693142
# motors ['hkb_q'] trans [-26.27957609] current loss 0.0011225157402129583
# motors ['hkb_q'] trans [-26.45265783] current loss 0.0012481656427005342
# motors ['hkb_q'] trans [-26.36611696] current loss 0.0012491461095083321
# motors ['hkb_q'] trans [-26.25794088] current loss 0.0011226908214802
# motors ['hkb_q'] trans [-26.30121131] current loss 0.0011223409889416353
# motors ['hkb_q'] trans [-26.34448174] current loss 0.00124938940018866
# motors ['hkb_q'] trans [-26.32284653] current loss 0.0012496343870139607
# motors ['hkb_q'] trans [-26.29580251] current loss 0.0011223846608475261
# motors ['hkb_q'] trans [-26.30662012] current loss 0.0012498183668077098
# motors ['hkb_q'] trans [-26.29985911] current loss 0.0011223519072995345
# motors ['hkb_q'] trans [-26.30256351] current loss 0.0011223300661584385
# motors ['hkb_q'] trans [-26.30526791] current loss 0.0012498336862239888
# motors ['hkb_q'] trans [-26.30391571] current loss 0.001122319148225457
# motors ['hkb_q'] trans [-26.30662012] current loss 0.0012498183668077098
# motors ['hkb_q'] trans [-26.30526791] current loss 0.0012498336862239888
# motors ['hkb_q'] trans [-26.30357766] current loss 0.0011223218777707794
# motors ['hkb_q'] trans [-26.30425376] current loss 0.0012498453507196836
# motors ['hkb_q'] trans [-26.3038312] current loss 0.0011223198305351286
#  70%|███████   | 7/10 [05:27<02:21, 47.02s/it]
# Test 6 success True
# Initial motor positions are [201.01633394]
# motors ['hkb_q'] trans [0.] current loss 0.011620029828920422
# Initial loss is 0.011620029828920422
# motors ['hkb_q'] trans [67.93417661] current loss 0.01623435185479353
# motors ['hkb_q'] trans [71.33088544] current loss 0.01633340388314274
# motors ['hkb_q'] trans [64.53746778] current loss 0.01613267708770639
# motors ['hkb_q'] trans [57.74405012] current loss 0.015467651922096277
# motors ['hkb_q'] trans [47.55392363] current loss 0.014694574836507476
# motors ['hkb_q'] trans [27.17367065] current loss 0.013548334523455278
# motors ['hkb_q'] trans [-3.39670883] current loss 0.011083217683094533
# motors ['hkb_q'] trans [-64.53746778] current loss 0.0032574214717213884
# motors ['hkb_q'] trans [-156.24860621] current loss 0.049515910680221924
# motors ['hkb_q'] trans [-41.60968318] current loss 0.006799901600432497
# motors ['hkb_q'] trans [-87.46525239] current loss 0.0018332018790075044
# motors ['hkb_q'] trans [-133.3208216] current loss 0.022512923634095544
# motors ['hkb_q'] trans [-110.393037] current loss 0.009518387808529158
# motors ['hkb_q'] trans [-81.73330624] current loss 0.001242193240903908
# motors ['hkb_q'] trans [-76.00136009] current loss 0.0016514849995742738
# motors ['hkb_q'] trans [-80.3003197] current loss 0.0012584206585115002
# motors ['hkb_q'] trans [-83.16629278] current loss 0.001225754320819251
# motors ['hkb_q'] trans [-86.03226585] current loss 0.0015853775913384797
# motors ['hkb_q'] trans [-84.59927931] current loss 0.0014739786896250725
# motors ['hkb_q'] trans [-82.80804614] current loss 0.0012298894326735182
# motors ['hkb_q'] trans [-83.52453941] current loss 0.0012216172503717853
# motors ['hkb_q'] trans [-84.24103268] current loss 0.001342483050742452
# motors ['hkb_q'] trans [-83.88278604] current loss 0.0013479004878840467
# motors ['hkb_q'] trans [-83.43497775] current loss 0.0012226532860075024
# motors ['hkb_q'] trans [-83.61410107] current loss 0.0012205793407881838
# motors ['hkb_q'] trans [-83.79322439] current loss 0.0012185071991737133
# motors ['hkb_q'] trans [-84.06190936] current loss 0.0013451903437009499
# motors ['hkb_q'] trans [-83.72605314] current loss 0.0012192826615266415
# motors ['hkb_q'] trans [-83.86039563] current loss 0.0012177290373272867
# motors ['hkb_q'] trans [-83.99473812] current loss 0.0013462083072420278
# motors ['hkb_q'] trans [-83.92756687] current loss 0.001347223308640235
# motors ['hkb_q'] trans [-83.84360282] current loss 0.0012179231573576311
# motors ['hkb_q'] trans [-83.87718844] current loss 0.0013479849711283186
# motors ['hkb_q'] trans [-83.85619743] current loss 0.0012177775531597448
# motors ['hkb_q'] trans [-83.86459383] current loss 0.0012176803448228453
# motors ['hkb_q'] trans [-83.87299024] current loss 0.0012175839534111954
# motors ['hkb_q'] trans [-83.88558485] current loss 0.001347857933911284
# motors ['hkb_q'] trans [-83.86984159] current loss 0.0013480943834125805
# motors ['hkb_q'] trans [-83.87299024] current loss 0.0012175839534111954
#  80%|████████  | 8/10 [06:36<01:47, 53.98s/it]
# Test 7 success True
# Initial motor positions are [103.16454623]
# motors ['hkb_q'] trans [0.] current loss 0.0049853935906363665
# Initial loss is 0.0049853935906363665
# motors ['hkb_q'] trans [88.62381609] current loss 0.010810555749873363
# motors ['hkb_q'] trans [93.0550069] current loss 0.011019229784286176
# motors ['hkb_q'] trans [84.19262529] current loss 0.010592111489451666
# motors ['hkb_q'] trans [75.33024368] current loss 0.009429715050401315
# motors ['hkb_q'] trans [62.03667126] current loss 0.008049412086535404
# motors ['hkb_q'] trans [35.44952644] current loss 0.0038279570274341434
# motors ['hkb_q'] trans [-4.4311908] current loss 0.006323066362429883
# motors ['hkb_q'] trans [25.47934713] current loss 0.0019224885168521648
# motors ['hkb_q'] trans [15.50916782] current loss 0.0012352302763400545
# motors ['hkb_q'] trans [-4.4311908] current loss 0.006323066362431112
# motors ['hkb_q'] trans [5.53898851] current loss 0.0030643594426462708
# motors ['hkb_q'] trans [18.00171264] current loss 0.001132967851043336
# motors ['hkb_q'] trans [20.49425747] current loss 0.0014564287206420671
# motors ['hkb_q'] trans [17.37857644] current loss 0.0011270404332120825
# motors ['hkb_q'] trans [16.75544023] current loss 0.0012494368353957966
# motors ['hkb_q'] trans [17.53436049] current loss 0.0011282940369823275
# motors ['hkb_q'] trans [17.22279238] current loss 0.001125788196071188
# motors ['hkb_q'] trans [16.91122428] current loss 0.0011232832358567969
# motors ['hkb_q'] trans [16.44387213] current loss 0.0012458981754431893
# motors ['hkb_q'] trans [17.02806232] current loss 0.0011242256663687097
# motors ['hkb_q'] trans [16.79438624] current loss 0.0011223399391740408
# motors ['hkb_q'] trans [16.56071017] current loss 0.0012472269998481994
# motors ['hkb_q'] trans [16.6775482] current loss 0.001121397735214414
# motors ['hkb_q'] trans [16.44387213] current loss 0.0012458981754431893
# motors ['hkb_q'] trans [16.56071017] current loss 0.001247226785500431
# motors ['hkb_q'] trans [16.70675771] current loss 0.0011216335235822554
# motors ['hkb_q'] trans [16.64833869] current loss 0.0012482248758338961
# motors ['hkb_q'] trans [16.68485058] current loss 0.0011214567420603976
# motors ['hkb_q'] trans [16.67024583] current loss 0.0012484726778837331
# motors ['hkb_q'] trans [16.6793738] current loss 0.0012485767673606771
# motors ['hkb_q'] trans [16.6775482] current loss 0.001121397735214414
#  90%|█████████ | 9/10 [07:33<00:54, 54.72s/it]
# Test 8 success True
# Initial motor positions are [165.27500583]
# motors ['hkb_q'] trans [0.] current loss 0.008053519244685892
# Initial loss is 0.008053519244685892
# motors ['hkb_q'] trans [-40.86261464] current loss 0.0014704920807160802
# motors ['hkb_q'] trans [-42.90574537] current loss 0.0012825297216510908
# motors ['hkb_q'] trans [-44.94887611] current loss 0.0011252943502813575
# motors ['hkb_q'] trans [-49.03513757] current loss 0.0014706539681706608
# motors ['hkb_q'] trans [-46.99200684] current loss 0.0012307452757744093
# motors ['hkb_q'] trans [-45.45965879] current loss 0.0012482528015877882
# motors ['hkb_q'] trans [-44.94887611] current loss 0.0011252943502813575
# 100%|██████████| 10/10 [07:51<00:00, 47.11s/it]
# Test 9 success True

# %%
initial_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in initial_out_beams]
initial_hists, initial_dws = zip(*initial_hists_dws)

# %%
initial_peaks = [dw.get_parameter('peak_intensity') for dw in initial_dws]
initial_h_fwhms = [dw.get_parameter('h_fwhm') for dw in initial_dws]
initial_v_fwhms = [dw.get_parameter('v_fwhm') for dw in initial_dws]

# %%
final_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams]
final_hists, final_dws = zip(*final_hists_dws)

# %%
final_peaks = [dw.get_parameter('peak_intensity') for dw in final_dws]
final_h_fwhms = [dw.get_parameter('h_fwhm') for dw in final_dws]
final_v_fwhms = [dw.get_parameter('v_fwhm') for dw in final_dws]

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes[0].plot(absolute_movements)
axes[0].set_ylabel('perturbation')

axes[1].plot(initial_losses)
axes[1].set_ylabel('v_centroid')

axes[2].plot(initial_peaks)
axes[2].set_ylabel('peak_intensity')

axes[3].plot(initial_h_fwhms)
axes[3].set_ylabel('h_fwhm')
axes[3].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[4].plot(initial_v_fwhms)
axes[4].set_ylabel('v_fwhm')
axes[4].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('Initial settings')
fig.savefig(f'{fig_save_path}/initial_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

axes[0].plot(final_losses)
axes[0].set_ylabel('Loss')

axes[1].plot(final_peaks)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(initial_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Initial beams')
fig.savefig(f'{fig_save_path}/initial_beams.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams.png', bbox_inches='tight')

# %%
# Test gaussian process optimization

# %%
import skopt

# %%
callback = skopt.callbacks.DeltaYStopper(1e-3)

# %%
# %%time
initial_losses = []
initial_out_beams = []
absolute_movements = []

start_guesses = []
overall_successes = []
final_losses = []
final_out_beams = []
opt_results_all = []

min_trans = -100.
max_trans = 100.

for outer in tqdm(range(10)):
    translations = np.random.uniform(min_trans, max_trans, size=1)
    test_absolute_movements = initial_absolute_positions + translations
    print("Initial motor positions are", test_absolute_movements)
    absolute_movements.append(test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    fwhm, out_beam, hist, dw = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    initial_losses.append(fwhm)
    initial_out_beams.append(out_beam)
    
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='fwhm')
    opt_trial.set_gaussian_process_optimizer(bounds=[min_trans, max_trans], callback=callback)
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=True, guess_min=min_trans, guess_max=max_trans)
    focusing_system = opt_trial.focusing_system
    
    start_guesses.append(guesses)
    overall_successes.append(success)
    fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    final_losses.append(fwhm)
    final_out_beams.append(out_beam)
    opt_results_all.append(opt_results)
    print(f'Test {outer} success {success}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initial motor positions are [116.14518776]
# motors ['hkb_q'] trans [0.] current loss 0.001468875822236916
# Initial loss is 0.001468875822236916
# motors ['hkb_q'] trans [-12.56319429] current loss 0.004754513010497626
# motors ['hkb_q'] trans [36.04751347] current loss 0.006115636363651106
# motors ['hkb_q'] trans [-60.81515755] current loss 0.0342250056306328
# motors ['hkb_q'] trans [-83.92405261] current loss 0.07932494409776719
# motors ['hkb_q'] trans [78.2798723] current loss 0.010935872636958681
# motors ['hkb_q'] trans [-88.54144434] current loss 0.09773161046325517
# motors ['hkb_q'] trans [31.95072384] current loss 0.005609245348507629
# motors ['hkb_q'] trans [-84.39679075] current loss 0.08274055601909946
# motors ['hkb_q'] trans [72.50302055] current loss 0.010291735818420054
# motors ['hkb_q'] trans [74.87702598] current loss 0.010773482636865088
# motors ['hkb_q'] trans [6.60258581] current loss 0.0012880688246544347
# motors ['hkb_q'] trans [100.] current loss 0.01307117269844435
# motors ['hkb_q'] trans [-29.74529168] current loss 0.011484528117230048
# motors ['hkb_q'] trans [14.94875108] current loss 0.002396591884051359
# motors ['hkb_q'] trans [53.42291609] current loss 0.008287212899063794
# motors ['hkb_q'] trans [3.54479976] current loss 0.0012468265975426542
# motors ['hkb_q'] trans [2.59877095] current loss 0.0012360430386373995
# motors ['hkb_q'] trans [89.92251355] current loss 0.01184341325661452
# motors ['hkb_q'] trans [4.02258769] current loss 0.001124024321766941
# motors ['hkb_q'] trans [-43.00739772] current loss 0.01884088469996134
# motors ['hkb_q'] trans [4.77026349] current loss 0.0011303145651172506
#  10%|█         | 1/10 [00:42<06:19, 42.18s/it]
# Test 0 success True
# Initial motor positions are [201.08555459]
# motors ['hkb_q'] trans [0.] current loss 0.011623166815398222
# Initial loss is 0.011623166815398222
# motors ['hkb_q'] trans [62.11729226] current loss 0.016060812319859147
# motors ['hkb_q'] trans [-95.9155166] current loss 0.004196176528143917
# motors ['hkb_q'] trans [-95.32499676] current loss 0.004096395260973825
# motors ['hkb_q'] trans [66.15107672] current loss 0.016183374348024714
# motors ['hkb_q'] trans [-40.26632128] current loss 0.007181457883271339
# motors ['hkb_q'] trans [-25.47815933] current loss 0.008937172742687986
# motors ['hkb_q'] trans [-32.59159145] current loss 0.008229923350714017
# motors ['hkb_q'] trans [2.95032734] current loss 0.011754912827554994
# motors ['hkb_q'] trans [65.16755341] current loss 0.016153826018288152
# motors ['hkb_q'] trans [77.4277759] current loss 0.01650716413981849
# motors ['hkb_q'] trans [-81.63973714] current loss 0.0012440451539045283
# motors ['hkb_q'] trans [99.98679403] current loss 0.017082019561217257
# motors ['hkb_q'] trans [-64.24451967] current loss 0.0037440517630529524
# motors ['hkb_q'] trans [-77.34577629] current loss 0.0014579403268199036
# motors ['hkb_q'] trans [28.82097983] current loss 0.013612195770735525
# motors ['hkb_q'] trans [-81.23525808] current loss 0.0011214638900836264
# motors ['hkb_q'] trans [-81.70588457] current loss 0.0012432943678773927
# motors ['hkb_q'] trans [-9.36514598] current loss 0.010807278312778603
# motors ['hkb_q'] trans [-31.16762932] current loss 0.00830572457824008
# motors ['hkb_q'] trans [-94.93005323] current loss 0.003848410650725358
# motors ['hkb_q'] trans [-81.51716825] current loss 0.001245442036610398
#  20%|██        | 2/10 [01:24<05:36, 42.06s/it]
# Test 1 success True
# Initial motor positions are [95.72627688]
# motors ['hkb_q'] trans [0.] current loss 0.007448179138567517
# Initial loss is 0.007448179138567517
# motors ['hkb_q'] trans [94.1748147] current loss 0.01071873588994279
# motors ['hkb_q'] trans [-6.27821839] current loss 0.010028540789237275
# motors ['hkb_q'] trans [89.25178097] current loss 0.009753359587451042
# motors ['hkb_q'] trans [-48.40796489] current loss 0.04529377994376574
# motors ['hkb_q'] trans [-68.15395008] current loss 0.09616844359135451
# motors ['hkb_q'] trans [94.09684831] current loss 0.01071493094022787
# motors ['hkb_q'] trans [-74.54128084] current loss 0.1356270096932074
# motors ['hkb_q'] trans [44.04097775] current loss 0.004128274498776496
# motors ['hkb_q'] trans [36.28043548] current loss 0.002639493427064989
# motors ['hkb_q'] trans [4.86668406] current loss 0.0057832422826736
# motors ['hkb_q'] trans [65.73130559] current loss 0.007525414064055148
# motors ['hkb_q'] trans [21.15750039] current loss 0.0013441247355375904
# motors ['hkb_q'] trans [-23.57072929] current loss 0.019547585654558306
# motors ['hkb_q'] trans [27.47473764] current loss 0.0014478352048815843
# motors ['hkb_q'] trans [76.38269267] current loss 0.00875339541430379
# motors ['hkb_q'] trans [99.99954819] current loss 0.010996451137370371
# motors ['hkb_q'] trans [16.82699184] current loss 0.002093151816416925
# motors ['hkb_q'] trans [54.8775335] current loss 0.005745899449778337
# motors ['hkb_q'] trans [23.75662346] current loss 0.00124447040066248
# motors ['hkb_q'] trans [-99.99181481] current loss 10000.0
# motors ['hkb_q'] trans [-36.68491261] current loss 0.03054972349885664
# motors ['hkb_q'] trans [-15.17518399] current loss 0.014367552085750707
# motors ['hkb_q'] trans [-42.98980959] current loss 0.03720875342634358
# motors ['hkb_q'] trans [-71.68167844] current loss 0.11408841192482995
# motors ['hkb_q'] trans [-58.11705738] current loss 0.06439420478670381
# motors ['hkb_q'] trans [-29.9221309] current loss 0.024477121222245393
# motors ['hkb_q'] trans [82.38946091] current loss 0.009410051261174657
# motors ['hkb_q'] trans [-0.60494083] current loss 0.0076923424279764
# motors ['hkb_q'] trans [59.97603505] current loss 0.006305015023785701
# motors ['hkb_q'] trans [10.73417738] current loss 0.003735203632658049
# motors ['hkb_q'] trans [48.90308437] current loss 0.0048853999881438535
# motors ['hkb_q'] trans [71.47750969] current loss 0.008159934251871401
# motors ['hkb_q'] trans [-53.25872672] current loss 0.05349840097445378
# motors ['hkb_q'] trans [-9.65940809] current loss 0.011585836351101997
# motors ['hkb_q'] trans [31.5210921] current loss 0.0018866357780081711
#  30%|███       | 3/10 [02:34<06:23, 54.84s/it]
# Test 2 success True
# Initial motor positions are [133.39456601]
# motors ['hkb_q'] trans [0.] current loss 0.0026877099570165506
# Initial loss is 0.0026877099570165506
# motors ['hkb_q'] trans [71.93958603] current loss 0.01181167125417857
# motors ['hkb_q'] trans [-98.28774124] current loss 0.06944805204443694
# motors ['hkb_q'] trans [-45.21372047] current loss 0.010623745477078183
# motors ['hkb_q'] trans [-68.22736268] current loss 0.02478237870998808
# motors ['hkb_q'] trans [-76.26050456] current loss 0.03225982064315962
# motors ['hkb_q'] trans [-37.43373494] current loss 0.007369699840427944
# motors ['hkb_q'] trans [1.43129033] current loss 0.002962198737048166
# motors ['hkb_q'] trans [-10.75643319] current loss 0.0012864780554094524
# motors ['hkb_q'] trans [-86.92712913] current loss 0.045766395788263546
# motors ['hkb_q'] trans [-60.20051947] current loss 0.018789128156238667
# motors ['hkb_q'] trans [100.] current loss 0.013739230703340573
# motors ['hkb_q'] trans [36.49686612] current loss 0.008304323289074138
# motors ['hkb_q'] trans [53.83037996] current loss 0.010585439654183052
# motors ['hkb_q'] trans [-16.72623206] current loss 0.0013408572290993525
# motors ['hkb_q'] trans [18.7493854] current loss 0.006112945900069824
# motors ['hkb_q'] trans [88.21325672] current loss 0.013293978225177834
# motors ['hkb_q'] trans [-13.51054142] current loss 0.0012490312453919117
# motors ['hkb_q'] trans [-13.30643838] current loss 0.001123382905799751
# motors ['hkb_q'] trans [-40.08295047] current loss 0.00836324828082903
# motors ['hkb_q'] trans [-13.73846531] current loss 0.0012464411126716756
#  40%|████      | 4/10 [03:15<04:55, 49.31s/it]
# Test 3 success True
# Initial motor positions are [102.7966204]
# motors ['hkb_q'] trans [0.] current loss 0.004956592865833827
# Initial loss is 0.004956592865833827
# motors ['hkb_q'] trans [86.98803987] current loss 0.010713038901299052
# motors ['hkb_q'] trans [99.58591121] current loss 0.01168162135985319
# motors ['hkb_q'] trans [84.95781717] current loss 0.01061211436417289
# motors ['hkb_q'] trans [-69.1495023] current loss 0.07359286852785804
# motors ['hkb_q'] trans [-83.81952673] current loss 0.15097194841024147
# motors ['hkb_q'] trans [-35.41417185] current loss 0.02291020687775556
# motors ['hkb_q'] trans [40.00404192] current loss 0.0045315688639958876
# motors ['hkb_q'] trans [35.25052426] current loss 0.003561029267285446
# motors ['hkb_q'] trans [-83.91247565] current loss 0.15229227991464955
# motors ['hkb_q'] trans [-62.73954384] current loss 0.059039879507282796
# motors ['hkb_q'] trans [-0.73814758] current loss 0.005155157305938318
# motors ['hkb_q'] trans [16.17039324] current loss 0.001238594794996358
# motors ['hkb_q'] trans [61.37983779] current loss 0.007991644041472006
# motors ['hkb_q'] trans [-16.82825654] current loss 0.011615701640855272
# motors ['hkb_q'] trans [24.62996073] current loss 0.0018912661235777656
# motors ['hkb_q'] trans [9.97691337] current loss 0.0019551984542543507
# motors ['hkb_q'] trans [18.4194802] current loss 0.0011334980028534095
# motors ['hkb_q'] trans [72.13525021] current loss 0.008902343012254042
# motors ['hkb_q'] trans [17.2751027] current loss 0.0011232505827575988
#  50%|█████     | 5/10 [03:53<03:47, 45.57s/it]
# Test 4 success True
# Initial motor positions are [48.83338102]
# motors ['hkb_q'] trans [0.] current loss 0.042226224802885876
# Initial loss is 0.042226224802885876
# motors ['hkb_q'] trans [85.71302606] current loss 0.0029518277814784537
# motors ['hkb_q'] trans [-95.42716879] current loss 10000.0
# motors ['hkb_q'] trans [-11.16537083] current loss 0.06420954708925726
# motors ['hkb_q'] trans [50.21357244] current loss 0.006237449693166888
# motors ['hkb_q'] trans [-33.67129498] current loss 0.19145923464446887
# motors ['hkb_q'] trans [-36.19624823] current loss 0.2173762383207535
# motors ['hkb_q'] trans [-0.2430247] current loss 0.042704298280022805
# motors ['hkb_q'] trans [-70.79138001] current loss 10000.0
# motors ['hkb_q'] trans [-18.65988201] current loss 0.08720618405843913
# motors ['hkb_q'] trans [98.60233927] current loss 0.0053005288963456606
# motors ['hkb_q'] trans [27.22702568] current loss 0.01693140868672806
# motors ['hkb_q'] trans [-32.20347623] current loss 0.17997274568951951
# motors ['hkb_q'] trans [-34.61929897] current loss 0.20298870603819527
# motors ['hkb_q'] trans [-34.63950114] current loss 0.19782670671498842
# motors ['hkb_q'] trans [-34.65968267] current loss 0.19846767922053818
# motors ['hkb_q'] trans [-34.67857699] current loss 0.19907166215689967
# motors ['hkb_q'] trans [-34.69700614] current loss 0.19966436116056197
# motors ['hkb_q'] trans [-34.71445583] current loss 0.20611786308190455
# motors ['hkb_q'] trans [-34.73128867] current loss 0.20077651569635196
# motors ['hkb_q'] trans [-34.74761801] current loss 0.2013107226786037
# motors ['hkb_q'] trans [-34.7633614] current loss 0.21370038726934207
# motors ['hkb_q'] trans [-34.77872351] current loss 0.21423807755859478
# motors ['hkb_q'] trans [-34.79370193] current loss 0.20879938003724427
# motors ['hkb_q'] trans [-34.80826731] current loss 0.20929997174045448
# motors ['hkb_q'] trans [-34.82250928] current loss 0.2097917418943873
# motors ['hkb_q'] trans [-34.83354189] current loss 0.21017423672468052
# motors ['hkb_q'] trans [-34.84997764] current loss 0.2167680692698742
# motors ['hkb_q'] trans [-34.86331003] current loss 0.2172482126832674
# motors ['hkb_q'] trans [-34.876291] current loss 0.20562255636721108
# motors ['hkb_q'] trans [-34.88900177] current loss 0.2060587128814756
# motors ['hkb_q'] trans [-34.90137166] current loss 0.2064849587620995
# motors ['hkb_q'] trans [-34.91349672] current loss 0.21298990691174502
# motors ['hkb_q'] trans [-34.9253002] current loss 0.21341210502993038
# motors ['hkb_q'] trans [97.78213548] current loss 0.005256783659094573
# motors ['hkb_q'] trans [-34.88684626] current loss 0.20598464417779458
# motors ['hkb_q'] trans [-25.21669847] current loss 0.11980368924086102
# motors ['hkb_q'] trans [-34.8318948] current loss 0.21011702782211092
# motors ['hkb_q'] trans [-34.84489912] current loss 0.20455341985815662
# motors ['hkb_q'] trans [-34.85590792] current loss 0.21698138661749208
# motors ['hkb_q'] trans [-34.86705045] current loss 0.21738329775191523
# motors ['hkb_q'] trans [97.72714236] current loss 0.005253860490557244
# motors ['hkb_q'] trans [84.49815749] current loss 0.002906171825559837
# motors ['hkb_q'] trans [-34.83777846] current loss 0.20431246141240803
# motors ['hkb_q'] trans [48.02563721] current loss 0.007036933880348848
# motors ['hkb_q'] trans [-22.75454393] current loss 0.1035598221325249
# motors ['hkb_q'] trans [-34.77114535] current loss 0.2139724939884036
# motors ['hkb_q'] trans [97.50199913] current loss 0.004973281074767375
# motors ['hkb_q'] trans [31.31409357] current loss 0.014698038053738795
# motors ['hkb_q'] trans [-34.7503394] current loss 0.2013999628803983
# motors ['hkb_q'] trans [7.91267084] current loss 0.03327773114572858
# motors ['hkb_q'] trans [-34.72576704] current loss 0.20649631355246506
# motors ['hkb_q'] trans [-34.73259234] current loss 0.20081906549889264
# motors ['hkb_q'] trans [18.28000402] current loss 0.023262136319130235
# motors ['hkb_q'] trans [-34.70942686] current loss 0.20006587962939854
# motors ['hkb_q'] trans [39.20198268] current loss 0.010711807462728146
# motors ['hkb_q'] trans [-34.69082924] current loss 0.199465283159182
# motors ['hkb_q'] trans [82.75129523] current loss 0.002412195605013583
# motors ['hkb_q'] trans [56.65094349] current loss 0.0040804115183934436
# motors ['hkb_q'] trans [-34.67267685] current loss 0.19888263236082904
# motors ['hkb_q'] trans [-34.67901357] current loss 0.19908566348666268
# motors ['hkb_q'] trans [62.80496319] current loss 0.002205872144065796
# motors ['hkb_q'] trans [-34.6651149] current loss 0.21032548073663893
# motors ['hkb_q'] trans [68.62072969] current loss 0.001221181950069525
# motors ['hkb_q'] trans [-34.64964034] current loss 0.19232045120200747
# motors ['hkb_q'] trans [73.90774238] current loss 0.0012879718488912788
# motors ['hkb_q'] trans [-34.63982424] current loss 0.19783693489180157
# motors ['hkb_q'] trans [77.90767723] current loss 0.001690079105227788
# motors ['hkb_q'] trans [-23.02808043] current loss 0.10538439955103975
# motors ['hkb_q'] trans [43.58671929] current loss 0.008718551654883763
# motors ['hkb_q'] trans [-34.62989529] current loss 0.20333243610070886
# motors ['hkb_q'] trans [65.77751127] current loss 0.0015768897150530501
#  60%|██████    | 6/10 [06:17<05:15, 78.89s/it]
# Test 5 success True
# Initial motor positions are [126.62603292]
# motors ['hkb_q'] trans [0.] current loss 0.001687533190657414
# Initial loss is 0.001687533190657414
# motors ['hkb_q'] trans [-94.19053172] current loss 0.0797538701943639
# motors ['hkb_q'] trans [13.39979978] current loss 0.004140997809969043
# motors ['hkb_q'] trans [-70.59882381] current loss 0.03355610461401163
# motors ['hkb_q'] trans [16.23350354] current loss 0.004534532171319276
# motors ['hkb_q'] trans [31.41286781] current loss 0.0067271451176779875
# motors ['hkb_q'] trans [-78.77643868] current loss 0.04419413940497439
# motors ['hkb_q'] trans [-72.06646461] current loss 0.0355115291129263
# motors ['hkb_q'] trans [-57.9769608] current loss 0.021884538322876318
# motors ['hkb_q'] trans [47.23975] current loss 0.008846679062006478
# motors ['hkb_q'] trans [-5.69936175] current loss 0.0011304305731295891
# motors ['hkb_q'] trans [100.] current loss 0.013489319074590925
# motors ['hkb_q'] trans [-24.42845952] current loss 0.005166841131153405
# motors ['hkb_q'] trans [76.85301757] current loss 0.011730369271600883
# motors ['hkb_q'] trans [-38.42952982] current loss 0.010625604627330889
# motors ['hkb_q'] trans [62.56872992] current loss 0.010683943708025183
# motors ['hkb_q'] trans [-3.28038917] current loss 0.001450554112483278
# motors ['hkb_q'] trans [90.20162098] current loss 0.013099746313768462
# motors ['hkb_q'] trans [-13.94567394] current loss 0.0020974143196335303
# motors ['hkb_q'] trans [4.59154972] current loss 0.002400545837335029
# motors ['hkb_q'] trans [-6.54432204] current loss 0.0011233311581820853
# motors ['hkb_q'] trans [91.78334346] current loss 0.013164979825362837
# motors ['hkb_q'] trans [-76.0669558] current loss 0.04008761647969383
# motors ['hkb_q'] trans [35.04336088] current loss 0.007537293472972579
# motors ['hkb_q'] trans [19.46762769] current loss 0.004960948904168276
# motors ['hkb_q'] trans [-29.89940814] current loss 0.007135324647991211
# motors ['hkb_q'] trans [-6.73060894] current loss 0.0012491604716948243
#  70%|███████   | 7/10 [07:08<03:29, 69.85s/it]
# Test 6 success True
# Initial motor positions are [183.54858719]
# motors ['hkb_q'] trans [0.] current loss 0.00968392794101534
# Initial loss is 0.00968392794101534
# motors ['hkb_q'] trans [23.10120752] current loss 0.011868506013308683
# motors ['hkb_q'] trans [72.38597816] current loss 0.014928229657378908
# motors ['hkb_q'] trans [90.51934906] current loss 0.016382636378585395
# motors ['hkb_q'] trans [-63.89222638] current loss 0.0012464440197023302
# motors ['hkb_q'] trans [83.58056176] current loss 0.01618015767170787
# motors ['hkb_q'] trans [61.27202587] current loss 0.014570073248163274
# motors ['hkb_q'] trans [-95.52972417] current loss 0.010710733478530979
# motors ['hkb_q'] trans [-83.20766847] current loss 0.005757921341785504
# motors ['hkb_q'] trans [-47.49658509] current loss 0.0032396789908522667
# motors ['hkb_q'] trans [-79.87838027] current loss 0.004760965953557446
# motors ['hkb_q'] trans [-59.61976924] current loss 0.0014614722823046127
# motors ['hkb_q'] trans [-12.50147282] current loss 0.008696110243009793
# motors ['hkb_q'] trans [-63.75188174] current loss 0.001248041097340962
# motors ['hkb_q'] trans [-29.50909368] current loss 0.006216272646983165
# motors ['hkb_q'] trans [-62.98852614] current loss 0.0011271762827491604
# motors ['hkb_q'] trans [5.84739724] current loss 0.010693892070538554
# motors ['hkb_q'] trans [-63.62293759] current loss 0.0012495010080173935
#  80%|████████  | 8/10 [07:43<01:57, 58.80s/it]
# Test 7 success True
# Initial motor positions are [142.08367855]
# motors ['hkb_q'] trans [0.] current loss 0.004495284109002724
# Initial loss is 0.004495284109002724
# motors ['hkb_q'] trans [-99.77383793] current loss 0.053895373423109655
# motors ['hkb_q'] trans [-33.0448886] current loss 0.0030854739644026324
# motors ['hkb_q'] trans [13.06079348] current loss 0.006275540733744779
# motors ['hkb_q'] trans [-35.55024748] current loss 0.0037404858757664624
# motors ['hkb_q'] trans [-75.90113815] current loss 0.0237163513011527
# motors ['hkb_q'] trans [-9.17824211] current loss 0.0028899590050525696
# motors ['hkb_q'] trans [-65.62843747] current loss 0.01644698403296762
# motors ['hkb_q'] trans [29.24139468] current loss 0.008711138972961106
# motors ['hkb_q'] trans [-87.30792177] current loss 0.0351465836653107
# motors ['hkb_q'] trans [3.74245299] current loss 0.004947222517152522
# motors ['hkb_q'] trans [100.] current loss 0.014476932867618088
# motors ['hkb_q'] trans [-21.37036182] current loss 0.0012583896714112675
# motors ['hkb_q'] trans [-21.0416669] current loss 0.0011316531359759185
# motors ['hkb_q'] trans [70.61290687] current loss 0.012120571886423006
# motors ['hkb_q'] trans [-21.49150411] current loss 0.0011274351245020324
# motors ['hkb_q'] trans [51.39325005] current loss 0.010891181213328273
# motors ['hkb_q'] trans [-21.43322553] current loss 0.0011279032888006028
# motors ['hkb_q'] trans [-20.83358146] current loss 0.001133858175261115
#  90%|█████████ | 9/10 [08:20<00:52, 52.00s/it]
# Test 8 success True
# Initial motor positions are [173.39994233]
# motors ['hkb_q'] trans [0.] current loss 0.00882218227673648
# Initial loss is 0.00882218227673648
# motors ['hkb_q'] trans [-2.95363939] current loss 0.008663475999662992
# motors ['hkb_q'] trans [-2.94754088] current loss 0.008663808945466228
# motors ['hkb_q'] trans [37.80440573] current loss 0.01205973004356167
# motors ['hkb_q'] trans [15.65231472] current loss 0.010676879897041774
# motors ['hkb_q'] trans [-10.40009299] current loss 0.00761131519132513
# motors ['hkb_q'] trans [-11.51885378] current loss 0.007549220459011827
# motors ['hkb_q'] trans [81.29120433] current loss 0.014889800505635774
# motors ['hkb_q'] trans [-98.20034402] current loss 0.01784546397750032
# motors ['hkb_q'] trans [87.88201645] current loss 0.016000918854327938
# motors ['hkb_q'] trans [0.03704768] current loss 0.008824138419171105
# motors ['hkb_q'] trans [-41.96179861] current loss 0.0024075586339806694
# motors ['hkb_q'] trans [-53.56515865] current loss 0.0012484725829243625
# motors ['hkb_q'] trans [-62.43312397] current loss 0.00261376934566633
# motors ['hkb_q'] trans [58.08422889] current loss 0.013670142101785871
# motors ['hkb_q'] trans [-51.91726744] current loss 0.0011363206070810691
# motors ['hkb_q'] trans [-51.71979964] current loss 0.0011383971617298224
# motors ['hkb_q'] trans [-49.13481856] current loss 0.0013101657824606636
# motors ['hkb_q'] trans [-80.29478825] current loss 0.008430827175967484
# motors ['hkb_q'] trans [99.98738842] current loss 0.01636321725867936
# motors ['hkb_q'] trans [-51.94785949] current loss 0.0011359989370453448
# 100%|██████████| 10/10 [09:01<00:00, 54.14s/it]
# Test 9 success True
# CPU times: user 11min 53s, sys: 21min 30s, total: 33min 24s
# Wall time: 9min 1s

# %%
opt_results_all
# Out:
# [[          fun: 0.001124024321766941
#       func_vals: array([0.00475451, 0.00611564, 0.03422501, 0.07932494, 0.01093587,
#          0.09773161, 0.00560925, 0.08274056, 0.01029174, 0.01077348,
#          0.00128807, 0.01307117, 0.01148453, 0.00239659, 0.00828721,
#          0.00124683, 0.00123604, 0.01184341, 0.00112402, 0.01884088,
#          0.00113031])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29c0b9fd0>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=558083384), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [4.022587689617922]
#         x_iters: [[-12.563194291816473], [36.04751347220568], [-60.815157550241], [-83.92405261491376], [78.27987230113123], [-88.54144433623927], [31.950723840157963], [-84.3967907467456], [72.5030205492227], [74.87702597702517], [6.602585814812812], [100.0], [-29.74529168314973], [14.948751080635134], [53.422916087992945], [3.5447997615648603], [2.598770951193657], [89.92251354758247], [4.022587689617922], [-43.00739771949614], [4.770263494837934]]],
#  [          fun: 0.0011214638900836264
#       func_vals: array([0.01606081, 0.00419618, 0.0040964 , 0.01618337, 0.00718146,
#          0.00893717, 0.00822992, 0.01175491, 0.01615383, 0.01650716,
#          0.00124405, 0.01708202, 0.00374405, 0.00145794, 0.0136122 ,
#          0.00112146, 0.00124329, 0.01080728, 0.00830572, 0.00384841,
#          0.00124544])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29fbe0550>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=564392053), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-81.2352580823139]
#         x_iters: [[62.11729226075141], [-95.91551660291987], [-95.32499676019881], [66.15107671873554], [-40.26632127809028], [-25.478159329988372], [-32.591591451292345], [2.9503273402700785], [65.16755340661177], [77.42777589514301], [-81.63973713768871], [99.98679402957023], [-64.24451966790696], [-77.34577629223472], [28.820979827588047], [-81.2352580823139], [-81.70588457484345], [-9.365145978245138], [-31.167629319981216], [-94.93005323368232], [-81.51716824698127]]],
#  [          fun: 0.00124447040066248
#       func_vals: array([1.07187359e-02, 1.00285408e-02, 9.75335959e-03, 4.52937799e-02,
#          9.61684436e-02, 1.07149309e-02, 1.35627010e-01, 4.12827450e-03,
#          2.63949343e-03, 5.78324228e-03, 7.52541406e-03, 1.34412474e-03,
#          1.95475857e-02, 1.44783520e-03, 8.75339541e-03, 1.09964511e-02,
#          2.09315182e-03, 5.74589945e-03, 1.24447040e-03, 1.00000000e+04,
#          3.05497235e-02, 1.43675521e-02, 3.72087534e-02, 1.14088412e-01,
#          6.43942048e-02, 2.44771212e-02, 9.41005126e-03, 7.69234243e-03,
#          6.30501502e-03, 3.73520363e-03, 4.88539999e-03, 8.15993425e-03,
#          5.34984010e-02, 1.15858364e-02, 1.88663578e-03])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29fb25bd0>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=501317005), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [23.756623458729152]
#         x_iters: [[94.17481469942243], [-6.278218389790283], [89.25178097436469], [-48.40796488901628], [-68.1539500837195], [94.09684830755657], [-74.54128083561666], [44.04097775062627], [36.28043547577013], [4.86668405595465], [65.73130559341692], [21.157500392482405], [-23.570729289182978], [27.474737639241667], [76.38269266679853], [99.99954818804275], [16.82699184355083], [54.87753349875442], [23.756623458729152], [-99.99181481336016], [-36.684912608582025], [-15.175183990970936], [-42.989809590447656], [-71.681678440459], [-58.11705737748227], [-29.922130904597708], [82.38946090833309], [-0.6049408258123776], [59.976035045706254], [10.734177378809036], [48.90308436712786], [71.47750968715732], [-53.258726717333325], [-9.659408088725627], [31.52109210408304]]],
#  [          fun: 0.001123382905799751
#       func_vals: array([0.01181167, 0.06944805, 0.01062375, 0.02478238, 0.03225982,
#          0.0073697 , 0.0029622 , 0.00128648, 0.0457664 , 0.01878913,
#          0.01373923, 0.00830432, 0.01058544, 0.00134086, 0.00611295,
#          0.01329398, 0.00124903, 0.00112338, 0.00836325, 0.00124644])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c2a0a63550>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1385621551), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-13.306438377208934]
#         x_iters: [[71.93958602574804], [-98.28774124397064], [-45.21372047137707], [-68.2273626837958], [-76.26050455518023], [-37.43373494433736], [1.4312903277024844], [-10.756433194702879], [-86.92712913212306], [-60.200519468944904], [100.0], [36.4968661198609], [53.8303799608525], [-16.726232061246463], [18.749385403165803], [88.213256720197], [-13.510541421406657], [-13.306438377208934], [-40.08295047241383], [-13.738465310059453]]],
#  [          fun: 0.0011232505827575988
#       func_vals: array([0.01071304, 0.01168162, 0.01061211, 0.07359287, 0.15097195,
#          0.02291021, 0.00453157, 0.00356103, 0.15229228, 0.05903988,
#          0.00515516, 0.00123859, 0.00799164, 0.0116157 , 0.00189127,
#          0.0019552 , 0.0011335 , 0.00890234, 0.00112325])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29c44e4d0>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1723716693), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [17.27510269688534]
#         x_iters: [[86.98803987301352], [99.58591121194829], [84.95781717057147], [-69.14950229992925], [-83.8195267302445], [-35.41417184793639], [40.004041919629174], [35.250524264653905], [-83.91247564809285], [-62.73954383881772], [-0.7381475788821632], [16.170393235252646], [61.37983779362685], [-16.828256538849345], [24.629960733661264], [9.976913373887527], [18.419480203130064], [72.13525021022667], [17.27510269688534]]],
#  [          fun: 0.001221181950069525
#       func_vals: array([2.95182778e-03, 1.00000000e+04, 6.42095471e-02, 6.23744969e-03,
#          1.91459235e-01, 2.17376238e-01, 4.27042983e-02, 1.00000000e+04,
#          8.72061841e-02, 5.30052890e-03, 1.69314087e-02, 1.79972746e-01,
#          2.02988706e-01, 1.97826707e-01, 1.98467679e-01, 1.99071662e-01,
#          1.99664361e-01, 2.06117863e-01, 2.00776516e-01, 2.01310723e-01,
#          2.13700387e-01, 2.14238078e-01, 2.08799380e-01, 2.09299972e-01,
#          2.09791742e-01, 2.10174237e-01, 2.16768069e-01, 2.17248213e-01,
#          2.05622556e-01, 2.06058713e-01, 2.06484959e-01, 2.12989907e-01,
#          2.13412105e-01, 5.25678366e-03, 2.05984644e-01, 1.19803689e-01,
#          2.10117028e-01, 2.04553420e-01, 2.16981387e-01, 2.17383298e-01,
#          5.25386049e-03, 2.90617183e-03, 2.04312461e-01, 7.03693388e-03,
#          1.03559822e-01, 2.13972494e-01, 4.97328107e-03, 1.46980381e-02,
#          2.01399963e-01, 3.32777311e-02, 2.06496314e-01, 2.00819065e-01,
#          2.32621363e-02, 2.00065880e-01, 1.07118075e-02, 1.99465283e-01,
#          2.41219561e-03, 4.08041152e-03, 1.98882632e-01, 1.99085663e-01,
#          2.20587214e-03, 2.10325481e-01, 1.22118195e-03, 1.92320451e-01,
#          1.28797185e-03, 1.97836935e-01, 1.69007911e-03, 1.05384400e-01,
#          8.71855165e-03, 2.03332436e-01, 1.57688972e-03])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c2a0372fd0>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1563143705), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [68.62072968598022]
#         x_iters: [[85.71302605914704], [-95.42716878769957], [-11.16537082532254], [50.213572440626194], [-33.67129497625385], [-36.19624822857782], [-0.24302469967337004], [-70.79138000918417], [-18.659882011471908], [98.60233926572008], [27.227025679477308], [-32.20347623209153], [-34.61929897129036], [-34.639501139116064], [-34.65968267126861], [-34.678576989335596], [-34.697006141328615], [-34.71445583454603], [-34.731288669444666], [-34.74761801215017], [-34.76336139841963], [-34.77872350976257], [-34.79370192864236], [-34.808267306945055], [-34.82250928057489], [-34.833541889551256], [-34.8499776447409], [-34.863310026618976], [-34.87629099722193], [-34.88900176999246], [-34.90137166466167], [-34.91349671609525], [-34.925300195695144], [97.78213548289091], [-34.88684626103105], [-25.216698472701623], [-34.83189480203663], [-34.844899115953865], [-34.85590792038451], [-34.86705045112387], [97.72714236461607], [84.4981574865285], [-34.83777846270391], [48.025637212530825], [-22.754543929937867], [-34.77114534749016], [97.50199912736667], [31.31409357020422], [-34.750339395455455], [7.912670844868487], [-34.72576704413416], [-34.732592342892616], [18.280004016250516], [-34.70942685922415], [39.20198268189594], [-34.69082924091221], [82.75129523189557], [56.65094349148859], [-34.672676847072466], [-34.67901356538168], [62.80496319381464], [-34.6651148971378], [68.62072968598022], [-34.64964033756257], [73.90774238096051], [-34.6398242435384], [77.90767722898417], [-23.028080434098257], [43.58671928604366], [-34.62989529388972], [65.77751127285322]]],
#  [          fun: 0.0011233311581820853
#       func_vals: array([0.07975387, 0.004141  , 0.0335561 , 0.00453453, 0.00672715,
#          0.04419414, 0.03551153, 0.02188454, 0.00884668, 0.00113043,
#          0.01348932, 0.00516684, 0.01173037, 0.0106256 , 0.01068394,
#          0.00145055, 0.01309975, 0.00209741, 0.00240055, 0.00112333,
#          0.01316498, 0.04008762, 0.00753729, 0.00496095, 0.00713532,
#          0.00124916])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
# ...
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29c620890>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=503621894), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-6.544322039801685]
#         x_iters: [[-94.19053171984439], [13.399799783350346], [-70.59882381262778], [16.23350354112256], [31.412867806560286], [-78.77643867860164], [-72.0664646117928], [-57.976960801221914], [47.23975000490003], [-5.699361746260934], [100.0], [-24.42845952177376], [76.85301756916937], [-38.42952982318061], [62.56872991664383], [-3.280389165113391], [90.20162097571088], [-13.945673943919118], [4.591549721854008], [-6.544322039801685], [91.78334345787488], [-76.06695580169134], [35.04336087985408], [19.46762769380625], [-29.899408138881313], [-6.730608942288129]]],
#  [          fun: 0.0011271762827491604
#       func_vals: array([0.01186851, 0.01492823, 0.01638264, 0.00124644, 0.01618016,
#          0.01457007, 0.01071073, 0.00575792, 0.00323968, 0.00476097,
#          0.00146147, 0.00869611, 0.00124804, 0.00621627, 0.00112718,
#          0.01069389, 0.0012495 ])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29b623950>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=253236007), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-62.988526142896184]
#         x_iters: [[23.101207522771446], [72.3859781619974], [90.51934906034006], [-63.892226379385534], [83.58056176377767], [61.27202586577704], [-95.52972416659992], [-83.20766847265239], [-47.49658509247473], [-79.87838027150266], [-59.61976923978739], [-12.501472821546926], [-63.751881737073816], [-29.509093684809926], [-62.988526142896184], [5.847397244585679], [-63.62293759003547]]],
#  [          fun: 0.0011274351245020324
#       func_vals: array([0.05389537, 0.00308547, 0.00627554, 0.00374049, 0.02371635,
#          0.00288996, 0.01644698, 0.00871114, 0.03514658, 0.00494722,
#          0.01447693, 0.00125839, 0.00113165, 0.01212057, 0.00112744,
#          0.01089118, 0.0011279 , 0.00113386])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c29fe646d0>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=725652056), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-21.49150410741393]
#         x_iters: [[-99.77383792974979], [-33.04488860348978], [13.0607934753139], [-35.5502474780606], [-75.90113814711249], [-9.17824210958345], [-65.62843746580936], [29.241394676385227], [-87.30792177053989], [3.7424529934771016], [100.0], [-21.370361818452125], [-21.04166689892581], [70.61290686683566], [-21.49150410741393], [51.39325004776319], [-21.433225528285377], [-20.833581463296014]]],
#  [          fun: 0.0011359989370453448
#       func_vals: array([0.00866348, 0.00866381, 0.01205973, 0.01067688, 0.00761132,
#          0.00754922, 0.0148898 , 0.01784546, 0.01600092, 0.00882414,
#          0.00240756, 0.00124847, 0.00261377, 0.01367014, 0.00113632,
#          0.0011384 , 0.00131017, 0.00843083, 0.01636322, 0.001136  ])
#          models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5) + WhiteKernel(noise_level=1),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086)]
#    random_state: RandomState(MT19937) at 0x14C2B08AF270
#           space: Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')])
#           specs: {'args': {'func': <bound method OptimizationCommon.TrialInstanceLossFunction.loss of <beamline34IDC.optimization.common.OptimizationCommon.TrialInstanceLossFunction object at 0x14c2a08fc090>>, 'dimensions': Space([Real(low=-100.0, high=100.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=1, nu=2.5),
#                            n_restarts_optimizer=2, noise='gaussian',
#                            normalize_y=True, random_state=1321407086), 'n_calls': 100, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x14C2B08AF270, 'verbose': False, 'callback': <skopt.callbacks.DeltaYStopper object at 0x14c29bb58b90>, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#               x: [-51.94785948551581]
#         x_iters: [[-2.9536393881526806], [-2.947540875105915], [37.804405729912276], [15.652314724004412], [-10.400092985905857], [-11.518853783795251], [81.29120433131501], [-98.20034402199408], [87.88201645046146], [0.03704768443002138], [-41.96179861024579], [-53.565158650483745], [-62.43312397203319], [58.08422889285515], [-51.91726743556258], [-51.71979963834977], [-49.13481856211208], [-80.29478824866982], [99.98738841561257], [-51.94785948551581]]]]

# %%
initial_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in initial_out_beams]
initial_hists, initial_dws = zip(*initial_hists_dws)

# %%
initial_peaks = [dw.get_parameter('peak_intensity') for dw in initial_dws]
initial_h_fwhms = [dw.get_parameter('h_fwhm') for dw in initial_dws]
initial_v_fwhms = [dw.get_parameter('v_fwhm') for dw in initial_dws]

# %%
final_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams]
final_hists, final_dws = zip(*final_hists_dws)

# %%
final_peaks = [dw.get_parameter('peak_intensity') for dw in final_dws]
final_h_fwhms = [dw.get_parameter('h_fwhm') for dw in final_dws]
final_v_fwhms = [dw.get_parameter('v_fwhm') for dw in final_dws]

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes[0].plot(absolute_movements)
axes[0].set_ylabel('perturbation')

#axes[1].plot(initial_centroids)
#axes[1].set_ylabel('v_centroid')

axes[2].plot(initial_peaks)
axes[2].set_ylabel('peak_intensity')

axes[3].plot(initial_h_fwhms)
axes[3].set_ylabel('h_fwhm')
axes[3].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[4].plot(initial_v_fwhms)
axes[4].set_ylabel('v_fwhm')
axes[4].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('Initial settings')
fig.savefig(f'{fig_save_path}/initial_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

#axes[0].plot(final_centroids)
#axes[0].set_ylabel('v_centroid')

axes[1].plot(final_peaks)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(initial_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Initial beams')
fig.savefig(f'{fig_save_path}/initial_beams.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams.png', bbox_inches='tight')

# %%
clean_up()

# %%
shutil.rmtree(temp_work_dir)
