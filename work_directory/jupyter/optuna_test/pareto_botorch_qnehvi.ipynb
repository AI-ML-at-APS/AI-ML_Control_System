# %%
# %load_ext autoreload
# %autoreload 2

# %%
from aps_ai.beamline34IDC.simulation.facade.focusing_optics_interface import Movement

import aps_ai
from aps_ai.beamline34IDC.simulation.facade import Implementors
from aps_ai.beamline34IDC.facade.focusing_optics_factory import focusing_optics_factory_method, ExecutionMode
from aps_ai.beamline34IDC.facade.focusing_optics_interface import Movement, AngularUnits, DistanceUnits
from aps_ai.beamline34IDC.simulation.facade.focusing_optics_interface import get_default_input_features
from aps_ai.common.util.shadow.common import plot_shadow_beam_spatial_distribution, get_shadow_beam_spatial_distribution, \
    load_shadow_beam, PreProcessorFiles, EmptyBeamException
import aps_ai.beamline34IDC.optimization.movers as movers
import aps_ai.beamline34IDC.optimization.common as opt_common
import aps_ai.beamline34IDC.optimization.configs as configs
from aps_ai.common.util import clean_up
from aps_ai.common.util.wrappers import PlotMode


from Shadow.ShadowTools import focnew
from pathlib import Path

import os
import matplotlib.pyplot as plt
import numpy as np
import scipy
from tqdm import tqdm
import shutil
import IPython
from skopt.callbacks import DeltaXStopper, DeltaYStopper, DeadlineStopper
from pathlib import Path
import optuna
from test_optuna_qnehvi import BoTorchSampler, qnehvi_candidates_func

# %matplotlib inline

# %%
DEFAULT_RANDOM_SEED = np.random.randint(100000)
print(DEFAULT_RANDOM_SEED)
# Out:
# 99368

# %%
# !pwd
# Out:
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test

# %%
base_dir = Path(aps_ai.__file__).parents[1]
orig_work_dir = base_dir /'work_directory'
temp_work_dir = base_dir / f'tmp_work_dir_{DEFAULT_RANDOM_SEED}'
temp_work_dir.mkdir(exist_ok=True)

# %%
dat_files = list(orig_work_dir.glob('*.dat')) + list(orig_work_dir.glob('*.ini'))
for df in dat_files:
    shutil.copy(df, temp_work_dir)

# %%
os.chdir(temp_work_dir)

# %%
input_beam_path = "primary_optics_system_beam.dat"

# %%
move_motors_ranges = {'hkb_1': [-50, 50], 
                      'vkb_1': [-50, 50],
                      'hkb_2': [-50, 50],
                      'vkb_2': [-50, 50],
                      'hkb_3': [-0.04, 0.04],
                      'vkb_3': [-0.04, 0.04],
                      'hkb_4': [-30, 30], 
                      'vkb_4': [-30, 30]}

# %%
save_figs = False

if save_figs:
    motors_str = move_motors[0] if len(move_motors) == 1 else '_'.join(move_motors)
    fig_save_path = f'{orig_work_dir}/figures/{motors_str}/'
    if not os.path.isdir(fig_save_path):
        os.mkdir(fig_save_path)

# %%
# Focusing Optics System -------------------------
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path, bender=True)
plot_shadow_beam_spatial_distribution(focusing_system.get_photon_beam())
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.

# %%
initial_absolute_positions = np.array(movers.get_absolute_positions(focusing_system, list(move_motors_ranges.keys())))
print(initial_absolute_positions)
# Out:
# [215.5 144.  112.5 231.5   3.    3.    0.    0. ]

# %%
hkb_motors_ranges = {k:v for k, v in move_motors_ranges.items() if 'hkb' in k}

# %%
vkb_motors_ranges = {k:v for k, v in move_motors_ranges.items() if 'vkb' in k}

# %%
class OptunaOptimizer(opt_common.OptimizationCommon):
    """"""
    opt_platform = 'optuna'

    
    #def motor_subset_loss_function(self, motor_types: list, verbose: bool = True):
    #    lossfn_object_this = self.TrialInstanceLossFunction(self, verbose=verbose)
    #    
    #    translations_all = np.zeros(len(self.motor_types))
    #    
    #    def closure_fn(translations):
    #        for ix, motor in enumerate(motor_types):
    #            iy = self.motor_types.index(motor)
    #            translations_all[iy] = translations[ix]
    #        
    #        return lossfn_object_this.loss(translations_all)
    #    return closure_fn
    
    def set_optimizer_options(self, motor_ranges: list=None, 
                              base_sampler: optuna.samplers.BaseSampler = None, 
                              directions: str = None, 
                              integral_threshold: float = 1e2,
                              raise_prune_exception: bool = True,
                              **extra_options):
        
        self.motor_ranges = self._get_guess_ranges(motor_ranges)
        
        if base_sampler is None:
            #if self.multi_objective_optimization:
            #    base_sampler = optuna.samplers.MOTPESampler()
            #else:
            base_sampler = optuna.samplers.TPESampler()
        self._base_sampler = base_sampler
        self._raise_prune_exception = raise_prune_exception
        
        if directions is None:
            directions = ['minimize'] * len(self._loss_function_list)
        elif len(directions) != len(self._loss_function_list):
            raise ValueError
        self._directions = directions
        
        self.study = optuna.create_study(sampler=self._base_sampler, directions=self._directions)
        self.study.enqueue_trial({mt: 0. for mt in self.motor_types})
        
        loss_fn_obj = self.TrialInstanceLossFunction(self, verbose=False)
        self._loss_fn_this = loss_fn_obj.loss
        self.integral_threshold = integral_threshold
        
        self.best_params = {k: 0. for k in self.motor_types}
    
    def _objective(self, trial):
        current_params = []
        for mot, r in zip(self.motor_types, self.motor_ranges):
            resolution = configs.DEFAULT_MOTOR_RESOLUTIONS[mot]
            #print(mot, 'Min, max, resolution', r[0], r[1], resolution)
            current_params.append(trial.suggest_float(mot, r[0], r[1], step=resolution))
        loss = self._loss_fn_this(current_params)
        if self.multi_objective_optimization:
            if np.nan in loss and self._raise_prune_exception:
                raise optuna.TrialPruned
            loss[np.isnan(loss)] = 1e4
            
            if self.integral_threshold is not None:
                if self.beam_state.hist.data_2D.sum() < self.integral_threshold:
                    if self._raise_prune_exception:
                        raise optuna.TrialPruned
                    else:
                        return [1e4] * len(self._loss_function_list)
                    
            
            for k in ['sigma', 'fwhm']:
                if k in self.loss_parameters:
                    width_idx = self.loss_parameters.index(k)
                    if loss[width_idx] == 0: loss[width_idx] = 1e4
            loss = list(loss)
        

        rads = (self.beam_state.hist.hh**2 + self.beam_state.hist.vv**2)**0.5
        weighted_sum_ints = np.sum(self.beam_state.hist.data_2D * rads)
        trial.set_user_attr("wsum", weighted_sum_ints)
            
        return loss
    
    def trials(self, n_trials: int, trial_motor_types: list = None):
        if trial_motor_types is None:
            self.study.optimize(self._objective, n_trials)
            
        else:
            
            fixed_params = {k: self.best_params[k] for k in self.best_params if k not in trial_motor_types}
            partial_sampler = optuna.samplers.PartialFixedSampler(fixed_params, self._base_sampler)
            
            self.study.sampler = partial_sampler
            self.study.optimize(self._objective, n_trials=n_trials)
            
            self.study.sampler = self._base_sampler
        
        self.best_params.update(self.study.best_trials[0].params)
    
    #def trials(self, n_guesses = 1, verbose: bool = False, accept_all_solutions: bool = False):
    #    pass
    
    def _optimize(self):
        pass

    #def set_optimizer_options(self):
    #    pass

# %%
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path, bender=True)
beam, hist, dw = opt_common.get_beam_hist_dw(focusing_system)
plot_shadow_beam_spatial_distribution(beam)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.

# %%
centroid_ground, *_ = opt_common.get_centroid_distance(photon_beam=beam, random_seed=DEFAULT_RANDOM_SEED)
sigma_ground, *_ = opt_common.get_sigma(photon_beam=beam)
centroid_ground, sigma_ground
# Out:
# (0.0004134023056922426, 0.0025289989338900926)

# %%
initial_movement, focusing_system, beam, hist, dw = opt_common.get_random_init(focusing_system, motor_types=list(move_motors_ranges.keys()),
                                                                               init_range=list(move_motors_ranges.values()),
                                                                               xrange=[-0.04, 0.04],yrange=[-0.04,0.04], 
                                                                               integral_threshold=100,
                                                                               nbins=128)
plt.pcolormesh(hist.vv, hist.hh, hist.data_2D.T)
plt.colorbar()
plt.show()
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# Random initialization is ['hkb_1', 'vkb_1', 'hkb_2', 'vkb_2', 'hkb_3', 'vkb_3', 'hkb_4', 'vkb_4'] [-26.165380949922813, -38.13721990562948, 5.2442830262224405, -20.63260077746779, -0.008343069930493316, -0.006755907874195985, -22.043529304161897, -2.1638262950881284]

# %%
hist.data_2D.sum()
# Out:
# 260.4704788545897

# %%
focusing_system = movers.move_motors(focusing_system, list(move_motors_ranges.keys()), initial_absolute_positions + initial_movement, movement='absolute')

# %%
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)

# %%
opt_trial = OptunaOptimizer(focusing_system, 
                            motor_types=list(move_motors_ranges.keys()), 
                            random_seed=DEFAULT_RANDOM_SEED, 
                            loss_parameters=['centroid', 'sigma'],
                            loss_min_value=5e-4,
                            use_gaussian_fit=False,
                            multi_objective_optimization=True,
                            camera_xrange=[-0.03, 0.03],
                            camera_yrange=[-0.03, 0.03],
                            camera_nbins=512)
#opt_trial.motor_ranges = centroid_ranges

# %% [markdown]
# opt_trial.reset()

# %%
#base_sampler = optuna.integration.BoTorchSampler()
base_sampler = BoTorchSampler(candidates_func=qnehvi_candidates_func, acq_func_kwargs={'ref_point':[-1e-3,-5e-3]})
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_78784/2930600393.py:2: ExperimentalWarning: BoTorchSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   base_sampler = BoTorchSampler(candidates_func=qnehvi_candidates_func, acq_func_kwargs={'ref_point':[-1e-3,-5e-3]})

# %%
# Pruning too manu values. For now, setting values to 1e4 instead of pruning
opt_trial.set_optimizer_options(motor_ranges=list(move_motors_ranges.values()), integral_threshold=100, base_sampler=base_sampler,
                                raise_prune_exception=True)
# Out:
# [I 2022-10-06 00:13:57,584] A new study created in memory with name: no-name-6943063e-c47d-497a-8435-1f71503018f2

# %%
opt_trial.trials(100, trial_motor_types=['hkb_4', 'vkb_4', 'hkb_3', 'vkb_3'])
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_78784/3771019275.py:91: ExperimentalWarning: PartialFixedSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   partial_sampler = optuna.samplers.PartialFixedSampler(fixed_params, self._base_sampler)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:14:24,470] Trial 1 finished with values: [0.012716664072147929, 0.004771375233110274] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.0016027564561247529, 'vkb_3': -0.008584073464102067, 'hkb_4': 27.0, 'vkb_4': -0.7999999999999972}.
# [I 2022-10-06 00:14:25,719] Trial 2 finished with values: [0.034635347955250334, 0.010113723205114802] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.017595865315812878, 'vkb_3': -0.012074731968090727, 'hkb_4': 1.5, 'vkb_4': -15.0}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-10-06 00:14:26,821] Trial 3 pruned.
# [I 2022-10-06 00:14:28,459] Trial 4 pruned.
# [I 2022-10-06 00:14:29,439] Trial 5 pruned.
# [I 2022-10-06 00:14:31,239] Trial 6 pruned.
# [I 2022-10-06 00:14:32,229] Trial 7 pruned.
# [I 2022-10-06 00:14:33,165] Trial 8 finished with values: [0.00965432351958384, 0.0038696550935142333] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.010614548307835557, 'vkb_3': 0.0071238898038469, 'hkb_4': 25.900000000000006, 'vkb_4': 11.0}.
# [I 2022-10-06 00:14:34,866] Trial 9 pruned.
# [I 2022-10-06 00:14:35,789] Trial 10 finished with values: [0.016425441583956014, 0.016196043909240773] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.036509341496011344, 'vkb_3': 0.019341194567807203, 'hkb_4': 27.400000000000006, 'vkb_4': 27.5}.
# [I 2022-10-06 00:14:36,944] Trial 11 pruned.
# [I 2022-10-06 00:14:37,955] Trial 12 pruned.
# [I 2022-10-06 00:14:39,197] Trial 13 pruned.
# [I 2022-10-06 00:14:40,091] Trial 14 pruned.
# [I 2022-10-06 00:14:41,283] Trial 15 pruned.
# [I 2022-10-06 00:14:42,110] Trial 16 finished with values: [0.024805827683297567, 0.005400468576394912] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.024292036732051034, 'vkb_3': 0.021086523819801535, 'hkb_4': 20.1, 'vkb_4': 19.6}.
# [I 2022-10-06 00:14:43,144] Trial 17 pruned.
# [I 2022-10-06 00:14:44,350] Trial 18 pruned.
# [I 2022-10-06 00:14:45,263] Trial 19 pruned.
# [I 2022-10-06 00:14:46,766] Trial 20 pruned.
# [I 2022-10-06 00:14:47,499] Trial 21 pruned.
# [I 2022-10-06 00:14:48,333] Trial 22 pruned.
# [I 2022-10-06 00:14:49,564] Trial 23 pruned.
# [I 2022-10-06 00:14:50,359] Trial 24 pruned.
# [I 2022-10-06 00:14:51,152] Trial 25 finished with values: [0.006395257305459883, 0.009159495233916308] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.019056048976068045, 'vkb_3': 0.015850536063818546, 'hkb_4': 22.0, 'vkb_4': -12.599999999999998}.
# [I 2022-10-06 00:14:52,266] Trial 26 pruned.
# [I 2022-10-06 00:14:53,742] Trial 27 finished with values: [0.011621505850108009, 0.004535848389361061] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.026322511575784517, 'vkb_3': -0.015565390472079388, 'hkb_4': 20.200000000000003, 'vkb_4': 3.1000000000000014}.
# [I 2022-10-06 00:14:54,728] Trial 28 pruned.
# [I 2022-10-06 00:14:55,595] Trial 29 pruned.
# [I 2022-10-06 00:14:56,385] Trial 30 pruned.
# [I 2022-10-06 00:14:57,262] Trial 31 finished with values: [0.007321164141222948, 0.009180862328107064] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.001887902047863911, 'vkb_3': 0.0001425727958695791, 'hkb_4': 13.900000000000006, 'vkb_4': 16.800000000000004}.
# [I 2022-10-06 00:14:58,532] Trial 32 finished with values: [0.01770891523584358, 0.005210665450134483] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.026322511575784517, 'vkb_3': 0.022831853071795867, 'hkb_4': 13.200000000000003, 'vkb_4': 6.100000000000001}.
# [I 2022-10-06 00:14:59,537] Trial 33 pruned.
# [I 2022-10-06 00:15:00,321] Trial 34 pruned.
# [I 2022-10-06 00:15:01,568] Trial 35 pruned.
# [I 2022-10-06 00:15:02,385] Trial 36 pruned.
# [I 2022-10-06 00:15:03,345] Trial 37 pruned.
# [I 2022-10-06 00:15:04,773] Trial 38 finished with values: [0.016378921762177652, 0.0045832767105627985] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.015850536063818546, 'vkb_3': -0.024292036732051034, 'hkb_4': 26.5, 'vkb_4': 0.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:07,945] Trial 39 finished with values: [0.014864304958966398, 0.004921410572844747] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.026037365984045366, 'vkb_3': -0.026037365984045366, 'hkb_4': 25.5, 'vkb_4': 8.400000000000006}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:11,285] Trial 40 finished with values: [0.0016980149225368853, 0.004509317124372114] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.001887902047863911, 'vkb_3': -0.003348085708119078, 'hkb_4': 22.400000000000006, 'vkb_4': 6.899999999999999}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:14,409] Trial 41 finished with values: [0.008711608897492059, 0.005583292234388523] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.005378560551852568, 'vkb_3': -0.006838744212107742, 'hkb_4': 30.0, 'vkb_4': 9.800000000000004}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:16,931] Trial 42 finished with values: [0.0009002034228487802, 0.00408315227473025] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.012074731968090727, 'vkb_3': 0.001887902047863911, 'hkb_4': 16.900000000000006, 'vkb_4': 4.100000000000001}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:19,602] Trial 43 finished with values: [0.009528177693836683, 0.004360440906582199] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.027782695236039694, 'vkb_3': 0.001887902047863911, 'hkb_4': 22.200000000000003, 'vkb_4': 8.200000000000003}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:22,539] Trial 44 finished with values: [0.006669651167827189, 0.004570937669615779] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.003348085708119078, 'vkb_3': -0.003348085708119078, 'hkb_4': 13.300000000000004, 'vkb_4': 6.800000000000004}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:25,613] Trial 45 finished with values: [0.019877101995467914, 0.00561670127833194] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.006838744212107742, 'vkb_3': 0.022831853071795867, 'hkb_4': 30.0, 'vkb_4': 11.300000000000004}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:28,058] Trial 46 finished with values: [0.004151846678214085, 0.004721762563196025] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.031273353740028355, 'vkb_3': -0.00509341496011341, 'hkb_4': 15.600000000000001, 'vkb_4': 4.700000000000003}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:30,920] Trial 47 finished with values: [0.0034640928522502758, 0.004051467509281132] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.0016027564561247529, 'vkb_3': 0.001887902047863911, 'hkb_4': 19.1, 'vkb_4': 1.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:33,412] Trial 48 finished with values: [0.005561335453697433, 0.0043933286342563785] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.024292036732051034, 'vkb_3': 0.003633231299858236, 'hkb_4': 16.1, 'vkb_4': -1.1999999999999993}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:36,084] Trial 49 finished with values: [0.012003333101265069, 0.004095131032046783] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.006838744212107742, 'vkb_3': 0.008869219055841225, 'hkb_4': 22.800000000000004, 'vkb_4': 12.300000000000004}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:39,059] Trial 50 finished with values: [0.0015041546362979021, 0.004825093043169065] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.00509341496011341, 'vkb_3': -0.003348085708119078, 'hkb_4': 18.900000000000006, 'vkb_4': 8.100000000000001}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:41,862] Trial 51 finished with values: [0.007498395943419271, 0.0037970844997331876] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.012359877559829889, 'vkb_3': 0.008869219055841225, 'hkb_4': 20.0, 'vkb_4': 8.0}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:44,908] Trial 52 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:48,189] Trial 53 finished with values: [0.02168599267423761, 0.004876536963559468] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.031273353740028355, 'vkb_3': -0.03825467074800567, 'hkb_4': 18.0, 'vkb_4': 1.9000000000000021}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:51,365] Trial 54 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:54,149] Trial 55 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:56,743] Trial 56 finished with values: [0.01666048514202104, 0.00940879383629948] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.027782695236039694, 'vkb_3': 0.015850536063818546, 'hkb_4': 12.200000000000003, 'vkb_4': 12.700000000000003}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:15:59,987] Trial 57 finished with values: [0.012236924468037568, 0.004206700384061718] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.026322511575784517, 'vkb_3': 0.015850536063818546, 'hkb_4': 23.1, 'vkb_4': 9.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:02,647] Trial 58 finished with values: [0.00893515960217761, 0.004162837693745442] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.001887902047863911, 'vkb_3': 0.0001425727958695791, 'hkb_4': 13.200000000000003, 'vkb_4': 1.7000000000000028}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:05,628] Trial 59 finished with values: [0.00431695280860633, 0.011180018263883259] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.022831853071795867, 'vkb_3': -0.008584073464102067, 'hkb_4': 21.700000000000003, 'vkb_4': 13.400000000000006}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:08,565] Trial 60 finished with values: [0.014122261989880645, 0.00384516604641919] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.006838744212107742, 'vkb_3': 0.0071238898038469, 'hkb_4': 30.0, 'vkb_4': 10.0}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:11,482] Trial 61 finished with values: [0.010197594088145764, 0.004470381167563118] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.008584073464102067, 'vkb_3': -0.015565390472079388, 'hkb_4': 18.5, 'vkb_4': 2.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:14,652] Trial 62 finished with values: [0.006384506435776498, 0.003865912467356664] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.03155849933176751, 'vkb_3': 0.010614548307835557, 'hkb_4': 22.200000000000003, 'vkb_4': 3.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:17,922] Trial 63 finished with values: [0.005105571554011043, 0.004335329538954174] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.033303828583761845, 'vkb_3': 0.017595865315812878, 'hkb_4': 23.300000000000004, 'vkb_4': -1.6999999999999993}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:20,735] Trial 64 finished with values: [0.004005089296951785, 0.0041883531977060665] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.010614548307835557, 'vkb_3': 0.017595865315812878, 'hkb_4': 24.800000000000004, 'vkb_4': 1.3000000000000007}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:23,679] Trial 65 finished with values: [0.004379250453627508, 0.004954944248216201] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.0001425727958695791, 'vkb_3': 0.03155849933176751, 'hkb_4': 23.400000000000006, 'vkb_4': -5.399999999999999}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:26,563] Trial 66 finished with values: [0.0012747526212634832, 0.004438732962116106] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.003348085708119078, 'vkb_3': 0.017595865315812878, 'hkb_4': 20.6, 'vkb_4': -2.599999999999998}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:29,689] Trial 67 finished with values: [0.013599621508526637, 0.005415807648253862] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.019341194567807203, 'vkb_3': 0.026322511575784517, 'hkb_4': 12.5, 'vkb_4': -2.1999999999999993}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:32,589] Trial 68 finished with values: [0.008969097941266761, 0.0038563302845215945] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.005378560551852568, 'vkb_3': 0.008869219055841225, 'hkb_4': 25.1, 'vkb_4': 9.400000000000006}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:35,636] Trial 69 finished with values: [0.01571049609793385, 0.004972109165868694] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.03476401224401701, 'vkb_3': -0.013820061220085056, 'hkb_4': 26.300000000000004, 'vkb_4': 6.0}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:38,705] Trial 70 finished with values: [0.006769191324011386, 0.003840112724745026] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.017595865315812878, 'vkb_3': 0.0071238898038469, 'hkb_4': 18.6, 'vkb_4': 5.100000000000001}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:16:41,790] Trial 71 finished with values: [0.011102396083968733, 0.00538042165570889] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.036509341496011344, 'vkb_3': 0.033303828583761845, 'hkb_4': 20.1, 'vkb_4': -2.3999999999999986}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# ...
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:35,945] Trial 87 finished with values: [0.011302814639113807, 0.004001199351380417] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.003633231299858236, 'vkb_3': 0.0001425727958695791, 'hkb_4': 19.200000000000003, 'vkb_4': -4.899999999999999}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:39,171] Trial 88 finished with values: [0.018326508571962812, 0.0051475138894654104] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.012074731968090727, 'vkb_3': -0.008584073464102067, 'hkb_4': 26.700000000000003, 'vkb_4': -5.899999999999999}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:42,223] Trial 89 finished with values: [0.002554643971193791, 0.004066641213000974] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.020801378228062377, 'vkb_3': 0.010614548307835557, 'hkb_4': 17.400000000000006, 'vkb_4': 2.6000000000000014}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:45,842] Trial 90 finished with values: [0.00945454307079819, 0.0038585571950674035] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.019056048976068045, 'vkb_3': 0.005378560551852568, 'hkb_4': 21.400000000000006, 'vkb_4': -3.799999999999997}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:49,135] Trial 91 finished with values: [0.015116930993972358, 0.004111978688251552] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.03476401224401701, 'vkb_3': 0.019341194567807203, 'hkb_4': 26.300000000000004, 'vkb_4': 0.9000000000000021}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:17:53,110] Trial 92 finished with values: [0.005097919029698669, 0.0044650276907691] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.02981317007977318, 'vkb_3': 0.03853981633974483, 'hkb_4': 26.6, 'vkb_4': -6.599999999999998}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-10-06 00:17:57,165] Trial 93 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:00,829] Trial 94 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:04,544] Trial 95 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:08,351] Trial 96 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:12,389] Trial 97 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:17,612] Trial 98 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:21,619] Trial 99 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-10-06 00:18:25,750] Trial 100 pruned.

# %%
opt_trial.study.best_trials
# Out:
# [FrozenTrial(number=42, values=[0.0009002034228487802, 0.00408315227473025], datetime_start=datetime.datetime(2022, 10, 6, 0, 15, 14, 410485), datetime_complete=datetime.datetime(2022, 10, 6, 0, 15, 16, 931380), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.012074731968090727, 'vkb_3': 0.001887902047863911, 'hkb_4': 16.900000000000006, 'vkb_4': 4.100000000000001}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.7657919836063362}, system_attrs={}, intermediate_values={}, trial_id=42, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=47, values=[0.0034640928522502758, 0.004051467509281132], datetime_start=datetime.datetime(2022, 10, 6, 0, 15, 28, 59619), datetime_complete=datetime.datetime(2022, 10, 6, 0, 15, 30, 920187), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.0016027564561247529, 'vkb_3': 0.001887902047863911, 'hkb_4': 19.1, 'vkb_4': 1.5}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 1.4521917253451493}, system_attrs={}, intermediate_values={}, trial_id=47, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=51, values=[0.007498395943419271, 0.0037970844997331876], datetime_start=datetime.datetime(2022, 10, 6, 0, 15, 39, 60529), datetime_complete=datetime.datetime(2022, 10, 6, 0, 15, 41, 862094), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.012359877559829889, 'vkb_3': 0.008869219055841225, 'hkb_4': 20.0, 'vkb_4': 8.0}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 2.6996143785666944}, system_attrs={}, intermediate_values={}, trial_id=51, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=62, values=[0.006384506435776498, 0.003865912467356664], datetime_start=datetime.datetime(2022, 10, 6, 0, 16, 11, 482937), datetime_complete=datetime.datetime(2022, 10, 6, 0, 16, 14, 651905), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.03155849933176751, 'vkb_3': 0.010614548307835557, 'hkb_4': 22.200000000000003, 'vkb_4': 3.5}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 1.2476789820609735}, system_attrs={}, intermediate_values={}, trial_id=62, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=70, values=[0.006769191324011386, 0.003840112724745026], datetime_start=datetime.datetime(2022, 10, 6, 0, 16, 35, 636923), datetime_complete=datetime.datetime(2022, 10, 6, 0, 16, 38, 705057), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.017595865315812878, 'vkb_3': 0.0071238898038469, 'hkb_4': 18.6, 'vkb_4': 5.100000000000001}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 1.2762354728014949}, system_attrs={}, intermediate_values={}, trial_id=70, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=73, values=[0.0036953903037940327, 0.00392833698285615], datetime_start=datetime.datetime(2022, 10, 6, 0, 16, 45, 341926), datetime_complete=datetime.datetime(2022, 10, 6, 0, 16, 48, 775759), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.036794487087750495, 'vkb_3': 0.0071238898038469, 'hkb_4': 26.1, 'vkb_4': 0.6000000000000014}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.9536281520546777}, system_attrs={}, intermediate_values={}, trial_id=73, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=84, values=[0.014750459598336721, 0.0036825403814505996], datetime_start=datetime.datetime(2022, 10, 6, 0, 17, 23, 1682), datetime_complete=datetime.datetime(2022, 10, 6, 0, 17, 26, 148039), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.027782695236039694, 'vkb_3': 0.008869219055841225, 'hkb_4': 26.900000000000006, 'vkb_4': -3.6999999999999993}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 2.295070150633998}, system_attrs={}, intermediate_values={}, trial_id=84, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=89, values=[0.002554643971193791, 0.004066641213000974], datetime_start=datetime.datetime(2022, 10, 6, 0, 17, 39, 172571), datetime_complete=datetime.datetime(2022, 10, 6, 0, 17, 42, 223408), params={'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.020801378228062377, 'vkb_3': 0.010614548307835557, 'hkb_4': 17.400000000000006, 'vkb_4': 2.6000000000000014}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.9567623330365678}, system_attrs={}, intermediate_values={}, trial_id=89, state=TrialState.COMPLETE, value=None)]

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.scatter(centroid_ground, sigma_ground, color='green')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_78784/1036378160.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum(), t.user_attrs['wsum'])
# Out:
# -12.513775767317304 0.7657919836063362
# -11.17398059924427 1.4521917253451493
# -10.466587899163976 2.6996143785666944
# -10.609438633177287 1.2476789820609735
# -10.557627206528139 1.2762354728014949
# -11.1402082021418 0.9536281520546777
# -9.82063348138939 2.295070150633998
# -11.474780285977168 0.9567623330365678

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values, t.user_attrs['wsum'])
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# [0.0009002034228487802, 0.00408315227473025] 0.7657919836063362
# [0.0034640928522502758, 0.004051467509281132] 1.4521917253451493
# [0.007498395943419271, 0.0037970844997331876] 2.6996143785666944
# [0.006384506435776498, 0.003865912467356664] 1.2476789820609735
# [0.006769191324011386, 0.003840112724745026] 1.2762354728014949
# [0.0036953903037940327, 0.00392833698285615] 0.9536281520546777
# [0.014750459598336721, 0.0036825403814505996] 2.295070150633998
# [0.002554643971193791, 0.004066641213000974] 0.9567623330365678

# %% [raw]
# opt_trial._objective(opt_trial.study.best_trials[4])

# %% [raw]
# opt_trial.study.enqueue_trial(opt_trial.study.best_trials[4].params)

# %%
opt_trial.trials(100)
# Out:
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:19:13,069] Trial 101 finished with values: [0.0004515694786789889, 0.003769290162987598] and parameters: {'hkb_1': 12.538399999999996, 'vkb_1': -6.316300000000005, 'hkb_2': -2.1888000000000076, 'vkb_2': 5.851499999999994, 'hkb_3': 0.001887902047863911, 'vkb_3': 0.010614548307835557, 'hkb_4': 21.0, 'vkb_4': 1.1000000000000014}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System
ream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:20:04,920] Trial 114 finished with values: [0.010788072397683353, 0.004226528360060137] and parameters: {'hkb_1': -5.9998000000000005, 'vkb_1': -34.5818, 'hkb_2': 11.951399999999992, 'vkb_2': 13.847599999999993, 'hkb_3': -0.026037365984045366, 'vkb_3': 0.008869219055841225, 'hkb_4': 22.800000000000004, 'vkb_4': -3.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:20:09,237] Trial 115 finished with values: [0.009578192143299153, 0.004194156988528687] and parameters: {'hkb_1': 30.244799999999998, 'vkb_1': -28.372100000000003, 'hkb_2': 26.96069999999999, 'vkb_2': 20.865199999999987, 'hkb_3': -0.006838744212107742, 'vkb_3': 0.001887902047863911, 'hkb_4': 17.700000000000003, 'vkb_4': -3.5}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:20:13,555] Trial 116 finished with values: [0.0019803046206133897, 0.00387872240654411] and parameters: {'hkb_1': 1.6228999999999942, 'vkb_1': -21.901000000000003, 'hkb_2': 10.587199999999996, 'vkb_2': 48.998299999999986, 'hkb_3': -0.012074731968090727, 'vkb_3': 0.014105206811824214, 'hkb_4': 19.400000000000006, 'vkb_4': 1.3000000000000007}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:20:17,893] Trial 117 finished with values: [0.0022857077703551795, 0.003964281457397968] and parameters: {'hkb_1': 33.42869999999999, 'vkb_1': -41.763400000000004, 'hkb_2': -14.800000000000004, 'vkb_2': 33.7307, 'hkb_3': 0.001887902047863911, 'vkb_3': 0.008869219055841225, 'hkb_4': 19.200000000000003, 'vkb_4': 0.8000000000000007}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:20:22,420] Trial 118 finished with values: [0.004458685285950482, 0.00416040266385745] and parameters: {'hkb_1': 19.848, 'vkb_1': 48.541, 'hkb_2': -34.6192, 'vkb_2': -16.5835, 'hkb_3': 0.033303828583761845, 'vkb_3': 0.005378560551852568, 'hkb_4': 27.0, 'vkb_4': -2.3999999999999986}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory
Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:26:49,462] Trial 194 finished with values: [0.005883015102996529, 0.0031896715621045715] and parameters: {'hkb_1': 45.09519999999999, 'vkb_1': 37.4725, 'hkb_2': 45.09169999999999, 'vkb_2': 38.40499999999999, 'hkb_3': 0.02806784082777885, 'vkb_3': 0.0071238898038469, 'hkb_4': 23.400000000000006, 'vkb_4': 6.800000000000004}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:26:55,983] Trial 195 pruned.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:27:02,034] Trial 196 finished with values: [0.0063338729444602036, 0.0036321506621579468] and parameters: {'hkb_1': 36.61649999999999, 'vkb_1': 47.11959999999999, 'hkb_2': -32.874700000000004, 'vkb_2': -17.597, 'hkb_3': 0.012359877559829889, 'vkb_3': 0.0071238898038469, 'hkb_4': 17.5, 'vkb_4': -2.799999999999997}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:27:08,368] Trial 197 finished with values: [0.015923490090952137, 0.0035657333223333646] and parameters: {'hkb_1': 13.494799999999998, 'vkb_1': 25.8523, 'hkb_2': 29.534299999999988, 'vkb_2': -9.0899, 'hkb_3': -0.029528024488034023, 'vkb_3': 0.012359877559829889, 'hkb_4': 29.6, 'vkb_4': -0.8999999999999986}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:27:13,171] Trial 198 finished with values: [0.0015943321151765052, 0.00479905945322047] and parameters: {'hkb_1': -7.847500000000004, 'vkb_1': -28.726300000000002, 'hkb_2': -46.1773, 'vkb_2': -37.5906, 'hkb_3': 0.022831853071795867, 'vkb_3': 0.012359877559829889, 'hkb_4': 25.700000000000003, 'vkb_4': -1.0}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:27:19,216] Trial 199 finished with values: [0.01978605538616948, 0.004842261689477328] and parameters: {'hkb_1': -47.985, 'vkb_1': 28.196099999999987, 'hkb_2': -47.460300000000004, 'vkb_2': 42.95379999999999, 'hkb_3': -0.029528024488034023, 'vkb_3': -0.04, 'hkb_4': 20.400000000000006, 'vkb_4': 5.700000000000003}.
# /Users/skandel/code/oasys/AI-ML_Control_System/work_directory/jupyter/optuna_test/test_optuna_qnehvi.py:551: ExperimentalWarning: qnehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds, self._acq_func_kwargs)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Downstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/AI-ML_Control_System/tmp_work_dir_99368/Raytracing_HKB_bender_profile.dat written to disk.
# [I 2022-10-06 00:27:25,271] Trial 200 finished with values: [0.00549246338463722, 0.003285264097419939] and parameters: {'hkb_1': 36.16869999999999, 'vkb_1': 21.084599999999995, 'hkb_2': 40.92649999999999, 'vkb_2': 30.127199999999988, 'hkb_3': 0.005378560551852568, 'vkb_3': 0.008869219055841225, 'hkb_4': 27.6, 'vkb_4': 3.3000000000000043}.

# %%
opt_trial.study.best_trials
# Out:
# [FrozenTrial(number=101, values=[0.0004515694786789889, 0.003769290162987598], datetime_start=datetime.datetime(2022, 10, 6, 0, 19, 8, 877324), datetime_complete=datetime.datetime(2022, 10, 6, 0, 19, 13, 68821), params={'hkb_1': 12.538399999999996, 'vkb_1': -6.316300000000005, 'hkb_2': -2.1888000000000076, 'vkb_2': 5.851499999999994, 'hkb_3': 0.001887902047863911, 'vkb_3': 0.010614548307835557, 'hkb_4': 21.0, 'vkb_4': 1.1000000000000014}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.7118770365795792}, system_attrs={}, intermediate_values={}, trial_id=101, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=102, values=[0.0003711685439727295, 0.00413686547148189], datetime_start=datetime.datetime(2022, 10, 6, 0, 19, 13, 69755), datetime_complete=datetime.datetime(2022, 10, 6, 0, 19, 17, 631915), params={'hkb_1': -0.01190000000000424, 'vkb_1': 0.7939999999999969, 'hkb_2': -23.911500000000004, 'vkb_2': -11.129400000000004, 'hkb_3': 0.02981317007977318, 'vkb_3': 0.010614548307835557, 'hkb_4': 27.200000000000003, 'vkb_4': 0.5}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.7528023846861153}, system_attrs={}, intermediate_values={}, trial_id=102, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=120, values=[0.0011072445019276633, 0.003344697925029193], datetime_start=datetime.datetime(2022, 10, 6, 0, 20, 26, 767911), datetime_complete=datetime.datetime(2022, 10, 6, 0, 20, 31, 247951), params={'hkb_1': 45.22239999999999, 'vkb_1': 7.453799999999994, 'hkb_2': 5.251899999999992, 'vkb_2': 25.37039999999999, 'hkb_3': 0.015850536063818546, 'vkb_3': 0.008869219055841225, 'hkb_4': 22.5, 'vkb_4': 2.5}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.5899307061720709}, system_attrs={}, intermediate_values={}, trial_id=120, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=132, values=[0.0014260592355695312, 0.003186112488680642], datetime_start=datetime.datetime(2022, 10, 6, 0, 21, 19, 227549), datetime_complete=datetime.datetime(2022, 10, 6, 0, 21, 23, 7734), params={'hkb_1': 44.2512, 'vkb_1': 33.34939999999999, 'hkb_2': 37.66199999999999, 'vkb_2': 49.99999999999999, 'hkb_3': 0.0071238898038469, 'vkb_3': 0.010614548307835557, 'hkb_4': 23.5, 'vkb_4': 1.3000000000000007}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.44605554548269477}, system_attrs={}, intermediate_values={}, trial_id=132, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=136, values=[0.001306678099689073, 0.0032517308682415247], datetime_start=datetime.datetime(2022, 10, 6, 0, 21, 36, 452139), datetime_complete=datetime.datetime(2022, 10, 6, 0, 21, 40, 547653), params={'hkb_1': 26.44409999999999, 'vkb_1': 36.28259999999999, 'hkb_2': 20.7761, 'vkb_2': 45.65299999999999, 'hkb_3': 0.010614548307835557, 'vkb_3': 0.003633231299858236, 'hkb_4': 24.1, 'vkb_4': 3.700000000000003}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.44401811524653567}, system_attrs={}, intermediate_values={}, trial_id=136, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=173, values=[0.0007490803597354909, 0.0035819239900321508], datetime_start=datetime.datetime(2022, 10, 6, 0, 24, 48, 422251), datetime_complete=datetime.datetime(2022, 10, 6, 0, 24, 54, 438847), params={'hkb_1': 37.66159999999999, 'vkb_1': 46.53059999999999, 'hkb_2': -12.0533, 'vkb_2': 9.944199999999995, 'hkb_3': -0.006838744212107742, 'vkb_3': 0.014105206811824214, 'hkb_4': 17.300000000000004, 'vkb_4': -2.099999999999998}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.5084493397596945}, system_attrs={}, intermediate_values={}, trial_id=173, state=TrialState.COMPLETE, value=None),
#  FrozenTrial(number=174, values=[0.00039547738046901066, 0.0038767944665414676], datetime_start=datetime.datetime(2022, 10, 6, 0, 24, 54, 439795), datetime_complete=datetime.datetime(2022, 10, 6, 0, 24, 59, 438302), params={'hkb_1': 22.0013, 'vkb_1': -4.584900000000005, 'hkb_2': -11.249400000000001, 'vkb_2': 28.348699999999994, 'hkb_3': -0.00509341496011341, 'vkb_3': 0.015850536063818546, 'hkb_4': 18.400000000000006, 'vkb_4': -1.0999999999999979}, distributions={'hkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_1': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'vkb_2': FloatDistribution(high=49.99999999999999, log=False, low=-50.0, step=9.999999999999999e-05), 'hkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'vkb_3': FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296), 'hkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1), 'vkb_4': FloatDistribution(high=30.0, log=False, low=-30.0, step=0.1)}, user_attrs={'wsum': 0.6457168755091208}, system_attrs={}, intermediate_values={}, trial_id=174, state=TrialState.COMPLETE, value=None)]

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.ylabel('Sigma')
plt.xlabel('Centroid')
plt.scatter(centroid_ground, sigma_ground, color='green', label='Ground truth')
plt.legend(loc='best')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_78784/3803381583.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum())
# Out:
# -13.283649893758692
# -13.386671212502538
# -12.506259676592173
# -12.301794179118648
# -12.368835013688702
# -12.828519486384291
# -13.388163599861594

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values, t.user_attrs['wsum'])
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_HKB_bender_profile.dat written to disk.
# [0.0005032166403173247, 0.0033348498406202435] 0.46210379310353034
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_HKB_bender_profile.dat written to disk.
# [0.00088543513510587, 0.0032786008812913823] 0.5034168810278813
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_HKB_bender_profile.dat written to disk.
# [0.010630315963050542, 0.003059270661420493] 3.705829137256818
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_HKB_bender_profile.dat written to disk.
# [0.006454561890302154, 0.003110057585249784] 1.0439842737358527
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_9684/Downstream_HKB_bender_profile.dat written to disk.
# [0.0023685004923036006, 0.0031305551987271863] 0.4789051515236666

# %%
tnums = []
centroids = []
sigmas = []
wsums = []
for t in opt_trial.study.trials:
    if t.state in [optuna.trial.TrialState.PRUNED, optuna.trial.TrialState.FAIL]:
        continue
    tnums.append(t.number)
    centroids.append(t.values[0])
    sigmas.append(t.values[1])
    wsums.append(t.user_attrs['wsum'])
    
tnums = np.array(tnums)
centroids = np.array(centroids)
sigmas = np.array(sigmas)
wsums = np.array(wsums)

# %%
plt.scatter(tnums, centroids)
plt.yscale('log')

# %%
plt.scatter(tnums, sigmas)
plt.yscale('log')

# %%
plt.scatter(tnums, wsums)
plt.yscale('log')

# %% [markdown]
# ### Starting same procedure for different random structure

# %%
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path, bender=True)
beam, hist, dw = opt_common.get_beam_hist_dw(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.

# %%
centroid_ground, *_ = opt_common.get_centroid_distance(photon_beam=beam)
sigma_ground, *_ = opt_common.get_sigma(photon_beam=beam, random_seed=DEFAULT_RANDOM_SEED)
centroid_ground, sigma_ground
# Out:
# (0.0002743679164684214, 0.0027418680323870043)

# %%
initial_movement, focusing_system, beam, hist, dw = opt_common.get_random_init(focusing_system, motor_types=list(move_motors_ranges.keys()),
                                                                               init_range=list(move_motors_ranges.values()),
                                                                               xrange=[-0.04, 0.04],yrange=[-0.04,0.04], 
                                                                               integral_threshold=100, random_seed=DEFAULT_RANDOM_SEED,
                                                                               nbins=128)
plt.pcolormesh(hist.vv, hist.hh, hist.data_2D.T)
plt.colorbar()
plt.show()
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# Random initialization is ['hkb_1', 'vkb_1', 'hkb_2', 'vkb_2', 'hkb_3', 'vkb_3', 'hkb_4', 'vkb_4'] [16.16790236325798, 36.78749105299613, -25.983811087521993, -43.26970399957091, 0.03260968496996106, -0.022099401560925706, -24.81688703301112, -3.850480877123843]

# %%
hist.data_2D.sum()
# Out:
# 165.286295374562

# %%
focusing_system = movers.move_motors(focusing_system, list(move_motors_ranges.keys()), initial_absolute_positions + initial_movement, movement='absolute')

# %%
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.

# %% [markdown]
# #### Trying out joint optimization with 200 epochs first.

# %%
opt_trial = OptunaOptimizer(focusing_system, 
                            motor_types=list(move_motors_ranges.keys()), 
                            random_seed=DEFAULT_RANDOM_SEED, 
                            loss_parameters=['centroid', 'sigma'],
                            loss_min_value=5e-4,
                            use_gaussian_fit=False,
                            multi_objective_optimization=True,
                            camera_xrange=[-0.03, 0.03],
                            camera_yrange=[-0.03, 0.03],
                            camera_nbins=512)
#opt_trial.motor_ranges = centroid_ranges

# %%
opt_trial.reset()
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.

# %%
base_sampler = optuna.integration.BoTorchSampler()
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/3702032374.py:1: ExperimentalWarning: BoTorchSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   base_sampler = optuna.integration.BoTorchSampler()

# %%
opt_trial.set_optimizer_options(motor_ranges=list(move_motors_ranges.values()), integral_threshold=100, base_sampler=base_sampler, raise_prune_exception=True)
# Out:
# [I 2022-09-24 23:07:27,250] A new study created in memory with name: no-name-c0d6dfd4-2ec2-4615-8b72-5db0e0d6f530

# %%
opt_trial.trials(200)

# %% [raw]
# opt_trial.study.best_trials

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.scatter(centroid_ground, sigma_ground, color='green')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/1036378160.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum())
# Out:
# -11.156154330856026
# -13.456432286196033
# -12.05475814855554

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values)
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.005486368619161271, 0.002604106557345038]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0004869526040894996, 0.0029407561865906194]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0022224953122590855, 0.0026172439332410743]

# %% [markdown]
# #### Now trying out 100/100, first optimizing only the 3/4 motors.

# %%
opt_trial = OptunaOptimizer(focusing_system, 
                            motor_types=list(move_motors_ranges.keys()), 
                            random_seed=DEFAULT_RANDOM_SEED, 
                            loss_parameters=['centroid', 'sigma'],
                            loss_min_value=5e-4,
                            use_gaussian_fit=False,
                            multi_objective_optimization=True,
                            camera_xrange=[-0.03, 0.03],
                            camera_yrange=[-0.03, 0.03],
                            camera_nbins=512)
#opt_trial.motor_ranges = centroid_ranges

# %%
opt_trial.reset()

# %%
base_sampler = optuna.integration.BoTorchSampler()
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/3702032374.py:1: ExperimentalWarning: BoTorchSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   base_sampler = optuna.integration.BoTorchSampler()

# %%
opt_trial.set_optimizer_options(motor_ranges=list(move_motors_ranges.values()), integral_threshold=100, base_sampler=base_sampler, raise_prune_exception=True)
# Out:
# [I 2022-09-24 23:45:57,116] A new study created in memory with name: no-name-c71d277d-735b-43b5-bc5a-e09f0135f2f3

# %%
opt_trial.trials(100, trial_motor_types=['hkb_4', 'vkb_4', 'hkb_3', 'vkb_3'])
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/3699402942.py:85: ExperimentalWarning: PartialFixedSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   partial_sampler = optuna.samplers.PartialFixedSampler(fixed_params, self._base_sampler)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/trial/_trial.py:618: UserWarning: Fixed parameter 'hkb_3' with value 0.0 is out of range for distribution FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296).
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/trial/_trial.py:618: UserWarning: Fixed parameter 'vkb_3' with value 0.0 is out of range for distribution FloatDistribution(high=0.038539816339744834, log=False, low=-0.04, step=0.0017453292519943296).
#   warnings.warn(
# [I 2022-09-24 23:46:16,556] Trial 0 finished with values: [0.01583903616861451, 0.018104512046947734] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.0, 'vkb_3': 0.0, 'hkb_4': 0.0, 'vkb_4': 0.0}.
# [I 2022-09-24 23:46:19,115] Trial 1 pruned.
# [I 2022-09-24 23:46:19,813] Trial 2 pruned.
# [I 2022-09-24 23:46:20,242] Trial 3 pruned.
# [I 2022-09-24 23:46:20,763] Trial 4 pruned.
# [I 2022-09-24 23:46:22,513] Trial 5 pruned.
# [I 2022-09-24 23:46:24,592] Trial 6 finished with values: [0.02268753150502902, 0.005839777610899282] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.020801378228062377, 'vkb_3': -0.024292036732051034, 'hkb_4': 10.900000000000006, 'vkb_4': 15.300000000000004}.
# [I 2022-09-24 23:46:25,625] Trial 7 pruned.
# [I 2022-09-24 23:46:27,393] Trial 8 pruned.
# [I 2022-09-24 23:46:29,618] Trial 9 pruned.
# [I 2022-09-24 23:46:33,344] Trial 10 pruned.
# [I 2022-09-24 23:46:36,878] Trial 11 finished with values: [0.0221686361820432, 0.004410818608254206] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.017595865315812878, 'vkb_3': -0.031273353740028355, 'hkb_4': 22.5, 'vkb_4': 15.200000000000003}.
# [I 2022-09-24 23:46:39,466] Trial 12 pruned.
# [I 2022-09-24 23:46:41,113] Trial 13 pruned.
# [I 2022-09-24 23:46:42,680] Trial 14 pruned.
# [I 2022-09-24 23:46:44,222] Trial 15 finished with values: [0.016487048300162507, 0.006995388741191244] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.00509341496011341, 'vkb_3': 0.022831853071795867, 'hkb_4': 25.900000000000006, 'vkb_4': -12.399999999999999}.
# [I 2022-09-24 23:46:45,332] Trial 16 pruned.
# [I 2022-09-24 23:46:48,776] Trial 17 pruned.
# [I 2022-09-24 23:46:50,864] Trial 18 finished with values: [0.019048751041585817, 0.019274756161329752] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.00509341496011341, 'vkb_3': -0.003348085708119078, 'hkb_4': 3.0, 'vkb_4': 7.0}.
# [I 2022-09-24 23:46:51,642] Trial 19 pruned.
# [I 2022-09-24 23:46:52,857] Trial 20 pruned.
# [I 2022-09-24 23:46:55,402] Trial 21 pruned.
# [I 2022-09-24 23:46:57,331] Trial 22 finished with values: [0.012340501169605583, 0.0031295610562160616] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.005378560551852568, 'vkb_3': 0.022831853071795867, 'hkb_4': 25.800000000000004, 'vkb_4': -2.599999999999998}.
# [I 2022-09-24 23:46:59,501] Trial 23 pruned.
# [I 2022-09-24 23:47:00,346] Trial 24 pruned.
# [I 2022-09-24 23:47:00,880] Trial 25 pruned.
# [I 2022-09-24 23:47:01,591] Trial 26 pruned.
# [I 2022-09-24 23:47:02,027] Trial 27 pruned.
# [I 2022-09-24 23:47:02,643] Trial 28 pruned.
# [I 2022-09-24 23:47:05,127] Trial 29 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:47:06,529] Trial 30 pruned.
# [I 2022-09-24 23:47:09,249] Trial 31 pruned.
# [I 2022-09-24 23:47:10,151] Trial 32 finished with values: [0.016966523714637624, 0.005655155872317822] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.03476401224401701, 'vkb_3': 0.02806784082777885, 'hkb_4': 20.900000000000006, 'vkb_4': 21.5}.
# [I 2022-09-24 23:47:12,253] Trial 33 pruned.
# [I 2022-09-24 23:47:13,548] Trial 34 pruned.
# [I 2022-09-24 23:47:17,085] Trial 35 pruned.
# [I 2022-09-24 23:47:19,894] Trial 36 finished with values: [0.019131504916942568, 0.0036491858345958604] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.03155849933176751, 'vkb_3': 0.019341194567807203, 'hkb_4': 24.0, 'vkb_4': 16.300000000000004}.
# [I 2022-09-24 23:47:21,857] Trial 37 pruned.
# [I 2022-09-24 23:47:24,953] Trial 38 pruned.
# [I 2022-09-24 23:47:26,101] Trial 39 finished with values: [0.024772500867903308, 0.006550430222028052] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.031273353740028355, 'vkb_3': 0.003633231299858236, 'hkb_4': 9.300000000000004, 'vkb_4': -4.699999999999999}.
# [I 2022-09-24 23:47:27,351] Trial 40 pruned.
# [I 2022-09-24 23:47:28,519] Trial 41 pruned.
# [I 2022-09-24 23:47:30,481] Trial 42 pruned.
# [I 2022-09-24 23:47:31,364] Trial 43 pruned.
# [I 2022-09-24 23:47:33,886] Trial 44 pruned.
# [I 2022-09-24 23:47:34,964] Trial 45 finished with values: [0.026590731500937326, 0.006737751020455624] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.029528024488034023, 'vkb_3': 0.0071238898038469, 'hkb_4': 12.400000000000006, 'vkb_4': -10.5}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:47:38,253] Trial 46 finished with values: [0.008059961518923337, 0.00390899373581299] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.014105206811824214, 'vkb_3': 0.02981317007977318, 'hkb_4': 30.0, 'vkb_4': -1.5999999999999979}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:47:41,963] Trial 47 finished with values: [0.016232096971867494, 0.005526029330465888] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.017595865315812878, 'vkb_3': 0.036794487087750495, 'hkb_4': 21.900000000000006, 'vkb_4': -5.0}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:47:45,308] Trial 48 finished with values: [0.01296342665438505, 0.003392323969748349] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.015850536063818546, 'vkb_3': 0.015850536063818546, 'hkb_4': 30.0, 'vkb_4': -1.6999999999999993}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:02,608] Trial 74 finished with values: [0.018818148812392733, 0.0033362374969788905] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.03853981633974483, 'vkb_3': 0.033303828583761845, 'hkb_4': 25.300000000000004, 'vkb_4': 7.600000000000001}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:05,873] Trial 75 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:09,667] Trial 76 finished with values: [0.020988383273173074, 0.01087189533426874] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': 0.010614548307835557, 'vkb_3': 0.003633231299858236, 'hkb_4': 18.200000000000003, 'vkb_4': 15.300000000000004}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:13,158] Trial 77 finished with values: [0.016967950554490758, 0.003680502644260425] and parameters: {'hkb_1': 0.0, 'vkb_1': 0.0, 'hkb_2': 0.0, 'vkb_2': 0.0, 'hkb_3': -0.04, 'vkb_3': -0.027782695236039694, 'hkb_4': 26.400000000000006, 'vkb_4': 12.600000000000001}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
# ...
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:46,294] Trial 86 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:49:49,912] Trial 87 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:49:53,522] Trial 88 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:49:57,327] Trial 89 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:50:00,814] Trial 90 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:04,317] Trial 91 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:08,911] Trial 92 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:12,238] Trial 93 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:16,149] Trial 94 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:19,928] Trial 95 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:23,631] Trial 96 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:27,361] Trial 97 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:50:31,442] Trial 98 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# [I 2022-09-24 23:50:34,971] Trial 99 pruned.

# %% [raw]
# opt_trial.study.best_trials

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.scatter(centroid_ground, sigma_ground, color='green')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/1036378160.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum())
# Out:
# -12.500921200555123
# -11.59046146310224
# -12.202951722343718
# -10.831114209145172
# -10.1817035927129
# -10.071191311891333

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values)
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# [0.0009192106096857698, 0.004050455595952688]
# [0.002907722258893795, 0.0031825381826671006]
# [0.001572547504039353, 0.0031894928317296126]
# [0.006291015951024853, 0.003143301789281197]
# [0.012182620377186364, 0.0031074317724965965]
# [0.013822380404893767, 0.0030588229927730366]

# %%
opt_trial.trials(100)
# Out:
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:50:55,649] Trial 100 finished with values: [0.0009936544532963233, 0.0031679462990487684] and parameters: {'hkb_1': 4.726999999999997, 'vkb_1': -5.765600000000006, 'hkb_2': -3.2923000000000044, 'vkb_2': -12.805800000000005, 'hkb_3': -0.03476401224401701, 'vkb_3': 0.026322511575784517, 'hkb_4': 25.6, 'vkb_4': 5.0}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022
vi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:52:08,876] Trial 123 finished with values: [0.0028464325203280748, 0.003419379157311708] and parameters: {'hkb_1': 33.1232, 'vkb_1': -32.7699, 'hkb_2': 49.206199999999995, 'vkb_2': -31.5944, 'hkb_3': -0.036509341496011344, 'vkb_3': 0.033303828583761845, 'hkb_4': 21.400000000000006, 'vkb_4': 1.6000000000000014}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# ...
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:56:49,001] Trial 190 finished with values: [0.0062299121216287355, 0.002916294836764803] and parameters: {'hkb_1': 26.259899999999988, 'vkb_1': -11.5852, 'hkb_2': 10.409499999999994, 'vkb_2': 49.91659999999999, 'hkb_3': -0.03301868299202268, 'vkb_3': 0.022831853071795867, 'hkb_4': 24.1, 'vkb_4': 11.0}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:56:53,232] Trial 191 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:56:57,899] Trial 192 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:02,413] Trial 193 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:07,528] Trial 194 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:11,878] Trial 195 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:15,338] Trial 196 finished with values: [0.011512974851665431, 0.0033118340885304] and parameters: {'hkb_1': -23.072200000000002, 'vkb_1': -42.753, 'hkb_2': 38.79119999999999, 'vkb_2': -14.137700000000002, 'hkb_3': -0.012074731968090727, 'vkb_3': 0.03155849933176751, 'hkb_4': 20.0, 'vkb_4': 7.100000000000001}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:20,191] Trial 197 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:26,003] Trial 198 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:57:30,623] Trial 199 pruned.

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.scatter(centroid_ground, sigma_ground, color='green')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/1036378160.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum())
# Out:
# -13.191309300089534
# -13.547152866907552
# -13.672063833826936
# -12.938619397465729
# -12.844992703386975
# -11.681361578515792

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values)
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0005995903923481749, 0.0031133826197188305]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0003873074716109549, 0.0033766837613488903]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0003402460739362589, 0.0033923839367220312]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0008818780069398018, 0.0027253386814622433]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0008674661816080307, 0.003042551906575605]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.00323827628455978, 0.002609367362614611]

# %%
opt_trial.trials(100)
# Out:
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:59:38,735] Trial 200 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:59:43,655] Trial 201 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:59:48,139] Trial 202 finished with values: [0.007740432600677483, 0.003456160534186666] and parameters: {'hkb_1': -26.267300000000002, 'vkb_1': -35.3843, 'hkb_2': 47.75609999999999, 'vkb_2': -24.1456, 'hkb_3': 0.003633231299858236, 'vkb_3': 0.026322511575784517, 'hkb_4': 26.5, 'vkb_4': 0.20000000000000284}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-24 23:59:53,332] Trial 203 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-24 23:59:58,337] Trial 204 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:04,053] Trial 205 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:09,910] Trial 206 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:13,722] Trial 207 finished with values: [0.006994335411076786, 0.0028665454437004135] and parameters: {'hkb_1': -47.7324, 'vkb_1': -16.9865, 'hkb_2': 42.422, 'vkb_2': 49.59219999999999, 'hkb_3': -0.022546707480056705, 'vkb_3': 0.015850536063818546, 'hkb_4': 23.0, 'vkb_4': 1.7000000000000028}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:18,048] Trial 208 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-25 00:00:22,513] Trial 209 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:26,924] Trial 210 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:31,914] Trial 211 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:36,734] Trial 212 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-25 00:00:41,538] Trial 213 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:46,888] Trial 214 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:52,361] Trial 215 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:00:57,049] Trial 216 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:01,311] Trial 217 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:06,113] Trial 218 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-25 00:01:11,765] Trial 219 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-25 00:01:16,477] Trial 220 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:283: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/oasys/util/oasys_util.py:292: RuntimeWarning: invalid value encountered in true_divide
#   frequency = histogram/numpy.sum(histogram)
# [I 2022-09-25 00:01:20,912] Trial 221 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:25,659] Trial 222 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:30,276] Trial 223 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:35,609] Trial 224 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:39,768] Trial 225 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:01:44,438] Trial 226 pruned.
# ...
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:01,286] Trial 290 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:05,845] Trial 291 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:10,348] Trial 292 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:16,452] Trial 293 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:21,572] Trial 294 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:25,077] Trial 295 finished with values: [0.0010873708141237036, 0.0029258394043553053] and parameters: {'hkb_1': 12.397099999999995, 'vkb_1': -19.7693, 'hkb_2': 47.949499999999986, 'vkb_2': 45.1699, 'hkb_3': -0.026037365984045366, 'vkb_3': 0.03504915783575618, 'hkb_4': 25.700000000000003, 'vkb_4': -0.6999999999999993}.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:30,060] Trial 296 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:34,556] Trial 297 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:39,527] Trial 298 pruned.
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/integration/botorch.py:526: ExperimentalWarning: qehvi_candidates_func is experimental (supported from v2.4.0). The interface can change in the future.
#   candidates = self._candidates_func(params, values, con, bounds)
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-50, 50] and step=9.999999999999999e-05, but the range is not divisible by `step`. It will be replaced by [-50, 49.99999999999999].
#   warnings.warn(
# /Applications/Oasys1.3.app/Contents/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/optuna/distributions.py:668: UserWarning: The distribution is specified by [-0.04, 0.04] and step=0.0017453292519943296, but the range is not divisible by `step`. It will be replaced by [-0.04, 0.038539816339744834].
#   warnings.warn(
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [I 2022-09-25 00:07:44,346] Trial 299 pruned.

# %%
optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)
#plt.xscale('log')
#plt.yscale('log')
plt.scatter(centroid_ground, sigma_ground, color='green')
# Out:
# /var/folders/gn/ggsvq37x5sv5bb1j9chn8mmw0000gr/T/ipykernel_28594/1036378160.py:1: ExperimentalWarning: plot_pareto_front is experimental (supported from v2.8.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_pareto_front(opt_trial.study, include_dominated_trials=False)

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    print(np.log(vals).sum())
# Out:
# -13.191309300089534
# -13.547152866907552
# -13.672063833826936
# -12.938619397465729
# -12.844992703386975
# -11.681361578515792
# -11.902883377492948

# %%
for t in opt_trial.study.best_trials:
    params = t.params
    vals = t.values
    current_params = []
    for mot in opt_trial.motor_types:
        current_params.append(params[mot])
    opt_trial._loss_fn_this(current_params)
    print(t.values)
    plot_shadow_beam_spatial_distribution(opt_trial.beam_state.photon_beam, xrange=opt_trial._camera_xrange, yrange=opt_trial._camera_yrange)
# Out:
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0005995903923481749, 0.0031133826197188305]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0003873074716109549, 0.0033766837613488903]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0003402460739362589, 0.0033923839367220312]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0008818780069398018, 0.0027253386814622433]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0008674661816080307, 0.003042551906575605]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.00323827628455978, 0.002609367362614611]
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_VKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Upstream_HKB_bender_profile.dat written to disk.
# write_shadow_surface: File for SHADOW /Users/skandel/code/oasys/ML_Control_System/tmp_work_dir_57793/Downstream_HKB_bender_profile.dat written to disk.
# [0.0025095657201744605, 0.0026980180884307757]
