# %%
# %load_ext autoreload
# %autoreload 2

# %%
from beamline34IDC.simulation.source import  GaussianUndulatorSource, StorageRing
from beamline34IDC.util.common import plot_shadow_beam_spatial_distribution, plot_shadow_beam_divergence_distribution, save_source_beam
from beamline34IDC.util import clean_up

# %%
source = GaussianUndulatorSource()
source.initialize(n_rays=500000, random_seed=3245345, storage_ring=StorageRing.APS)
source.set_angular_acceptance_from_aperture(aperture=[0.05, 0.09], distance=50500)
source.set_energy(energy_range=[4999.0, 5001.0], photon_energy_distribution=GaussianUndulatorSource.PhotonEnergyDistributions.UNIFORM)

source_beam = source.get_source_beam()
# Out:
# Initializa geometrical source with limited divergence:  [5.940594059405941e-07, 1.3861386138613863e-06] rad
# Initializa geometrical source with limited divergence:  [9.900990099009902e-07, 1.7821782178217822e-06] rad
#  Generated        25000  rays out of       500000
#                   50000
#                   75000
#                  100000
#                  125000
#                  150000
#                  175000
#                  200000
#                  225000
#                  250000
#                  275000
#                  300000
#                  325000
#                  350000
#                  375000
#                  400000
#                  425000
#                  450000
#                  475000
#                  500000
#  Exit from SOURCE

# %%
save_source_beam(source_beam, "gaussian_undulator_source.dat")

# %%
_ = plot_shadow_beam_spatial_distribution(source_beam)

# %%
_ = plot_shadow_beam_divergence_distribution(source_beam)

# %%
clean_up()
