# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from beamline34IDC.simulation.primary_optics_system import PrimaryOpticsSystem, PreProcessorFiles
from beamline34IDC.util.common import save_shadow_beam, load_source_beam, plot_shadow_beam_spatial_distribution, plot_shadow_beam_divergence_distribution
from beamline34IDC.util import clean_up

# %%
# Source -------------------------
source_beam = load_source_beam("gaussian_undulator_source.dat")

# %%
# Primary Optics System -------------------------
primary_system = PrimaryOpticsSystem()

# %%
primary_system.initialize(source_beam, rewrite_preprocessor_files=PreProcessorFiles.YES_SOURCE_RANGE)
# Out:
# File written to disk: /gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/work_directory/tests/Pt.dat
#   Unit cell dimensions are 5.430700 5.430700 5.430700
#   Unit cell angles are 90.000000 90.000000 90.000000
#   Unit cell volume is 160.164932 A^3
#   Atoms at:
#      Z  fraction    X        Y        Z
#      14 1.000000 0.000000 0.000000 0.000000
#      14 1.000000 0.000000 0.500000 0.500000
#      14 1.000000 0.500000 0.000000 0.500000
#      14 1.000000 0.500000 0.500000 0.000000
#      14 1.000000 0.250000 0.250000 0.250000
#      14 1.000000 0.250000 0.750000 0.750000
#      14 1.000000 0.750000 0.250000 0.750000
#      14 1.000000 0.750000 0.750000 0.250000
#
# File written to disk: /gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/work_directory/tests/Si111.dat
# System initialized to central energy: 5000.000330960348

# %%
input_beam = primary_system.get_beam()
# Out:
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  MIRROR1: Warning: Empty element (no mirr.xx file)
#  Call to SCREEN
#  Exit from SCREEN
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  Exit from MIRROR
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
# ...

# %%
save_shadow_beam(input_beam, "primary_optics_system_beam.dat")
_ = plot_shadow_beam_spatial_distribution(input_beam, xrange=[-0.01, 0.01], yrange=[-0.01, 0.01])
# Out:
# fixing poolOE for Fortran
# fixed poolOE for Fortran
# fixing poolOE for Fortran
# fixed poolOE for Fortran

# %%
_= plot_shadow_beam_divergence_distribution(input_beam)

# %%
clean_up()
