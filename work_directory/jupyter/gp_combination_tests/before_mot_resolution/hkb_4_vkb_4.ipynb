# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from aps_ai.beamline34IDC.simulation.facade.focusing_optics_interface import Movement

from aps_ai.beamline34IDC.util.shadow.common import \
    plot_shadow_beam_spatial_distribution, get_shadow_beam_spatial_distribution,\
    load_shadow_beam, PreProcessorFiles, EmptyBeamException
import beamline34IDC.optimization.common as opt_common
import beamline34IDC.optimization.movers as movers
from aps_ai.beamline34IDC.util import clean_up
import matplotlib.pyplot as plt
import numpy as np
import scipy
import skopt
from tqdm import tqdm
import shutil
import glob
import dill

# %%
# %matplotlib inline

# %%
DEFAULT_RANDOM_SEED = 69392#np.random.randint(100000)
print(DEFAULT_RANDOM_SEED)
# Out:
# 69392

# %%
base_dir = '/gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/'
orig_work_dir = f'{base_dir}/work_directory'
temp_work_dir = f'{base_dir}/tmp_work_dir/{DEFAULT_RANDOM_SEED}'

# %%
if not os.path.isdir(temp_work_dir):
    os.mkdir(temp_work_dir)
    dat_files = glob.glob(f'{orig_work_dir}/*.dat')
    for df in dat_files:
        shutil.copy(df, temp_work_dir)

# %%
os.chdir(temp_work_dir)

# %%
input_beam_path = "primary_optics_system_beam.dat"

# %%
move_motors = ['vkb_4', 'hkb_4']

# %%
motors_str = move_motors[0] if len(move_motors) == 1 else '_'.join(move_motors)
fig_save_path = f'{orig_work_dir}/figures/{motors_str}/'
if not os.path.isdir(fig_save_path):
    os.mkdir(fig_save_path)

# %%
# Focusing Optics System -------------------------
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path)

# %%
centroid, out_beam, hist, dw = opt_common.get_centroid_distance(focusing_system=focusing_system, 
                                                                random_seed=DEFAULT_RANDOM_SEED)
print(centroid)
_ = plot_shadow_beam_spatial_distribution(out_beam)
# Out:
# 9.483920491356152e-05

# %%
initial_absolute_positions = np.array(movers.get_absolute_positions(focusing_system, move_motors))
print(initial_absolute_positions)
# Out:
# [0. 0.]

# %%
# Plotting the loss function for a grid of values

# %%
move_motors
# Out:
# ['vkb_4', 'hkb_4']

# %%
test_hkb_4 = np.linspace(-0.14, 0.14, 6)
test_vkb_4 = test_hkb_4
centroid_values = []
for v in tqdm(test_vkb_4):
    for h in (test_hkb_4):
        focusing_system = movers.move_motors(focusing_system, move_motors, [v, h], movement='relative')
        centroid_distance, out_beam, *_ = opt_common.get_centroid_distance(focusing_system=focusing_system, random_seed=DEFAULT_RANDOM_SEED)
        focusing_system = movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')
        centroid_values.append(centroid_distance)
# Out:
# 100%|██████████| 6/6 [01:50<00:00, 18.37s/it]

# %%
xvals = test_hkb_4 + initial_absolute_positions[1]
yvals = test_vkb_4 + initial_absolute_positions[0]

xx, yy = np.meshgrid(xvals, yvals)

#plt.plot(test_values + initial_absolute_positions[0], fwhm_values)
plt.pcolormesh(xx, yy, np.reshape(centroid_values, (6,6)), shading='gouraud')
plt.xlabel('Position h')
plt.ylabel('Position V')
plt.colorbar()
plt.show()

# %%
N_RUNS = 5

min_trans = -0.14
max_trans = 0.14

# %% [markdown]
# #### Trying out joint optimization with scipy

# %%
# %%time
initial_losses = []
initial_out_beams = []
absolute_movements = []

start_guesses = []
overall_successes = []
final_losses = []
final_out_beams = []
opt_results_all_scipy = []



for outer in tqdm(range(N_RUNS)):
    translations = np.random.uniform(min_trans, max_trans, size=2)
    test_absolute_movements = initial_absolute_positions + translations
    print("Initial motor positions are", test_absolute_movements)
    absolute_movements.append(test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    centroid, out_beam, hist, dw = opt_common.get_centroid_distance(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    initial_losses.append(centroid)
    initial_out_beams.append(out_beam)
    
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='centroid',
                                              default_opt_params={'maxfev':100,
                                                                  'fatol': 1e-4, 
                                                                  'disp': True})
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=False, guess_min=min_trans, guess_max=max_trans)
    focusing_system = opt_trial.focusing_system
    
    start_guesses.append(guesses)
    overall_successes.append(success)
    centroid, out_beam, *_ = opt_common.get_centroid_distance(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    final_losses.append(centroid)
    final_out_beams.append(out_beam)
    opt_results_all_scipy.append(opt_results)
    print(f'Test {outer} success {success} with final x {opt_results[-1].x} and final value {opt_results[-1].fun}')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Initial motor positions are [ 0.06435251 -0.02236745]
# Initial loss is 0.0679274364164133
# initial guess is [-0.06865277 -0.0366918 ]
# Optimization terminated successfully.
#          Current function value: 0.000048
#          Iterations: 28
#          Function evaluations: 54
#  20%|██        | 1/5 [03:04<12:19, 184.76s/it]
# Test 0 success True with final x [-0.06438303  0.02232923] and final value 4.769475400370923e-05
# Initial motor positions are [-0.05919984 -0.02763221]
# Initial loss is 0.0650008232577076
# initial guess is [ 0.00842609 -0.04583371]
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 37
#          Function evaluations: 72
#  40%|████      | 2/5 [07:08<10:57, 219.19s/it]
# Test 1 success True with final x [0.05911101 0.02756869] and final value 1.750218707442562e-05
# Initial motor positions are [ 0.02226906 -0.13370602]
# Initial loss is 0.13528881403667387
# initial guess is [ 0.11070024 -0.05094994]
# Warning: Maximum number of function evaluations has been exceeded.
# Initial loss is 0.13528881403667387
# Initial guess [ 0.06995231 -0.11930109] produces beam out of bounds. Trying another guess.
# initial guess is [ 0.09844595 -0.00230517]

# %%
with open('final_scipy_simul_beams/opt_results_all_scipy.pkl', 'wb') as f:
    dill.dump(opt_results_all_scipy, f)

# %%
initial_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in initial_out_beams]
initial_hists, initial_dws = zip(*initial_hists_dws)

# %%
initial_peaks = [dw.get_parameter('peak_intensity') for dw in initial_dws]
initial_h_fwhms = [dw.get_parameter('h_fwhm') for dw in initial_dws]
initial_v_fwhms = [dw.get_parameter('v_fwhm') for dw in initial_dws]

# %%
final_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams]
final_hists, final_dws = zip(*final_hists_dws)

# %%
final_peaks = [dw.get_parameter('peak_intensity') for dw in final_dws]
final_h_fwhms = [dw.get_parameter('h_fwhm') for dw in final_dws]
final_v_fwhms = [dw.get_parameter('v_fwhm') for dw in final_dws]

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes[0].plot(absolute_movements)
axes[0].set_ylabel('perturbation')

axes[1].plot(initial_losses)
axes[1].set_ylabel('v_centroid')

axes[2].plot(initial_peaks)
axes[2].set_ylabel('peak_intensity')

axes[3].plot(initial_h_fwhms)
axes[3].set_ylabel('h_fwhm')
axes[3].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[4].plot(initial_v_fwhms)
axes[4].set_ylabel('v_fwhm')
axes[4].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('Initial settings')
fig.savefig(f'{fig_save_path}/initial_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

axes[0].plot(final_losses)
axes[0].set_ylabel('Loss')

axes[1].plot(final_peaks)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(initial_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Initial beams')
fig.savefig(f'{fig_save_path}/initial_beams.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams.png', bbox_inches='tight')

# %%
absolute_movements
# Out:
# [array([ 0.08153128, -0.04539434]),
#  array([-0.09036973, -0.08380041]),
#  array([0.08939178, 0.09628829]),
#  array([-0.0108506 , -0.12566181]),
#  array([-0.03739743,  0.08965405])]

# %% [markdown]
# #### Reloading scipy optimization results

# %%
with open('final_scipy_simul_beams/opt_results_all_scipy.pkl', 'rb') as f:
    scipy_opt_results_all = dill.load(f)

# %%
nfevals = []
func_vals = []
for sr_per_guess in scipy_opt_results_all:
    nfevals.append(sum([sr['nfev'] for sr in sr_per_guess]))
    func_vals.append(sr_per_guess[-1]['fun'])

# %%
nfevals, func_vals
# Out:
# ([67, 79, 61, 84, 69],
#  [3.978828118594534e-05,
#   4.025923322579147e-05,
#   3.721591933015535e-05,
#   3.883230354795503e-05,
#   5.607357915637893e-05])

# %% [markdown]
# #### Test joint gaussian process optimization

# %%
focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         absolute_movements[0],
                                         movement='absolute')

# %%
??plot_shadow_beam_spatial_distribution
# Out:
# Signature:
# plot_shadow_beam_spatial_distribution(
#     shadow_beam,
#     nbins=201,
#     nolost=1,
#     title='X,Z',
#     xrange=None,
#     yrange=None,
# )
# Docstring: <no docstring>
# Source:
# def plot_shadow_beam_spatial_distribution(shadow_beam, nbins=201, nolost=1, title="X,Z", xrange=None, yrange=None):
#     return Shadow.ShadowTools.plotxy(shadow_beam._beam, 1, 3, nbins=nbins, nolost=nolost, title=title, xrange=xrange, yrange=yrange)
# File:      /gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/beamline34IDC/util/shadow/common.py
# Type:      function

# %%
test_out_beam = focusing_system.get_photon_beam(random_seed=DEFAULT_RANDOM_SEED)

# %%
hist, dw = get_shadow_beam_spatial_distribution(test_out_beam)

# %%
plt.pcolormesh(hist.hh, hist.vv, hist.data_2D)

# %%
callback_y = skopt.callbacks.DeltaYStopper(1e-5)
callback_x = skopt.callbacks.DeltaXStopper(1e-5)

# %%
# %%time

start_guesses_gp = []
overall_successes_gp = []
final_losses_gp = []
final_out_beams_gp = []
opt_results_all_gp = []

min_trans = -0.14
max_trans = 0.14

for outer, test_absolute_movements in tqdm(enumerate(absolute_movements)):
    print("Initial motor positions are", test_absolute_movements)
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='centroid', 
                                              loss_min_value=1e-3)
    bounds = []
    for m in test_absolute_movements:
        bounds_this = [min_trans - m - 0.02, max_trans - m + 0.02]
        bounds.append(bounds_this)
    print('Bounds are', bounds)
    opt_trial.set_gaussian_process_optimizer(bounds=bounds, callback=[callback_x, callback_y])
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=True, guess_min=0., guess_max=0.0)
    focusing_system = opt_trial.focusing_system
    
    start_guesses_gp.append(guesses)
    overall_successes_gp.append(success)
    centroid, out_beam, *_ = opt_common.get_centroid_distance(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    final_losses_gp.append(centroid)
    final_out_beams_gp.append(out_beam)
    opt_results_all_gp.append(opt_results)
    print(f'Test {outer} success {success} with final x {opt_results[-1].x} and final value {opt_results[-1].fun}')
# Out:
# 0it [00:00, ?it/s]
# Initial motor positions are [ 0.08153128 -0.04539434]
# Bounds are [[-0.24153128, 0.07846872000000002], [-0.11460566000000001, 0.20539434]]
# Initial loss is 0.09301584326050917
# motors ['vkb_4', 'hkb_4'] trans [-0.1455665   0.19607158] current loss 0.16056084880859348
# motors ['vkb_4', 'hkb_4'] trans [-0.17381685  0.13647631] current loss 0.12916050908958027
# motors ['vkb_4', 'hkb_4'] trans [0.03176717 0.12116359] current loss 0.1358240133596474
# motors ['vkb_4', 'hkb_4'] trans [-0.02052418  0.17910895] current loss 0.1460890731137437
# motors ['vkb_4', 'hkb_4'] trans [-0.11567933 -0.01122587] current loss 0.06591319147354147
# motors ['vkb_4', 'hkb_4'] trans [ 0.04024797 -0.0318242 ] current loss 0.14379334192282472
# motors ['vkb_4', 'hkb_4'] trans [-0.07992922  0.05980748] current loss 0.014541062821959966
# motors ['vkb_4', 'hkb_4'] trans [-0.00617525  0.12101847] current loss 0.10642874638896312
# motors ['vkb_4', 'hkb_4'] trans [-0.21285161  0.16996132] current loss 0.18025891763108856
# motors ['vkb_4', 'hkb_4'] trans [-0.0903585  -0.07237157] current loss 0.1178986562104235
# motors ['vkb_4', 'hkb_4'] trans [-0.11179945  0.05669411] current loss 0.032169981462474545
# motors ['vkb_4', 'hkb_4'] trans [-0.24153128 -0.11460566] current loss 0.22550750925744217
# motors ['vkb_4', 'hkb_4'] trans [-0.0616492   0.03089206] current loss 0.024675454536834725
# motors ['vkb_4', 'hkb_4'] trans [-0.0716164   0.06244734] current loss 0.019819821297650565
# motors ['vkb_4', 'hkb_4'] trans [-0.08123463  0.04662097] current loss 0.0013398640112799749
# motors ['vkb_4', 'hkb_4'] trans [-0.08066046  0.0426606 ] current loss 0.002835083977607556
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.07846872 -0.11460566] current loss 0.22579422087008158
# motors ['vkb_4', 'hkb_4'] trans [-0.07689994  0.04061464] current loss 0.0066893215033026815
# motors ['vkb_4', 'hkb_4'] trans [-0.24153128  0.01878447] current loss 0.16141771705479227
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.07846872 0.20539434] current loss 0.23666629497215072
# motors ['vkb_4', 'hkb_4'] trans [-0.04674211  0.02910318] current loss 0.03831429711376411
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.07846872 0.04362117] current loss 0.159543750504423
# motors ['vkb_4', 'hkb_4'] trans [-0.0830134   0.05224982] current loss 0.0070523229979147575
# motors ['vkb_4', 'hkb_4'] trans [-0.08981399  0.03281191] current loss 0.015018446814765529
# motors ['vkb_4', 'hkb_4'] trans [-0.0834685  0.0465676] current loss 0.0022556483769116437
# motors ['vkb_4', 'hkb_4'] trans [-0.08386693  0.0417784 ] current loss 0.004224675567097491
# motors ['vkb_4', 'hkb_4'] trans [-0.24153128  0.09273659] current loss 0.1660369670529809
# motors ['vkb_4', 'hkb_4'] trans [-0.08384499  0.04029893] current loss 0.005519005763292183
# motors ['vkb_4', 'hkb_4'] trans [-0.08380038  0.03976164] current loss 0.005995852794720685
# motors ['vkb_4', 'hkb_4'] trans [-0.08376183  0.04027606] current loss 0.005506232959082705
# motors ['vkb_4', 'hkb_4'] trans [-0.21060914 -0.04489851] current loss 0.15687988481143536
# motors ['vkb_4', 'hkb_4'] trans [-0.07198946 -0.11460566] current loss 0.15996925455143285
# motors ['vkb_4', 'hkb_4'] trans [-0.07601225  0.04700666] current loss 0.005880857633444015
# motors ['vkb_4', 'hkb_4'] trans [-0.08464213  0.04613573] current loss 0.0031713438597701254
# motors ['vkb_4', 'hkb_4'] trans [-0.08448634  0.04607866] current loss 0.0030045272130045445
# motors ['vkb_4', 'hkb_4'] trans [-0.0844614   0.04602965] current loss 0.0029687709523438396
# motors ['vkb_4', 'hkb_4'] trans [-0.08443041  0.04598599] current loss 0.0029289683988559657
# motors ['vkb_4', 'hkb_4'] trans [-0.08440319  0.04594769] current loss 0.002894148935148882
# motors ['vkb_4', 'hkb_4'] trans [-0.08970363  0.12085126] current loss 0.07568747372729592
# motors ['vkb_4', 'hkb_4'] trans [-0.08430193  0.0459051 ] current loss 0.0027879584397083232
# motors ['vkb_4', 'hkb_4'] trans [-0.08434118  0.04587486] current loss 0.0028195415007308882
# motors ['vkb_4', 'hkb_4'] trans [-0.08433522  0.04584754] current loss 0.0028088153062654857
# motors ['vkb_4', 'hkb_4'] trans [-0.08431296  0.04582253] current loss 0.0027824267429622574
# motors ['vkb_4', 'hkb_4'] trans [-0.08428766  0.04579917] current loss 0.0027534409469841927
# motors ['vkb_4', 'hkb_4'] trans [-0.04472487 -0.02176296] current loss 0.07641934630731366
# motors ['vkb_4', 'hkb_4'] trans [-0.08425121  0.04578915] current loss 0.0027162098232067352
# motors ['vkb_4', 'hkb_4'] trans [-0.15764238  0.03868903] current loss 0.07601302732192873
# motors ['vkb_4', 'hkb_4'] trans [-0.13802589  0.08959509] current loss 0.07140890015553096
# motors ['vkb_4', 'hkb_4'] trans [-0.14846183 -0.11460566] current loss 0.17299420188071477
# motors ['vkb_4', 'hkb_4'] trans [-0.0833709   0.04575046] current loss 0.0018360088186426039
# motors ['vkb_4', 'hkb_4'] trans [-0.00486562  0.05957484] current loss 0.07771514490926082
# motors ['vkb_4', 'hkb_4'] trans [-0.05390622  0.09738361] current loss 0.058711578345514895
# motors ['vkb_4', 'hkb_4'] trans [-0.08337154  0.04579079] current loss 0.0018463547454136435
# motors ['vkb_4', 'hkb_4'] trans [-0.08334531  0.04580841] current loss 0.0018245218119885794
# motors ['vkb_4', 'hkb_4'] trans [-0.08331275  0.04582493] current loss 0.001796879712187336
# motors ['vkb_4', 'hkb_4'] trans [-0.08327462  0.04584058] current loss 0.0017636146265805923
# motors ['vkb_4', 'hkb_4'] trans [-0.07778301  0.20539434] current loss 0.15250246138739737
# motors ['vkb_4', 'hkb_4'] trans [-0.07817705 -0.00056976] current loss 0.04598793997250495
# motors ['vkb_4', 'hkb_4'] trans [-0.08317031  0.04587071] current loss 0.0016701461446722327
# motors ['vkb_4', 'hkb_4'] trans [-0.12212338  0.02764895] current loss 0.04405373786417452
# motors ['vkb_4', 'hkb_4'] trans [-0.00573264  0.0098156 ] current loss 0.08346399507713181
# motors ['vkb_4', 'hkb_4'] trans [-0.08121968  0.04587969] current loss 0.0006685249676003145
# motors ['vkb_4', 'hkb_4'] trans [-0.08162924  0.04609948] current loss 0.0007679763998883028
# motors ['vkb_4', 'hkb_4'] trans [-0.00522117 -0.11460566] current loss 0.17686502488514394
# motors ['vkb_4', 'hkb_4'] trans [-0.08088865  0.04620117] current loss 0.0011308471745096734
# motors ['vkb_4', 'hkb_4'] trans [-0.09218279  0.08626568] current loss 0.04214496723157262
# motors ['vkb_4', 'hkb_4'] trans [-0.24075642  0.20366644] current loss 0.21535648962191004
# motors ['vkb_4', 'hkb_4'] trans [-0.08111374  0.04591456] current loss 0.0007628628154895904
# motors ['vkb_4', 'hkb_4'] trans [-0.07987034  0.04622708] current loss 0.0019619151007429516
# motors ['vkb_4', 'hkb_4'] trans [-0.07985566  0.04622772] current loss 0.0019750705363368913
# motors ['vkb_4', 'hkb_4'] trans [-0.07985898  0.04622612] current loss 0.001971582132151316
# Loss is 0.0006685249676003145 and min acceptable value is 0.001
# Solution is acceptable.
# 1it [04:10, 250.93s/it]
# Test 0 success True with final x [-0.08121968300116728, 0.04587968990492654] and final value 0.0006685249676003145
# Initial motor positions are [-0.09036973 -0.08380041]
# Bounds are [[-0.06963027000000002, 0.25036973], [-0.07619959000000001, 0.24380041]]
# Initial loss is 0.12281321578194175
# motors ['vkb_4', 'hkb_4'] trans [0.2207641 0.2280678] current loss 0.19342387765348162
# motors ['vkb_4', 'hkb_4'] trans [0.22413464 0.11588181] current loss 0.1369572112827265
# motors ['vkb_4', 'hkb_4'] trans [-0.00067076  0.18011379] current loss 0.13198871418262925
# motors ['vkb_4', 'hkb_4'] trans [ 0.0142928  -0.05984646] current loss 0.1621693601964743
# motors ['vkb_4', 'hkb_4'] trans [0.16964033 0.08284315] current loss 0.07900146386751235
# motors ['vkb_4', 'hkb_4'] trans [0.0811088  0.16440148] current loss 0.08090651662628918
# motors ['vkb_4', 'hkb_4'] trans [0.12730475 0.22787844] current loss 0.14775030012611853
# motors ['vkb_4', 'hkb_4'] trans [ 0.07885559 -0.00422406] current loss 0.08861067242969467
# motors ['vkb_4', 'hkb_4'] trans [0.02309922 0.01245425] current loss 0.0977047787665369
# motors ['vkb_4', 'hkb_4'] trans [0.19967111 0.16130693] current loss 0.13339701184043037
# motors ['vkb_4', 'hkb_4'] trans [0.15723111 0.07551881] current loss 0.06715832609807627
# motors ['vkb_4', 'hkb_4'] trans [0.12558456 0.06649521] current loss 0.03914065557238918
# motors ['vkb_4', 'hkb_4'] trans [0.08893105 0.08208016] current loss 0.0021564678496670026
# motors ['vkb_4', 'hkb_4'] trans [0.04610841 0.09111912] current loss 0.04459632036459663
# motors ['vkb_4', 'hkb_4'] trans [0.1000024  0.10320219] current loss 0.021741263662737806
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.25036973 -0.07619959] current loss 0.22579422087008155
# motors ['vkb_4', 'hkb_4'] trans [0.0870788  0.07606477] current loss 0.008336427495506993
# motors ['vkb_4', 'hkb_4'] trans [-0.06963027  0.06879022] current loss 0.15992096948102305
# motors ['vkb_4', 'hkb_4'] trans [0.08551756 0.07403853] current loss 0.010837506086031543
# motors ['vkb_4', 'hkb_4'] trans [-0.06963027  0.24380041] current loss 0.21638417163352694
# motors ['vkb_4', 'hkb_4'] trans [0.08727824 0.07746794] current loss 0.00697243017109835
# motors ['vkb_4', 'hkb_4'] trans [-0.06948262 -0.07293397] current loss 0.22320665244919297
# motors ['vkb_4', 'hkb_4'] trans [ 0.13584484 -0.07469576] current loss 0.1645180162562213
# motors ['vkb_4', 'hkb_4'] trans [0.08746271 0.07922463] current loss 0.00534532812551648
# motors ['vkb_4', 'hkb_4'] trans [0.10346331 0.08671946] current loss 0.0135887567632079
# motors ['vkb_4', 'hkb_4'] trans [0.08581913 0.08046277] current loss 0.005581449114374502
# motors ['vkb_4', 'hkb_4'] trans [0.08537711 0.08267771] current loss 0.0050840853998029446
# motors ['vkb_4', 'hkb_4'] trans [0.08488042 0.0845126 ] current loss 0.005526887711596231
# motors ['vkb_4', 'hkb_4'] trans [0.08462677 0.08594195] current loss 0.006138352916718752
# motors ['vkb_4', 'hkb_4'] trans [0.08527207 0.08663683] current loss 0.005843705436845457
# motors ['vkb_4', 'hkb_4'] trans [0.08644468 0.08608347] current loss 0.004541713757718876
# motors ['vkb_4', 'hkb_4'] trans [0.08731451 0.08591716] current loss 0.003716070541898912
# motors ['vkb_4', 'hkb_4'] trans [0.0881362  0.08587868] current loss 0.0030550329231262114
# motors ['vkb_4', 'hkb_4'] trans [0.18020909 0.02153833] current loss 0.10895627809934039
# motors ['vkb_4', 'hkb_4'] trans [0.10313532 0.03600099] current loss 0.04941255271669325
# motors ['vkb_4', 'hkb_4'] trans [0.04746113 0.0543189 ] current loss 0.05179950377891953
# motors ['vkb_4', 'hkb_4'] trans [0.08638999 0.08706267] current loss 0.005158910097308117
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.25036973 0.04321388] current loss 0.16457198471975856
# motors ['vkb_4', 'hkb_4'] trans [0.09285796 0.08382976] current loss 0.0025806161488817463
# motors ['vkb_4', 'hkb_4'] trans [0.09141754 0.08469175] current loss 0.0014750357718542328
# motors ['vkb_4', 'hkb_4'] trans [0.09162466 0.08513124] current loss 0.001931612948683681
# motors ['vkb_4', 'hkb_4'] trans [0.0494896  0.24380041] current loss 0.1574320006038661
# motors ['vkb_4', 'hkb_4'] trans [0.09139748 0.08469549] current loss 0.001461317506977985
# motors ['vkb_4', 'hkb_4'] trans [0.09141913 0.08483224] current loss 0.0015708733580343567
# motors ['vkb_4', 'hkb_4'] trans [0.0912461  0.08459126] current loss 0.001280127494442497
# motors ['vkb_4', 'hkb_4'] trans [0.09139962 0.08497291] current loss 0.0016576124908987157
# motors ['vkb_4', 'hkb_4'] trans [0.00076471 0.10106709] current loss 0.09083291915431267
# motors ['vkb_4', 'hkb_4'] trans [0.09116841 0.08432171] current loss 0.0010541547743085633
# motors ['vkb_4', 'hkb_4'] trans [0.09145733 0.08463989] current loss 0.0014742335423251424
# motors ['vkb_4', 'hkb_4'] trans [0.09126494 0.08414837] current loss 0.001055290716669516
# motors ['vkb_4', 'hkb_4'] trans [0.0914118  0.08395201] current loss 0.0011401477373118867
# motors ['vkb_4', 'hkb_4'] trans [0.09143621 0.08370403] current loss 0.001144728331722147
# motors ['vkb_4', 'hkb_4'] trans [0.13699342 0.13228396] current loss 0.0670981158081304
# motors ['vkb_4', 'hkb_4'] trans [0.09153893 0.0835212 ] current loss 0.001268636332103818
# motors ['vkb_4', 'hkb_4'] trans [ 0.07208816 -0.07619959] current loss 0.16072850501153974
# motors ['vkb_4', 'hkb_4'] trans [0.09140694 0.08339207] current loss 0.0011672565441337279
# motors ['vkb_4', 'hkb_4'] trans [-0.06963027  0.14627957] current loss 0.1709277111166577
# motors ['vkb_4', 'hkb_4'] trans [0.04393106 0.14364966] current loss 0.0754507049647028
# motors ['vkb_4', 'hkb_4'] trans [0.06621412 0.07685767] current loss 0.02500937361874879
# motors ['vkb_4', 'hkb_4'] trans [0.09173106 0.08339898] current loss 0.0014858576992544158
# motors ['vkb_4', 'hkb_4'] trans [0.09150847 0.08345537] current loss 0.0012505578314005398
# motors ['vkb_4', 'hkb_4'] trans [0.09117721 0.08342044] current loss 0.0009414797157779466
# motors ['vkb_4', 'hkb_4'] trans [0.09065056 0.08342398] current loss 0.000471863418683833
# motors ['vkb_4', 'hkb_4'] trans [ 0.18912606 -0.07619959] current loss 0.18755091054435907
# motors ['vkb_4', 'hkb_4'] trans [-0.01832466  0.03175985] current loss 0.12001915419981984
# motors ['vkb_4', 'hkb_4'] trans [0.11950621 0.10404385] current loss 0.03541390947338457
# motors ['vkb_4', 'hkb_4'] trans [0.09163327 0.0830487 ] current loss 0.0015130279280399896
# motors ['vkb_4', 'hkb_4'] trans [0.09146813 0.08320524] current loss 0.0012923801498928894
# motors ['vkb_4', 'hkb_4'] trans [0.1361343  0.01628921] current loss 0.08138541145363286
# motors ['vkb_4', 'hkb_4'] trans [0.09141719 0.0832331 ] current loss 0.0012333009983007917
# motors ['vkb_4', 'hkb_4'] trans [0.09121286 0.08327982] current loss 0.001028593903358408
# motors ['vkb_4', 'hkb_4'] trans [0.17003921 0.24380041] current loss 0.17254533399732364
# motors ['vkb_4', 'hkb_4'] trans [0.09112059 0.08327501] current loss 0.0009508453814406402
# motors ['vkb_4', 'hkb_4'] trans [0.11073795 0.14899786] current loss 0.06812746698534325
# motors ['vkb_4', 'hkb_4'] trans [0.091147   0.08322619] current loss 0.0009981137961394305
# motors ['vkb_4', 'hkb_4'] trans [0.09048269 0.08332256] current loss 0.00045334371634441915
# motors ['vkb_4', 'hkb_4'] trans [0.02503509 0.08207513] current loss 0.06500316044617954
# motors ['vkb_4', 'hkb_4'] trans [0.09043247 0.08325665] current loss 0.0004987912535258014
# motors ['vkb_4', 'hkb_4'] trans [0.09052836 0.24380041] current loss 0.15242824999629676
# motors ['vkb_4', 'hkb_4'] trans [0.06524677 0.11314774] current loss 0.03850216350662174
# motors ['vkb_4', 'hkb_4'] trans [0.09040633 0.08320361] current loss 0.0005455722771047664
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.25036973 0.17472822] current loss 0.18358017840915467
# motors ['vkb_4', 'hkb_4'] trans [0.09039175 0.08315478] current loss 0.0005907932817204891
# motors ['vkb_4', 'hkb_4'] trans [-0.02169467  0.24380041] current loss 0.1882300624440366
# motors ['vkb_4', 'hkb_4'] trans [0.07654618 0.07974943] current loss 0.014455037712708277
# motors ['vkb_4', 'hkb_4'] trans [0.07331955 0.0397839 ] current loss 0.04714195288660548
# motors ['vkb_4', 'hkb_4'] trans [0.09039492 0.08312558] current loss 0.0006202098400817271
# motors ['vkb_4', 'hkb_4'] trans [0.09039146 0.08309945] current loss 0.0006453489986359893
# motors ['vkb_4', 'hkb_4'] trans [0.11181498 0.0689657 ] current loss 0.02596615102291034
# motors ['vkb_4', 'hkb_4'] trans [0.09039151 0.08309669] current loss 0.0006479106336830764
# motors ['vkb_4', 'hkb_4'] trans [0.09039169 0.08308533] current loss 0.0006597074352821425
# motors ['vkb_4', 'hkb_4'] trans [0.09039266 0.0830782 ] current loss 0.0006663289158274685
# Loss is 0.00045334371634441915 and min acceptable value is 0.001
# Solution is acceptable.
# 2it [09:42, 298.19s/it]
# Test 1 success True with final x [0.09048268648054913, 0.08332255803413557] and final value 0.00045334371634441915
# Initial motor positions are [0.08939178 0.09628829]
# Bounds are [[-0.24939178, 0.07060822000000001], [-0.25628829000000003, 0.06371171000000002]]
# Initial loss is 0.130914176391395
# motors ['vkb_4', 'hkb_4'] trans [-0.09764693 -0.13035185] current loss 0.0349704114579879
# motors ['vkb_4', 'hkb_4'] trans [ 0.0389271  -0.12480747] current loss 0.13088723752931322
# motors ['vkb_4', 'hkb_4'] trans [-0.12534814  0.03684443] current loss 0.1371343262522726
# motors ['vkb_4', 'hkb_4'] trans [ 0.00136205 -0.05260172] current loss 0.10037001920701194
# motors ['vkb_4', 'hkb_4'] trans [ 0.056012   -0.13917248] current loss 0.15080582461925832
# motors ['vkb_4', 'hkb_4'] trans [-0.07644132 -0.11271128] current loss 0.020973809425992817
# motors ['vkb_4', 'hkb_4'] trans [-0.12218104  0.0370488 ] current loss 0.1364720867994087
# motors ['vkb_4', 'hkb_4'] trans [-0.19578355 -0.10228835] current loss 0.10607486309996751
# motors ['vkb_4', 'hkb_4'] trans [-0.22727342 -0.00486525] current loss 0.16485709200261078
# motors ['vkb_4', 'hkb_4'] trans [ 0.00090752 -0.21958693] current loss 0.15246213340063186
# motors ['vkb_4', 'hkb_4'] trans [-0.08917603 -0.09322027] current loss 0.003141178343647271
# motors ['vkb_4', 'hkb_4'] trans [-0.09429727 -0.06499092] current loss 0.031604213153523186
# motors ['vkb_4', 'hkb_4'] trans [-0.11024213 -0.09665941] current loss 0.02089283963891179
# motors ['vkb_4', 'hkb_4'] trans [-0.06860095 -0.0847127 ] current loss 0.02373304677440593
# motors ['vkb_4', 'hkb_4'] trans [-0.24939178 -0.25628829] current loss 0.22550750925744206
# motors ['vkb_4', 'hkb_4'] trans [-0.09057286 -0.09630866] current loss 0.0011242929292541637
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.07060822 0.06371171] current loss 0.23666722511763816
# motors ['vkb_4', 'hkb_4'] trans [-0.09040512 -0.0961703 ] current loss 0.0009686419010392922
# motors ['vkb_4', 'hkb_4'] trans [-0.10425676 -0.25628829] current loss 0.1603722503069766
# motors ['vkb_4', 'hkb_4'] trans [-0.09315295 -0.10510128] current loss 0.0095111321466866
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.07060822 -0.25628829] current loss 0.2257934284722094
# motors ['vkb_4', 'hkb_4'] trans [-0.24939178  0.06371171] current loss 0.21638417163352716
# motors ['vkb_4', 'hkb_4'] trans [-0.08971587 -0.09131893] current loss 0.005032615284479046
# motors ['vkb_4', 'hkb_4'] trans [-0.08904703 -0.09387516] current loss 0.0025088299139433435
# motors ['vkb_4', 'hkb_4'] trans [-0.08886028 -0.09390887] current loss 0.0025150903623836623
# motors ['vkb_4', 'hkb_4'] trans [-0.12970126 -0.1746192 ] current loss 0.08784050840279567
# motors ['vkb_4', 'hkb_4'] trans [-0.09032006 -0.02500355] current loss 0.0710913527849772
# motors ['vkb_4', 'hkb_4'] trans [-0.24939178 -0.1328534 ] current loss 0.16335428509735508
# motors ['vkb_4', 'hkb_4'] trans [-0.03739066  0.06371171] current loss 0.16145842449447242
# motors ['vkb_4', 'hkb_4'] trans [-0.08803021 -0.0951518 ] current loss 0.0018786364713476115
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.07060822 -0.0534556 ] current loss 0.16519672559722853
# motors ['vkb_4', 'hkb_4'] trans [-0.08786906 -0.09524009] current loss 0.001955428770985826
# motors ['vkb_4', 'hkb_4'] trans [-0.08747386 -0.09550451] current loss 0.0021778395290294153
# motors ['vkb_4', 'hkb_4'] trans [-0.08716499 -0.09587416] current loss 0.002367361437006799
# motors ['vkb_4', 'hkb_4'] trans [-0.05617459 -0.16065122] current loss 0.07226930378916636
# motors ['vkb_4', 'hkb_4'] trans [-0.09200877 -0.09696387] current loss 0.0026455227641043765
# motors ['vkb_4', 'hkb_4'] trans [-0.08716053 -0.09775592] current loss 0.0027153785570613524
# motors ['vkb_4', 'hkb_4'] trans [-0.08991757 -0.09679438] current loss 0.0006398639907881899
# motors ['vkb_4', 'hkb_4'] trans [-0.08996473 -0.09697076] current loss 0.0008026737102025698
# motors ['vkb_4', 'hkb_4'] trans [-0.09037552 -0.09697101] current loss 0.001110399292320486
# motors ['vkb_4', 'hkb_4'] trans [-0.09072064 -0.09689706] current loss 0.0013833263869346452
# motors ['vkb_4', 'hkb_4'] trans [-0.09077902 -0.09685635] current loss 0.0014211751274449133
# motors ['vkb_4', 'hkb_4'] trans [-0.09076709 -0.09683101] current loss 0.0014008447760078477
# motors ['vkb_4', 'hkb_4'] trans [-0.1458457  -0.06472058] current loss 0.06436280404120172
# motors ['vkb_4', 'hkb_4'] trans [-0.24939178 -0.06447505] current loss 0.16234202103911324
# motors ['vkb_4', 'hkb_4'] trans [-0.09057527 -0.09687405] current loss 0.0012416170859480423
# motors ['vkb_4', 'hkb_4'] trans [-0.09066464 -0.09683042] current loss 0.0013067812022576478
# motors ['vkb_4', 'hkb_4'] trans [-0.0314693  -0.10629892] current loss 0.05860991670544616
# motors ['vkb_4', 'hkb_4'] trans [-0.09061175 -0.09684196] current loss 0.001261932632305419
# motors ['vkb_4', 'hkb_4'] trans [-0.09066893 -0.09680616] current loss 0.0013018767806132528
# motors ['vkb_4', 'hkb_4'] trans [-0.09069968 -0.09677433] current loss 0.0013194713161679772
# motors ['vkb_4', 'hkb_4'] trans [-0.09070602 -0.09675099] current loss 0.00131886710781566
# motors ['vkb_4', 'hkb_4'] trans [-0.17261496 -0.25628829] current loss 0.17986817419024106
# motors ['vkb_4', 'hkb_4'] trans [-0.09068325 -0.09674638] current loss 0.0012960907483616307
# motors ['vkb_4', 'hkb_4'] trans [-0.14582899 -0.12024315] current loss 0.06098938637939826
# motors ['vkb_4', 'hkb_4'] trans [-0.09053536 -0.096788  ] current loss 0.0011694728889285588
# motors ['vkb_4', 'hkb_4'] trans [-0.09059203 -0.09675523] current loss 0.0012121668938643675
# motors ['vkb_4', 'hkb_4'] trans [-0.09063447 -0.09671848] current loss 0.0012412242348679861
# motors ['vkb_4', 'hkb_4'] trans [-0.04453865 -0.04052833] current loss 0.0713841534058787
# motors ['vkb_4', 'hkb_4'] trans [-0.04560591 -0.25628829] current loss 0.16554729771984955
# motors ['vkb_4', 'hkb_4'] trans [-0.09059713 -0.09675255] current loss 0.001216326702672657
# motors ['vkb_4', 'hkb_4'] trans [-0.11852937 -0.05324047] current loss 0.05180535343931419
# motors ['vkb_4', 'hkb_4'] trans [-0.0905041  -0.09680121] current loss 0.0011456531743433897
# motors ['vkb_4', 'hkb_4'] trans [-0.17961307  0.06371171] current loss 0.17632068163553538
# motors ['vkb_4', 'hkb_4'] trans [-0.09052382 -0.09678868] current loss 0.001159382052770647
# motors ['vkb_4', 'hkb_4'] trans [-0.08975403 -0.17276128] current loss 0.07631728213096442
# motors ['vkb_4', 'hkb_4'] trans [-0.09053222 -0.09679206] current loss 0.0011682355993008669
# motors ['vkb_4', 'hkb_4'] trans [-0.05585965 -0.1100071 ] current loss 0.03612967126400502
# motors ['vkb_4', 'hkb_4'] trans [-0.09054493 -0.09677723] current loss 0.0011748789785077643
# motors ['vkb_4', 'hkb_4'] trans [-0.09060179 -0.09673801] current loss 0.0012158502728504407
# motors ['vkb_4', 'hkb_4'] trans [-0.09064073 -0.09670674] current loss 0.001243890152200385
# motors ['vkb_4', 'hkb_4'] trans [-0.1284958  -0.09057357] current loss 0.03929235984711477
# motors ['vkb_4', 'hkb_4'] trans [-0.09010796 -0.09694996] current loss 0.0008847214912969608
# motors ['vkb_4', 'hkb_4'] trans [-0.09003169 -0.09702229] current loss 0.000884326236526731
# motors ['vkb_4', 'hkb_4'] trans [-0.08995974 -0.09709152] current loss 0.0008962464238521284
# motors ['vkb_4', 'hkb_4'] trans [-0.08989497 -0.09715188] current loss 0.0009138541631800397
# motors ['vkb_4', 'hkb_4'] trans [-0.08983745 -0.09720678] current loss 0.0009375577966605944
# motors ['vkb_4', 'hkb_4'] trans [-0.17976123 -0.16349854] current loss 0.11219009219043474
# motors ['vkb_4', 'hkb_4'] trans [-0.0897854  -0.09725391] current loss 0.0009614141208195893
# motors ['vkb_4', 'hkb_4'] trans [-0.01067446 -0.14739976] current loss 0.09356448485376039
# motors ['vkb_4', 'hkb_4'] trans [-0.08943183 -0.09759036] current loss 0.0012404872474809662
# motors ['vkb_4', 'hkb_4'] trans [-0.08946779 -0.09734367] current loss 0.0009935552377789553
# motors ['vkb_4', 'hkb_4'] trans [-0.08947597 -0.09730748] current loss 0.0009569076890182557
# motors ['vkb_4', 'hkb_4'] trans [-0.0894797 -0.0972905] current loss 0.0009399002512212235
# motors ['vkb_4', 'hkb_4'] trans [-0.08948246 -0.0972797 ] current loss 0.0009296398606726383
# motors ['vkb_4', 'hkb_4'] trans [-0.08948382 -0.09727562] current loss 0.0009255055105549628
# Loss is 0.0006398639907881899 and min acceptable value is 0.001
# Solution is acceptable.
# 3it [14:48, 301.77s/it]
# Test 2 success True with final x [-0.08991756775251339, -0.09679438395448675] and final value 0.0006398639907881899
# Initial motor positions are [-0.0108506  -0.12566181]
# Bounds are [[-0.14914940000000002, 0.1708506], [-0.034338190000000005, 0.28566181]]
# Initial loss is 0.12594808784728376
# motors ['vkb_4', 'hkb_4'] trans [-0.03154718  0.08661614] current loss 0.057381320117099656
# motors ['vkb_4', 'hkb_4'] trans [0.12242756 0.09694267] current loss 0.11476241377876267
# motors ['vkb_4', 'hkb_4'] trans [0.01462404 0.11877692] current loss 0.007849064788974139
# motors ['vkb_4', 'hkb_4'] trans [-0.12324595 -0.00908171] current loss 0.1895092932226157
# motors ['vkb_4', 'hkb_4'] trans [-0.05996901  0.02537629] current loss 0.12240239846599953
# motors ['vkb_4', 'hkb_4'] trans [-0.09232777  0.01247687] current loss 0.15268757792928425
# motors ['vkb_4', 'hkb_4'] trans [-0.06462316  0.04239929] current loss 0.11199597452117065
# motors ['vkb_4', 'hkb_4'] trans [-0.00602002  0.03799307] current loss 0.08912777746678778
# motors ['vkb_4', 'hkb_4'] trans [-0.11719288  0.01531024] current loss 0.1684544246687025
# motors ['vkb_4', 'hkb_4'] trans [0.12869002 0.13396671] current loss 0.1176190011364555
# motors ['vkb_4', 'hkb_4'] trans [-0.02693587  0.28566181] current loss 0.1566992080014247
# motors ['vkb_4', 'hkb_4'] trans [0.00778197 0.16185395] current loss 0.03622974819421397
# motors ['vkb_4', 'hkb_4'] trans [0.03819673 0.12329788] current loss 0.027352861829623005
# motors ['vkb_4', 'hkb_4'] trans [-0.00405234  0.12809474] current loss 0.015186537859476674
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.1708506  0.28566181] current loss 0.2366662949721498
# motors ['vkb_4', 'hkb_4'] trans [-0.1491494   0.23943421] current loss 0.1954395535207726
# motors ['vkb_4', 'hkb_4'] trans [0.01179837 0.10694637] current loss 0.018695890145124603
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.1708506  -0.03433819] current loss 0.22579422087008108
# motors ['vkb_4', 'hkb_4'] trans [-0.05166612  0.15369545] current loss 0.06817508330920388
# motors ['vkb_4', 'hkb_4'] trans [0.00927069 0.12462196] current loss 0.0018073309283333627
# motors ['vkb_4', 'hkb_4'] trans [ 0.04427373 -0.03412938] current loss 0.16294019804030904
# motors ['vkb_4', 'hkb_4'] trans [0.00944331 0.12526318] current loss 0.0013891743299269035
# motors ['vkb_4', 'hkb_4'] trans [-0.14894485  0.11257494] current loss 0.15948165341561557
# motors ['vkb_4', 'hkb_4'] trans [0.00880039 0.12608347] current loss 0.00205805940978952
# motors ['vkb_4', 'hkb_4'] trans [0.00777064 0.12735758] current loss 0.003508430697431575
# motors ['vkb_4', 'hkb_4'] trans [0.06524288 0.22285263] current loss 0.1110074961506112
# motors ['vkb_4', 'hkb_4'] trans [0.04209322 0.08228065] current loss 0.05332716522345425
# motors ['vkb_4', 'hkb_4'] trans [0.04398075 0.14916422] current loss 0.040521228853636966
# motors ['vkb_4', 'hkb_4'] trans [0.00701153 0.12655335] current loss 0.003919605416527882
# motors ['vkb_4', 'hkb_4'] trans [0.00759453 0.12707744] current loss 0.003538988040427193
# motors ['vkb_4', 'hkb_4'] trans [0.0086157  0.12772384] current loss 0.003044404368113201
# motors ['vkb_4', 'hkb_4'] trans [0.01526564 0.13283755] current loss 0.00852926302750933
# motors ['vkb_4', 'hkb_4'] trans [0.00846119 0.12719556] current loss 0.002830834341688835
# motors ['vkb_4', 'hkb_4'] trans [0.05031773 0.28539707] current loss 0.15716736353256358
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.1708506 0.189157 ] current loss 0.17170150620997782
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.17022346 0.06925429] current loss 0.16898063118220302
# motors ['vkb_4', 'hkb_4'] trans [0.00760542 0.12691615] current loss 0.003464873063844115
# motors ['vkb_4', 'hkb_4'] trans [0.00860041 0.1272451 ] current loss 0.002745000277559992
# motors ['vkb_4', 'hkb_4'] trans [0.00819859 0.12307042] current loss 0.003633705506022265
# motors ['vkb_4', 'hkb_4'] trans [-0.01746511  0.19831224] current loss 0.07773087467764495
# motors ['vkb_4', 'hkb_4'] trans [0.00939955 0.12494073] current loss 0.0015394377698530067
# motors ['vkb_4', 'hkb_4'] trans [0.00935881 0.12458581] current loss 0.001754743453287214
# motors ['vkb_4', 'hkb_4'] trans [0.04627864 0.18162377] current loss 0.06606443805276857
# motors ['vkb_4', 'hkb_4'] trans [0.00928327 0.12437451] current loss 0.001942399063191394
# motors ['vkb_4', 'hkb_4'] trans [0.00917883 0.12406676] current loss 0.0022263365487198666
# motors ['vkb_4', 'hkb_4'] trans [0.0172136  0.12604767] current loss 0.006505468406720663
# motors ['vkb_4', 'hkb_4'] trans [0.07583819 0.12341876] current loss 0.0648247468765805
# motors ['vkb_4', 'hkb_4'] trans [0.0091829  0.12397499] current loss 0.00228754324449842
# motors ['vkb_4', 'hkb_4'] trans [-0.07231795  0.10983232] current loss 0.08424771563518152
# motors ['vkb_4', 'hkb_4'] trans [-0.02957929  0.12735974] current loss 0.04022112827595313
# motors ['vkb_4', 'hkb_4'] trans [0.01163434 0.12575294] current loss 0.0008766819408083077
# motors ['vkb_4', 'hkb_4'] trans [0.08162642 0.0447267 ] current loss 0.10724323540720426
# motors ['vkb_4', 'hkb_4'] trans [0.01000383 0.12471145] current loss 0.001182224943477817
# motors ['vkb_4', 'hkb_4'] trans [-0.0278215  -0.03433819] current loss 0.16423497978516655
# motors ['vkb_4', 'hkb_4'] trans [0.01000816 0.12458531] current loss 0.0012776118890040556
# motors ['vkb_4', 'hkb_4'] trans [-0.0168459   0.15434472] current loss 0.0397259611728386
# motors ['vkb_4', 'hkb_4'] trans [0.011668   0.12573394] current loss 0.0009058460663613002
# motors ['vkb_4', 'hkb_4'] trans [0.01036189 0.12485847] current loss 0.0008543860137524155
# motors ['vkb_4', 'hkb_4'] trans [0.01041936 0.12477093] current loss 0.0009062442028922968
# motors ['vkb_4', 'hkb_4'] trans [-0.09194488  0.28566181] current loss 0.182943176512583
# motors ['vkb_4', 'hkb_4'] trans [0.01164163 0.12565607] current loss 0.0008721391076005863
# motors ['vkb_4', 'hkb_4'] trans [0.01060678 0.12473752] current loss 0.0008795295238590266
# motors ['vkb_4', 'hkb_4'] trans [0.01161057 0.12561452] current loss 0.0008399111804723688
# motors ['vkb_4', 'hkb_4'] trans [0.01158718 0.1255996 ] current loss 0.0008161723547129912
# motors ['vkb_4', 'hkb_4'] trans [0.01157361 0.12558479] current loss 0.0008030921974919649
# motors ['vkb_4', 'hkb_4'] trans [0.01155786 0.1255862 ] current loss 0.000787052835652181
# motors ['vkb_4', 'hkb_4'] trans [0.01155778 0.12557846] current loss 0.0007873860770458341
# Loss is 0.000787052835652181 and min acceptable value is 0.001
# Solution is acceptable.
# 4it [18:44, 275.95s/it]
# Test 3 success True with final x [0.011557855303340608, 0.12558619738267301] and final value 0.000787052835652181
# Initial motor positions are [-0.03739743  0.08965405]
# Bounds are [[-0.12260257000000001, 0.19739743], [-0.24965405, 0.07034595000000002]]
# Initial loss is 0.09681140438651067
# motors ['vkb_4', 'hkb_4'] trans [ 0.14952733 -0.18552837] current loss 0.147156458384063
# motors ['vkb_4', 'hkb_4'] trans [ 0.14226103 -0.17159688] current loss 0.13269023887231587
# motors ['vkb_4', 'hkb_4'] trans [-0.04813269 -0.23968374] current loss 0.17220567759113387
# motors ['vkb_4', 'hkb_4'] trans [-0.03463233 -0.07782272] current loss 0.07263178673987636
# motors ['vkb_4', 'hkb_4'] trans [ 0.01092992 -0.14784803] current loss 0.06376022081253119
# motors ['vkb_4', 'hkb_4'] trans [0.03496975 0.02133161] current loss 0.11065425568710494
# motors ['vkb_4', 'hkb_4'] trans [ 0.13745993 -0.02072638] current loss 0.12107517094790646
# motors ['vkb_4', 'hkb_4'] trans [ 0.06933207 -0.18174745] current loss 0.09727736937233025
# motors ['vkb_4', 'hkb_4'] trans [ 0.11305421 -0.22473865] current loss 0.15446853590129223
# motors ['vkb_4', 'hkb_4'] trans [ 0.08287172 -0.19224122] current loss 0.11199794503661001
# motors ['vkb_4', 'hkb_4'] trans [ 0.02267032 -0.11468756] current loss 0.029028438770993144
# motors ['vkb_4', 'hkb_4'] trans [ 0.04208506 -0.09549699] current loss 0.007513749551565538
# motors ['vkb_4', 'hkb_4'] trans [-0.12260257  0.07034595] current loss 0.21638545740436796
# motors ['vkb_4', 'hkb_4'] trans [ 0.04756378 -0.06652155] current loss 0.025285329295383137
# motors ['vkb_4', 'hkb_4'] trans [ 0.07069278 -0.10020942] current loss 0.034829130243978434
# motors ['vkb_4', 'hkb_4'] trans [ 0.03035941 -0.08527663] current loss 0.008319154041338555
# motors ['vkb_4', 'hkb_4'] trans [ 0.02847409 -0.08413474] current loss 0.010533554534070585
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [0.19739743 0.07034595] current loss 0.23666629497215083
# motors ['vkb_4', 'hkb_4'] trans [-0.12260257 -0.1463106 ] current loss 0.1689898724789169
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.19739743 -0.08658958] current loss 0.1595651093323635
# motors ['vkb_4', 'hkb_4'] trans [ 0.03117769 -0.08497826] current loss 0.00780753250637638
# motors ['vkb_4', 'hkb_4'] trans [-0.12228698 -0.04475268] current loss 0.16520260630846512
# motors ['vkb_4', 'hkb_4'] trans [ 0.01596702 -0.0624559 ] current loss 0.03453405959624811
# motors ['vkb_4', 'hkb_4'] trans [0.08110125 0.07034595] current loss 0.1589258442587463
# motors ['vkb_4', 'hkb_4'] trans [ 0.03987421 -0.08888319] current loss 0.0026992881036023617
# motors ['vkb_4', 'hkb_4'] trans [ 0.03980981 -0.09004041] current loss 0.002524111004885975
# motors ['vkb_4', 'hkb_4'] trans [ 0.04127487 -0.08940551] current loss 0.003994215779313011
# motors ['vkb_4', 'hkb_4'] trans [ 0.04238463 -0.08789621] current loss 0.005420013329264092
# motors ['vkb_4', 'hkb_4'] trans [ 0.0406261 -0.0895085] current loss 0.0033339066908251963
# motors ['vkb_4', 'hkb_4'] trans [ 0.04112058 -0.08877623] current loss 0.003942637471396091
# motors ['vkb_4', 'hkb_4'] trans [-0.02735655  0.07034595] current loss 0.16500191883337958
# motors ['vkb_4', 'hkb_4'] trans [ 0.04140416 -0.08840369] current loss 0.004315799404316139
# motors ['vkb_4', 'hkb_4'] trans [ 0.10118095 -0.08348528] current loss 0.06389438704201114
# motors ['vkb_4', 'hkb_4'] trans [ 0.04114655 -0.08847006] current loss 0.004050942694347981
# motors ['vkb_4', 'hkb_4'] trans [ 0.02680729 -0.24965405] current loss 0.16002729525369203
# motors ['vkb_4', 'hkb_4'] trans [ 0.03888355 -0.09052603] current loss 0.0017687369586150683
# motors ['vkb_4', 'hkb_4'] trans [-0.00407524 -0.09817684] current loss 0.042077267822003106
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.19739743 -0.24965405] current loss 0.2257933601811353
# motors ['vkb_4', 'hkb_4'] trans [ 0.03865846 -0.09125127] current loss 0.00204042125537402
# motors ['vkb_4', 'hkb_4'] trans [ 0.0382125  -0.09179573] current loss 0.0022630376986756376
# motors ['vkb_4', 'hkb_4'] trans [-0.12260257 -0.24965405] current loss 0.2255075092574422
# motors ['vkb_4', 'hkb_4'] trans [ 0.03791061 -0.09215295] current loss 0.002506804580620551
# motors ['vkb_4', 'hkb_4'] trans [ 0.03768249 -0.08612854] current loss 0.0036034104686011236
# motors ['vkb_4', 'hkb_4'] trans [ 0.07764469 -0.03181772] current loss 0.070290749184221
# motors ['vkb_4', 'hkb_4'] trans [ 0.03638588 -0.09085991] current loss 0.0014862777086173656
# motors ['vkb_4', 'hkb_4'] trans [ 0.03597509 -0.09100587] current loss 0.001876744354042316
# motors ['vkb_4', 'hkb_4'] trans [ 0.03655329 -0.09056326] current loss 0.0011501200122178803
# motors ['vkb_4', 'hkb_4'] trans [-0.01847986 -0.02150246] current loss 0.08778168442978992
# motors ['vkb_4', 'hkb_4'] trans [ 0.03640519 -0.09047372] current loss 0.0011990470382753748
# motors ['vkb_4', 'hkb_4'] trans [ 0.03634798 -0.0903473 ] current loss 0.0011729626409770135
# motors ['vkb_4', 'hkb_4'] trans [ 0.03633543 -0.09021004] current loss 0.0011164090291689835
# motors ['vkb_4', 'hkb_4'] trans [ 0.08444559 -0.13231871] current loss 0.06336373186574437
# motors ['vkb_4', 'hkb_4'] trans [ 0.03631587 -0.09012908] current loss 0.0011019986103508797
# motors ['vkb_4', 'hkb_4'] trans [ 0.03394111 -0.03253824] current loss 0.05706676046957891
# motors ['vkb_4', 'hkb_4'] trans [-0.04459393 -0.14097575] current loss 0.09632447708849004
# motors ['vkb_4', 'hkb_4'] trans [ 0.03629822 -0.09007019] current loss 0.0010983284548230971
# motors ['vkb_4', 'hkb_4'] trans [ 0.03633035 -0.0899562 ] current loss 0.0010351854271437783
# motors ['vkb_4', 'hkb_4'] trans [ 0.03636343 -0.08984791] current loss 0.0009815169260515666
# motors ['vkb_4', 'hkb_4'] trans [ 0.03639544 -0.08974525] current loss 0.0009403169855524133
# motors ['vkb_4', 'hkb_4'] trans [ 0.03642663 -0.08965495] current loss 0.0009092921112551
# motors ['vkb_4', 'hkb_4'] trans [ 0.04749347 -0.12927733] current loss 0.04083650334315729
# motors ['vkb_4', 'hkb_4'] trans [ 0.03642607 -0.0896057 ] current loss 0.0009145667551266532
# motors ['vkb_4', 'hkb_4'] trans [ 0.0364524  -0.08955221] current loss 0.0008953581379347291
# motors ['vkb_4', 'hkb_4'] trans [ 0.03647333 -0.08950168] current loss 0.0008858087774007627
# motors ['vkb_4', 'hkb_4'] trans [ 0.03648463 -0.08946754] current loss 0.0008831934311238652
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.19739743 -0.14900069] current loss 0.17012957977998872
# motors ['vkb_4', 'hkb_4'] trans [ 0.03648801 -0.08945668] current loss 0.0008834962984664387
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_4', 'hkb_4'] trans [ 0.19739743 -0.0178707 ] current loss 0.17492595770501412
# motors ['vkb_4', 'hkb_4'] trans [ 0.03647954 -0.0894484 ] current loss 0.0008940367036800443
# motors ['vkb_4', 'hkb_4'] trans [ 0.03649176 -0.08943235] current loss 0.0008872280618547634
# motors ['vkb_4', 'hkb_4'] trans [ 0.03649998 -0.08941422] current loss 0.0008850039805160996
# Loss is 0.0008831934311238652 and min acceptable value is 0.001
# Solution is acceptable.
# 5it [22:57, 275.45s/it]
# Test 4 success True with final x [0.036484629719525666, -0.08946754234910331] and final value 0.0008831934311238652
# CPU times: user 32min 7s, sys: 1h 1min 36s, total: 1h 33min 43s
# Wall time: 22min 57s

# %%
yvals_this.size, len(xvals_this)
# Out:
# (71, 71)

# %%
fig, axs = plt.subplots(1, 5, figsize=[15, 4], constrained_layout=True)
axs = axs.flat

nfevals_gp = []
for idx, results_this in enumerate(opt_results_all_gp):
    #yvals_this = opt_results_all_gp[idx][0].func_vals
    xvals_this, yvals_this = np.array(results_this[0].x_iters).T
    nfevals_gp.append(xvals_this.size)
    colors = np.arange(yvals_this.size) / yvals_this.size
    axs[idx].scatter(xvals_this, yvals_this, c=colors, cmap='jet')

# %%
final_hists_dws_gp = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams_gp]
final_hists_gp, final_dws_gp = zip(*final_hists_dws_gp)

# %%
final_peaks_gp = [dw.get_parameter('peak_intensity') for dw in final_dws_gp]
final_h_fwhms_gp = [dw.get_parameter('h_fwhm') for dw in final_dws_gp]
final_v_fwhms_gp = [dw.get_parameter('v_fwhm') for dw in final_dws_gp]

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

#axes[0].plot(final_centroids)
#axes[0].set_ylabel('v_centroid')

axes[1].plot(final_peaks_gp)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms_gp)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms_gp)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics_gp.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists_gp):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams_gp.png', bbox_inches='tight')

# %% [markdown]
# #### Alternating optimization with scipy

# %%
opt_results[-1].fun
# Out:
# 0.0046002452451416615

# %%
# %%time

def inner_opt(focusing_system, motors, num_iters):
    opt_results_inner = []
    for inner in range(num_iters):
        for mot in zip(motors):
            print(f"Starting inner iteration {inner}, motor {mot}.")
            
            opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=mot, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='centroid', 
                                              loss_min_value=1e-3,
                                              default_opt_params={'maxfev':10, 'disp': True})
    
            opt_results, guesses, solution, _ = opt_trial.trials(verbose=True, guess_min=0, guess_max=0, accept_all_solutions=True)
            focusing_system = opt_trial.focusing_system
            opt_results_inner.append(opt_results)
            if opt_results[-1].fun < opt_trial._loss_min_value:
                print("Optimization successful. Terminating both inner and outer iteration")
                return focusing_system, opt_results_inner, True
    return focusing_system, opt_results_inner, False

overall_successes_alt = []
final_losses_alt = []
final_out_beams_alt = []
opt_results_all_alt = []

min_trans = -0.14
max_trans = 0.14

for outer, test_absolute_movements in tqdm(enumerate(absolute_movements)):
    print("Initial motor positions are", test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    focusing_system, opt_results_inner, success = inner_opt(focusing_system, move_motors, 5)
    
    overall_successes_alt.append(success)
    centroid, out_beam, *_ = opt_common.get_centroid_distance(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    final_losses_alt.append(centroid)
    final_out_beams_alt.append(out_beam)
    opt_results_all_alt.append(opt_results_inner)
    print(f'Test {outer} success {success} with final x {opt_results_inner[-1][-1].x} and final value {opt_results_inner[-1][-1].fun}')
# Out:
# 0it [00:00, ?it/s]
# Initial motor positions are [ 0.08153128 -0.04539434]
# Starting inner iteration 0, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.09301584326050917
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.09301584326050917
# motors ('vkb_4',) trans [0.00025] current loss 0.09323367127522796
# motors ('vkb_4',) trans [-0.00025] current loss 0.09279796780072706
# motors ('vkb_4',) trans [-0.00075] current loss 0.09236427029261066
# motors ('vkb_4',) trans [-0.0015] current loss 0.09171569880792753
# motors ('vkb_4',) trans [-0.003] current loss 0.09042033569620679
# motors ('vkb_4',) trans [-0.00525] current loss 0.08849095280748845
# motors ('vkb_4',) trans [-0.00975] current loss 0.08467636340554324
# motors ('vkb_4',) trans [-0.0165] current loss 0.07908474831787808
# motors ('vkb_4',) trans [-0.03] current loss 0.06850599478358478
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 0, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.06850599478358478
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.06850599478358478
# motors ('hkb_4',) trans [0.00025] current loss 0.06834142652841267
# motors ('hkb_4',) trans [0.0005] current loss 0.06817687606991986
# motors ('hkb_4',) trans [0.001] current loss 0.06784991690700912
# motors ('hkb_4',) trans [0.00175] current loss 0.06736344472777335
# motors ('hkb_4',) trans [0.00325] current loss 0.06640526559625785
# motors ('hkb_4',) trans [0.0055] current loss 0.06500770586865318
# motors ('hkb_4',) trans [0.01] current loss 0.062357856085877204
# motors ('hkb_4',) trans [0.01675] current loss 0.058806555975946195
# motors ('hkb_4',) trans [0.03025] current loss 0.05356734450913671
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.05356734450913671
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.05356734450913671
# motors ('vkb_4',) trans [0.00025] current loss 0.05380533552927736
# motors ('vkb_4',) trans [-0.00025] current loss 0.053328857438293624
# motors ('vkb_4',) trans [-0.00075] current loss 0.05285205028832155
# motors ('vkb_4',) trans [-0.0015] current loss 0.0521369285068228
# motors ('vkb_4',) trans [-0.003] current loss 0.050709752314186646
# motors ('vkb_4',) trans [-0.00525] current loss 0.04857729224465467
# motors ('vkb_4',) trans [-0.00975] current loss 0.04434261512234399
# motors ('vkb_4',) trans [-0.0165] current loss 0.038065923804999145
# motors ('vkb_4',) trans [-0.03] current loss 0.02621402330026391
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.02621402330026391
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.02621402330026391
# motors ('hkb_4',) trans [0.00025] current loss 0.026071402120446573
# motors ('hkb_4',) trans [0.0005] current loss 0.025930425061646122
# motors ('hkb_4',) trans [0.001] current loss 0.025652101845575828
# motors ('hkb_4',) trans [0.00175] current loss 0.025247371672124697
# motors ('hkb_4',) trans [0.00325] current loss 0.024487243868104858
# motors ('hkb_4',) trans [0.0055] current loss 0.02348174032707385
# motors ('hkb_4',) trans [0.01] current loss 0.022031546073531073
# motors ('hkb_4',) trans [0.01675] current loss 0.021501900283864287
# motors ('hkb_4',) trans [0.03025] current loss 0.026240770310264172
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.026240770310264172
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.026240770310264172
# motors ('vkb_4',) trans [0.00025] current loss 0.026445600831284104
# motors ('vkb_4',) trans [-0.00025] current loss 0.026036223785844925
# motors ('vkb_4',) trans [-0.00075] current loss 0.025630603400234465
# motors ('vkb_4',) trans [-0.0015] current loss 0.025174756743963658
# motors ('vkb_4',) trans [-0.003] current loss 0.02407809339680274
# motors ('vkb_4',) trans [-0.00525] current loss 0.022361949483923074
# motors ('vkb_4',) trans [-0.00975] current loss 0.019275984803662837
# motors ('vkb_4',) trans [-0.0165] current loss 0.015985829700254528
# motors ('vkb_4',) trans [-0.03] current loss 0.01734817519336901
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.01734817519336901
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.01734817519336901
# motors ('hkb_4',) trans [0.00025] current loss 0.01756714477819511
# motors ('hkb_4',) trans [-0.00025] current loss 0.01713128397993137
# motors ('hkb_4',) trans [-0.00075] current loss 0.016700031973733875
# motors ('hkb_4',) trans [-0.0015] current loss 0.01606097847807622
# motors ('hkb_4',) trans [-0.003] current loss 0.01481313160182734
# motors ('hkb_4',) trans [-0.00525] current loss 0.013035789984614852
# motors ('hkb_4',) trans [-0.00975] current loss 0.01006016583275025
# motors ('hkb_4',) trans [-0.0165] current loss 0.008585434048554528
# motors ('hkb_4',) trans [-0.03] current loss 0.017090907574095985
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 3, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.017090907574095985
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.017090907574095985
# motors ('vkb_4',) trans [0.00025] current loss 0.016965178538142386
# motors ('vkb_4',) trans [0.0005] current loss 0.016846973106700722
# motors ('vkb_4',) trans [0.001] current loss 0.016610770788200634
# motors ('vkb_4',) trans [0.00175] current loss 0.016284969789747937
# motors ('vkb_4',) trans [0.00325] current loss 0.01572103049094928
# motors ('vkb_4',) trans [0.0055] current loss 0.015123306621130548
# motors ('vkb_4',) trans [0.01] current loss 0.014925868279257966
# motors ('vkb_4',) trans [0.01675] current loss 0.017059578836926364
# motors ('vkb_4',) trans [0.0083125] current loss 0.014838208446583075
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 3, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.014838208446583075
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.014838208446583075
# motors ('hkb_4',) trans [0.00025] current loss 0.014589113252118261
# motors ('hkb_4',) trans [0.0005] current loss 0.014338957778270269
# motors ('hkb_4',) trans [0.001] current loss 0.01383824913973455
# motors ('hkb_4',) trans [0.00175] current loss 0.013086552881296702
# motors ('hkb_4',) trans [0.00325] current loss 0.011584778481628444
# motors ('hkb_4',) trans [0.0055] current loss 0.009333721943567935
# motors ('hkb_4',) trans [0.01] current loss 0.0048332338808626234
# motors ('hkb_4',) trans [0.01675] current loss 0.001919376888776833
# motors ('hkb_4',) trans [0.03025] current loss 0.01538433637881271
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 4, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.01538433637881271
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.01538433637881271
# motors ('vkb_4',) trans [0.00025] current loss 0.015385069370618303
# motors ('vkb_4',) trans [-0.00025] current loss 0.015387897795495228
# motors ('vkb_4',) trans [6.25e-05] current loss 0.0153841099731489
# Optimization terminated successfully.
#          Current function value: 0.015384
#          Iterations: 2
#          Function evaluations: 4
# Starting inner iteration 4, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.0153841099731489
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.0153841099731489
# motors ('hkb_4',) trans [0.00025] current loss 0.015633311119504462
# motors ('hkb_4',) trans [-0.00025] current loss 0.015133586966735257
# motors ('hkb_4',) trans [-0.00075] current loss 0.014633887099173142
# motors ('hkb_4',) trans [-0.0015] current loss 0.013888576523427332
# motors ('hkb_4',) trans [-0.003] current loss 0.012394156444539142
# motors ('hkb_4',) trans [-0.00525] current loss 0.010148138953987978
# motors ('hkb_4',) trans [-0.00975] current loss 0.005659977495271428
# motors ('hkb_4',) trans [-0.0165] current loss 0.0010830963020280737
# motors ('hkb_4',) trans [-0.03] current loss 0.0145889010423296
# Warning: Maximum number of function evaluations has been exceeded.
# 1it [04:24, 264.46s/it]
# Test 0 success False with final x [-0.0165] and final value 0.0010830963020280737
# Initial motor positions are [-0.09036973 -0.08380041]
# Starting inner iteration 0, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.12281321578194175
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.12281321578194175
# motors ('vkb_4',) trans [0.00025] current loss 0.12263112106836173
# motors ('vkb_4',) trans [0.0005] current loss 0.12244860808694318
# motors ('vkb_4',) trans [0.001] current loss 0.12208508504056596
# motors ('vkb_4',) trans [0.00175] current loss 0.12154123036160935
# motors ('vkb_4',) trans [0.00325] current loss 0.12045977790675437
# motors ('vkb_4',) trans [0.0055] current loss 0.11885569575911878
# motors ('vkb_4',) trans [0.01] current loss 0.11571464026263778
# motors ('vkb_4',) trans [0.01675] current loss 0.11117033031405879
# motors ('vkb_4',) trans [0.03025] current loss 0.10280561209976367
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 0, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.10280561209976367
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.10280561209976367
# motors ('hkb_4',) trans [0.00025] current loss 0.10260232766466287
# motors ('hkb_4',) trans [0.0005] current loss 0.10239940262768939
# motors ('hkb_4',) trans [0.001] current loss 0.10199476070258964
# motors ('hkb_4',) trans [0.00175] current loss 0.10138887504016304
# motors ('hkb_4',) trans [0.00325] current loss 0.10018222331797073
# motors ('hkb_4',) trans [0.0055] current loss 0.0983885062965987
# motors ('hkb_4',) trans [0.01] current loss 0.09485899298998078
# motors ('hkb_4',) trans [0.01675] current loss 0.08972812258737113
# motors ('hkb_4',) trans [0.03025] current loss 0.08018236632682714
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.08018236632682714
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.08018236632682714
# motors ('vkb_4',) trans [0.00025] current loss 0.07999698162594725
# motors ('vkb_4',) trans [0.0005] current loss 0.079812120169939
# motors ('vkb_4',) trans [0.001] current loss 0.07944254578503519
# motors ('vkb_4',) trans [0.00175] current loss 0.07889013254978687
# motors ('vkb_4',) trans [0.00325] current loss 0.07779688572779048
# motors ('vkb_4',) trans [0.0055] current loss 0.07618420141968954
# motors ('vkb_4',) trans [0.01] current loss 0.0730553498969512
# motors ('vkb_4',) trans [0.01675] current loss 0.06864782686381515
# motors ('vkb_4',) trans [0.03025] current loss 0.06113657206963768
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.06113657206963768
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.06113657206963768
# motors ('hkb_4',) trans [0.00025] current loss 0.06091881952860951
# motors ('hkb_4',) trans [0.0005] current loss 0.060701067653798436
# motors ('hkb_4',) trans [0.001] current loss 0.06026568264492064
# motors ('hkb_4',) trans [0.00175] current loss 0.0596150248447863
# motors ('hkb_4',) trans [0.00325] current loss 0.05832250335247723
# motors ('hkb_4',) trans [0.0055] current loss 0.05639928853644013
# motors ('hkb_4',) trans [0.01] current loss 0.05263579359469261
# motors ('hkb_4',) trans [0.01675] current loss 0.0472278348108368
# motors ('hkb_4',) trans [0.03025] current loss 0.037720916202383235
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.037720916202383235
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.037720916202383235
# motors ('vkb_4',) trans [0.00025] current loss 0.037524997105576746
# motors ('vkb_4',) trans [0.0005] current loss 0.0373319813433056
# motors ('vkb_4',) trans [0.001] current loss 0.03694594524195028
# motors ('vkb_4',) trans [0.00175] current loss 0.036368677275590656
# motors ('vkb_4',) trans [0.00325] current loss 0.03523840132454643
# motors ('vkb_4',) trans [0.0055] current loss 0.03359384247804698
# motors ('vkb_4',) trans [0.01] current loss 0.030639166914465346
# motors ('vkb_4',) trans [0.01675] current loss 0.026720641099339394
# motors ('vkb_4',) trans [0.03025] current loss 0.023246511369260675
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.023246511369260675
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.023246511369260675
# motors ('hkb_4',) trans [0.00025] current loss 0.02299835526936012
# motors ('hkb_4',) trans [0.0005] current loss 0.02275102606484577
# motors ('hkb_4',) trans [0.001] current loss 0.02225376994769702
# motors ('hkb_4',) trans [0.00175] current loss 0.021507426874062555
# motors ('hkb_4',) trans [0.00325] current loss 0.020011050643381396
# motors ('hkb_4',) trans [0.0055] current loss 0.017755827660591274
# motors ('hkb_4',) trans [0.01] current loss 0.013250728858900647
# motors ('hkb_4',) trans [0.01675] current loss 0.006505148584344166
# motors ('hkb_4',) trans [0.03025] current loss 0.007016781761807277
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 3, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.007016781761807277
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.007016781761807277
# motors ('vkb_4',) trans [0.00025] current loss 0.007037909645594072
# motors ('vkb_4',) trans [-0.00025] current loss 0.0070049876845072944
# motors ('vkb_4',) trans [-0.00075] current loss 0.007008750270326996
# motors ('vkb_4',) trans [-0.0005] current loss 0.0070022868936729646
# motors ('vkb_4',) trans [-0.001] current loss 0.007024026737493466
# motors ('vkb_4',) trans [-0.00075] current loss 0.007008750270326996
# motors ('vkb_4',) trans [-0.0004375] current loss 0.007002131245267432
# Optimization terminated successfully.
#          Current function value: 0.007002
#          Iterations: 4
#          Function evaluations: 8
# Starting inner iteration 3, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.007002131245267432
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.007002131245267432
# motors ('hkb_4',) trans [0.00025] current loss 0.007251827648985246
# motors ('hkb_4',) trans [-0.00025] current loss 0.006752304302858924
# motors ('hkb_4',) trans [-0.00075] current loss 0.0062528387658869755
# motors ('hkb_4',) trans [-0.0015] current loss 0.005503965885397666
# motors ('hkb_4',) trans [-0.003] current loss 0.0040093854269516015
# motors ('hkb_4',) trans [-0.00525] current loss 0.0017621018518790303
# motors ('hkb_4',) trans [-0.00975] current loss 0.002738241187726501
# motors ('hkb_4',) trans [-0.0075] current loss 0.0004878519860813573
# motors ('hkb_4',) trans [-0.012] current loss 0.004989595542594217
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization successful. Terminating both inner and outer iteration
# 2it [08:05, 238.64s/it]
# Test 1 success True with final x [-0.0075] and final value 0.0004878519860813573
# Initial motor positions are [0.08939178 0.09628829]
# Starting inner iteration 0, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.130914176391395
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.130914176391395
# motors ('vkb_4',) trans [0.00025] current loss 0.13108352144025515
# motors ('vkb_4',) trans [-0.00025] current loss 0.13074507341789682
# motors ('vkb_4',) trans [-0.00075] current loss 0.13040825618622132
# motors ('vkb_4',) trans [-0.0015] current loss 0.12990398037784115
# motors ('vkb_4',) trans [-0.003] current loss 0.12890298619273066
# motors ('vkb_4',) trans [-0.00525] current loss 0.12742021110548513
# motors ('vkb_4',) trans [-0.00975] current loss 0.124520581182594
# motors ('vkb_4',) trans [-0.0165] current loss 0.1203532653966641
# motors ('vkb_4',) trans [-0.03] current loss 0.11275528556842446
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 0, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.11275528556842446
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.11275528556842446
# motors ('hkb_4',) trans [0.00025] current loss 0.11296747280631322
# motors ('hkb_4',) trans [-0.00025] current loss 0.11254322749328512
# motors ('hkb_4',) trans [-0.00075] current loss 0.11211994924494385
# motors ('hkb_4',) trans [-0.0015] current loss 0.11148625174127612
# motors ('hkb_4',) trans [-0.003] current loss 0.11026430032832377
# motors ('hkb_4',) trans [-0.00525] current loss 0.10837958691468982
# motors ('hkb_4',) trans [-0.00975] current loss 0.10465472756910262
# motors ('hkb_4',) trans [-0.0165] current loss 0.09918224113860205
# motors ('hkb_4',) trans [-0.03] current loss 0.08875325029360466
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.08875325029360466
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.08875325029360466
# motors ('vkb_4',) trans [0.00025] current loss 0.08891973361499389
# motors ('vkb_4',) trans [-0.00025] current loss 0.08858749715371154
# motors ('vkb_4',) trans [-0.00075] current loss 0.0882565500902551
# motors ('vkb_4',) trans [-0.0015] current loss 0.0877645949211396
# motors ('vkb_4',) trans [-0.003] current loss 0.08678965285722502
# motors ('vkb_4',) trans [-0.00525] current loss 0.08535655980737406
# motors ('vkb_4',) trans [-0.00975] current loss 0.08259618931488162
# motors ('vkb_4',) trans [-0.0165] current loss 0.07875245315177672
# motors ('vkb_4',) trans [-0.03] current loss 0.07230992003159165
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.07230992003159165
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.07230992003159165
# motors ('hkb_4',) trans [0.00025] current loss 0.07253798873549099
# motors ('hkb_4',) trans [-0.00025] current loss 0.07208231016207474
# motors ('hkb_4',) trans [-0.00075] current loss 0.0716278559011804
# motors ('hkb_4',) trans [-0.0015] current loss 0.07094734049092458
# motors ('hkb_4',) trans [-0.003] current loss 0.06958972493406268
# motors ('hkb_4',) trans [-0.00525] current loss 0.06756069998852318
# motors ('hkb_4',) trans [-0.00975] current loss 0.06354776163539982
# motors ('hkb_4',) trans [-0.0165] current loss 0.057660495300941916
# motors ('hkb_4',) trans [-0.03] current loss 0.04657349645202212
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.04657349645202212
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.04657349645202212
# motors ('vkb_4',) trans [0.00025] current loss 0.04673263173434185
# motors ('vkb_4',) trans [-0.00025] current loss 0.04641636133722269
# motors ('vkb_4',) trans [-0.00075] current loss 0.04610515476233368
# motors ('vkb_4',) trans [-0.0015] current loss 0.04564370254583517
# motors ('vkb_4',) trans [-0.003] current loss 0.04474608704044161
# motors ('vkb_4',) trans [-0.00525] current loss 0.04346035199076881
# motors ('vkb_4',) trans [-0.00975] current loss 0.04126581233642406
# motors ('vkb_4',) trans [-0.0165] current loss 0.03848188167453487
# motors ('vkb_4',) trans [-0.03] current loss 0.03620373363174918
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.03620373363174918
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.03620373363174918
# motors ('hkb_4',) trans [0.00025] current loss 0.03645302449649592
# motors ('hkb_4',) trans [-0.00025] current loss 0.03595365322870787
# motors ('hkb_4',) trans [-0.00075] current loss 0.03545762217831625
# motors ('hkb_4',) trans [-0.0015] current loss 0.034710006730730096
# motors ('hkb_4',) trans [-0.003] current loss 0.03321335296243636
# motors ('hkb_4',) trans [-0.00525] current loss 0.030970683484085354
# motors ('hkb_4',) trans [-0.00975] current loss 0.026484934193840907
# motors ('hkb_4',) trans [-0.0165] current loss 0.019812051788772513
# motors ('hkb_4',) trans [-0.03] current loss 0.006364623604643117
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 3, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.006364623604643117
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.006364623604643117
# motors ('vkb_4',) trans [0.00025] current loss 0.006348059854070026
# motors ('vkb_4',) trans [0.0005] current loss 0.006341394816612181
# motors ('vkb_4',) trans [0.001] current loss 0.006358309955136483
# motors ('vkb_4',) trans [0.00075] current loss 0.006344825791760698
# motors ('vkb_4',) trans [0.0005625] current loss 0.006341335456312131
# Optimization terminated successfully.
#          Current function value: 0.006341
#          Iterations: 3
#          Function evaluations: 6
# Starting inner iteration 3, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.006341335456312131
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.006341335456312131
# motors ('hkb_4',) trans [0.00025] current loss 0.0065904984200936744
# motors ('hkb_4',) trans [-0.00025] current loss 0.006091732881513993
# motors ('hkb_4',) trans [-0.00075] current loss 0.005592704105089008
# motors ('hkb_4',) trans [-0.0015] current loss 0.004846154101594325
# motors ('hkb_4',) trans [-0.003] current loss 0.003348053271783924
# motors ('hkb_4',) trans [-0.00525] current loss 0.0011009128332644157
# motors ('hkb_4',) trans [-0.00975] current loss 0.003400018555146995
# motors ('hkb_4',) trans [-0.0075] current loss 0.0011498277386567648
# motors ('hkb_4',) trans [-0.0058125] current loss 0.0005390808326979325
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization successful. Terminating both inner and outer iteration
# 3it [11:38, 227.19s/it]
# Test 2 success True with final x [-0.0058125] and final value 0.0005390808326979325
# Initial motor positions are [-0.0108506  -0.12566181]
# Starting inner iteration 0, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.12594808784728376
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.12594808784728376
# motors ('vkb_4',) trans [0.00025] current loss 0.12592586034447673
# motors ('vkb_4',) trans [0.0005] current loss 0.12590507977608817
# motors ('vkb_4',) trans [0.001] current loss 0.12586414674942578
# motors ('vkb_4',) trans [0.00175] current loss 0.12580711455181898
# motors ('vkb_4',) trans [0.00325] current loss 0.1257061134469504
# motors ('vkb_4',) trans [0.0055] current loss 0.12558939456960924
# motors ('vkb_4',) trans [0.01] current loss 0.125478618698732
# motors ('vkb_4',) trans [0.01675] current loss 0.12562034203465122
# motors ('vkb_4',) trans [0.0116875] current loss 0.12547949730283656
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 0, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.12547949730283656
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.12547949730283656
# motors ('hkb_4',) trans [0.00025] current loss 0.12522959605495793
# motors ('hkb_4',) trans [0.0005] current loss 0.12497984538531491
# motors ('hkb_4',) trans [0.001] current loss 0.12448055017908835
# motors ('hkb_4',) trans [0.00175] current loss 0.12370681386285766
# motors ('hkb_4',) trans [0.00325] current loss 0.12221731663767409
# motors ('hkb_4',) trans [0.0055] current loss 0.11996423456438564
# motors ('hkb_4',) trans [0.01] current loss 0.1154603696974102
# motors ('hkb_4',) trans [0.01675] current loss 0.10871797779787011
# motors ('hkb_4',) trans [0.03025] current loss 0.09523538250358822
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.09523538250358822
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.09523538250358822
# motors ('vkb_4',) trans [0.00025] current loss 0.09523812026985971
# motors ('vkb_4',) trans [-0.00025] current loss 0.09523331282389214
# motors ('vkb_4',) trans [-0.00075] current loss 0.09523106521900551
# motors ('vkb_4',) trans [-0.0015] current loss 0.09523286933063442
# motors ('vkb_4',) trans [-0.0009375] current loss 0.09523093972595004
# motors ('vkb_4',) trans [-0.001125] current loss 0.09523119372170927
# motors ('vkb_4',) trans [-0.00089062] current loss 0.0952309672466081
# Optimization terminated successfully.
#          Current function value: 0.095231
#          Iterations: 4
#          Function evaluations: 8
# Starting inner iteration 1, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.0952309672466081
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.0952309672466081
# motors ('hkb_4',) trans [0.00025] current loss 0.09498108001093214
# motors ('hkb_4',) trans [0.0005] current loss 0.09473128297729227
# motors ('hkb_4',) trans [0.001] current loss 0.09423229244990211
# motors ('hkb_4',) trans [0.00175] current loss 0.09348285380747692
# motors ('hkb_4',) trans [0.00325] current loss 0.09198447339839841
# motors ('hkb_4',) trans [0.0055] current loss 0.08973734592628026
# motors ('hkb_4',) trans [0.01] current loss 0.08524438872993585
# motors ('hkb_4',) trans [0.01675] current loss 0.07850278517277143
# motors ('hkb_4',) trans [0.03025] current loss 0.06502384942191627
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.06502384942191627
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.06502384942191627
# motors ('vkb_4',) trans [0.00025] current loss 0.06502439337316727
# motors ('vkb_4',) trans [-0.00025] current loss 0.0650244362489183
# motors ('vkb_4',) trans [6.25e-05] current loss 0.06502389607942435
# Optimization terminated successfully.
#          Current function value: 0.065024
#          Iterations: 2
#          Function evaluations: 4
# Starting inner iteration 2, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.06502389607942435
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.06502389607942435
# motors ('hkb_4',) trans [0.00025] current loss 0.06477459651504767
# motors ('hkb_4',) trans [0.0005] current loss 0.0645249481228108
# motors ('hkb_4',) trans [0.001] current loss 0.06402584307871224
# motors ('hkb_4',) trans [0.00175] current loss 0.06327676961518586
# motors ('hkb_4',) trans [0.00325] current loss 0.06177882610822499
# motors ('hkb_4',) trans [0.0055] current loss 0.0595330769073429
# motors ('hkb_4',) trans [0.01] current loss 0.05504000536392534
# motors ('hkb_4',) trans [0.01675] current loss 0.04830118045759264
# motors ('hkb_4',) trans [0.03025] current loss 0.034827821667995536
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 3, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.034827821667995536
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.034827821667995536
# motors ('vkb_4',) trans [0.00025] current loss 0.0348292928056777
# motors ('vkb_4',) trans [-0.00025] current loss 0.034828161799502454
# motors ('vkb_4',) trans [-6.25e-05] current loss 0.03482773454987866
# Optimization terminated successfully.
#          Current function value: 0.034828
#          Iterations: 2
#          Function evaluations: 4
# Starting inner iteration 3, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.03482773454987866
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.03482773454987866
# motors ('hkb_4',) trans [0.00025] current loss 0.03457905246451988
# motors ('hkb_4',) trans [0.0005] current loss 0.03432826918173448
# motors ('hkb_4',) trans [0.001] current loss 0.03382815066486318
# motors ('hkb_4',) trans [0.00175] current loss 0.03307937577146551
# motors ('hkb_4',) trans [0.00325] current loss 0.03158240867434509
# motors ('hkb_4',) trans [0.0055] current loss 0.02933871941268698
# motors ('hkb_4',) trans [0.01] current loss 0.024846460991041184
# motors ('hkb_4',) trans [0.01675] current loss 0.018113038348752473
# motors ('hkb_4',) trans [0.03025] current loss 0.0046002452451416615
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 4, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.0046002452451416615
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.0046002452451416615
# motors ('vkb_4',) trans [0.00025] current loss 0.004607926374070987
# motors ('vkb_4',) trans [-0.00025] current loss 0.0046063527891299786
# motors ('vkb_4',) trans [-6.25e-05] current loss 0.004600436137580101
# Optimization terminated successfully.
#          Current function value: 0.004600
#          Iterations: 2
#          Function evaluations: 4
# Starting inner iteration 4, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.004600436137580101
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.004600436137580101
# motors ('hkb_4',) trans [0.00025] current loss 0.00435054675304975
# motors ('hkb_4',) trans [0.0005] current loss 0.004101549625069499
# motors ('hkb_4',) trans [0.001] current loss 0.003600899507218324
# motors ('hkb_4',) trans [0.00175] current loss 0.0028498205417677703
# motors ('hkb_4',) trans [0.00325] current loss 0.0013508601272204743
# motors ('hkb_4',) trans [0.0055] current loss 0.0009017592345073842
# motors ('hkb_4',) trans [0.01] current loss 0.005393269468043314
# motors ('hkb_4',) trans [0.00775] current loss 0.0031488090890155742
# motors ('hkb_4',) trans [0.0049375] current loss 0.00034184390802420784
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization successful. Terminating both inner and outer iteration
# 4it [15:21, 225.52s/it]
# Test 3 success True with final x [0.0049375] and final value 0.00034184390802420784
# Initial motor positions are [-0.03739743  0.08965405]
# Starting inner iteration 0, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.09681140438651067
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.09681140438651067
# motors ('vkb_4',) trans [0.00025] current loss 0.09671593831991887
# motors ('vkb_4',) trans [0.0005] current loss 0.0966216549320258
# motors ('vkb_4',) trans [0.001] current loss 0.09643457892458848
# motors ('vkb_4',) trans [0.00175] current loss 0.09615832465357081
# motors ('vkb_4',) trans [0.00325] current loss 0.09561977523070796
# motors ('vkb_4',) trans [0.0055] current loss 0.09485069582524533
# motors ('vkb_4',) trans [0.01] current loss 0.09345316739980963
# motors ('vkb_4',) trans [0.01675] current loss 0.09175497666674448
# motors ('vkb_4',) trans [0.03025] current loss 0.0896748104828379
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 0, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.0896748104828379
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.0896748104828379
# motors ('hkb_4',) trans [0.00025] current loss 0.08992280993436735
# motors ('hkb_4',) trans [-0.00025] current loss 0.0894266304167422
# motors ('hkb_4',) trans [-0.00075] current loss 0.08892977837830549
# motors ('hkb_4',) trans [-0.0015] current loss 0.08818627900378671
# motors ('hkb_4',) trans [-0.003] current loss 0.08669764823634711
# motors ('hkb_4',) trans [-0.00525] current loss 0.08446377911604036
# motors ('hkb_4',) trans [-0.00975] current loss 0.0799973831964243
# motors ('hkb_4',) trans [-0.0165] current loss 0.07329901076558094
# motors ('hkb_4',) trans [-0.03] current loss 0.05992242951618241
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.05992242951618241
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.05992242951618241
# motors ('vkb_4',) trans [0.00025] current loss 0.05989248028883477
# motors ('vkb_4',) trans [0.0005] current loss 0.059863984672404946
# motors ('vkb_4',) trans [0.001] current loss 0.05981008283252226
# motors ('vkb_4',) trans [0.00175] current loss 0.05973671176612973
# motors ('vkb_4',) trans [0.00325] current loss 0.05961965484409079
# motors ('vkb_4',) trans [0.0055] current loss 0.059515872768174195
# motors ('vkb_4',) trans [0.01] current loss 0.05956737209258759
# motors ('vkb_4',) trans [0.00775] current loss 0.05949814147405657
# motors ('vkb_4',) trans [0.01225] current loss 0.059723323823897896
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 1, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.059723323823897896
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.059723323823897896
# motors ('hkb_4',) trans [0.00025] current loss 0.05997153636804686
# motors ('hkb_4',) trans [-0.00025] current loss 0.05947398206711778
# motors ('hkb_4',) trans [-0.00075] current loss 0.05897814109828484
# motors ('hkb_4',) trans [-0.0015] current loss 0.058233561429910916
# motors ('hkb_4',) trans [-0.003] current loss 0.0567444529849516
# motors ('hkb_4',) trans [-0.00525] current loss 0.054513007120168225
# motors ('hkb_4',) trans [-0.00975] current loss 0.050048063857374696
# motors ('hkb_4',) trans [-0.0165] current loss 0.043360432657659514
# motors ('hkb_4',) trans [-0.03] current loss 0.030042826530220994
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('vkb_4',).
# Alternating optimization for motor ('vkb_4',)
# Initial loss is 0.030042826530220994
# initial guess is [0.]
# motors ('vkb_4',) trans [0.] current loss 0.030042826530220994
# motors ('vkb_4',) trans [0.00025] current loss 0.03008702779192305
# motors ('vkb_4',) trans [-0.00025] current loss 0.02999966914521915
# motors ('vkb_4',) trans [-0.00075] current loss 0.02992078236619167
# motors ('vkb_4',) trans [-0.0015] current loss 0.029817225110747508
# motors ('vkb_4',) trans [-0.003] current loss 0.029666935544811892
# motors ('vkb_4',) trans [-0.00525] current loss 0.02958572547084669
# motors ('vkb_4',) trans [-0.00975] current loss 0.029943958038491456
# motors ('vkb_4',) trans [-0.0075] current loss 0.02967858200439037
# motors ('vkb_4',) trans [-0.0046875] current loss 0.029589673546114782
# Warning: Maximum number of function evaluations has been exceeded.
# Starting inner iteration 2, motor ('hkb_4',).
# Alternating optimization for motor ('hkb_4',)
# Initial loss is 0.029589673546114782
# initial guess is [0.]
# motors ('hkb_4',) trans [0.] current loss 0.029589673546114782
# motors ('hkb_4',) trans [0.00025] current loss 0.029839133943730983
# motors ('hkb_4',) trans [-0.00025] current loss 0.02934003937946571
# motors ('hkb_4',) trans [-0.00075] current loss 0.028841957130364318
# motors ('hkb_4',) trans [-0.0015] current loss 0.02809336090623098
# motors ('hkb_4',) trans [-0.003] current loss 0.026600295056278606
# motors ('hkb_4',) trans [-0.00525] current loss 0.02435607934073555
# motors ('hkb_4',) trans [-0.00975] current loss 0.01992582721002756
# motors ('hkb_4',) trans [-0.0165] current loss 0.0131976933684123
# motors ('hkb_4',) trans [-0.03] current loss 0.0005657643660938349
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization successful. Terminating both inner and outer iteration
# 5it [18:11, 218.34s/it]
# Test 4 success True with final x [-0.03] and final value 0.0005657643660938349
# CPU times: user 17min 30s, sys: 1min 51s, total: 19min 22s
# Wall time: 18min 11s

# %%
op

# %%
nfevals_alt = []
func_vals_alt = []
for sr_per_outer in opt_results_all_alt:
    nfevals_outer = 0
    func_vals_outer = 0
    for sr_per_guess in sr_per_outer:
        nfevals_outer += sum([sr['nfev'] for sr in sr_per_guess])
        func_vals_outer = sr_per_guess[-1]['fun']
    nfevals_alt.append(nfevals_outer)
    func_vals_alt.append(func_vals_outer)

# %%
nfevals_alt
# Out:
# [94, 78, 76, 80, 60]

# %%
final_hists_dws_alt = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams_alt]
final_hists_alt, final_dws_alt = zip(*final_hists_dws_alt)

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists_alt):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams_scipy_alt.png', bbox_inches='tight')

# %% [markdown]
# #### Alternating optimization with skopt

# %%
callback_y = skopt.callbacks.DeltaYStopper(1e-5)
callback_x = skopt.callbacks.DeltaXStopper(1e-5)

# %%
# %%time

    
def inner_opt(focusing_system, motors, bounds_all, num_iters):
    opt_results_inner = []
    for inner in range(num_iters):
        for mot, bound in zip(motors, bounds_all):
            print(f"Starting inner iteration {inner}, motor {mot} with bounds {bound}.")
            
            
            starting_val = movers.get_absolute_positions(focusing_system, mot)
            opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=mot, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='centroid', 
                                              loss_min_value=1e-3)
            opt_trial.set_gaussian_process_optimizer(bounds=[bound], callback=[callback_x, callback_y],
                                                     n_calls=10, n_initial_points=5)
    
            opt_results, guesses, solution, _ = opt_trial.trials(verbose=False, guess_min=0, guess_max=0, accept_all_solutions=True)
            focusing_system = opt_trial.focusing_system
            relative_trans = opt_results[-1].x
            
            new_trans = np.atleast_1d(relative_trans) + np.atleast_1d(starting_val)
            focusing_system = movers.move_motors(focusing_system, mot, new_trans, movement='absolute')
            
            opt_results_inner.append(opt_results)
            if opt_results[-1].fun < opt_trial._loss_min_value:
                print("Optimization successful. Terminating both inner and outer iteration")
                return focusing_system, opt_results_inner, True
    return focusing_system, opt_results_inner, False

overall_successes_alt_gp = []
final_losses_alt_gp = []
final_out_beams_alt_gp = []
opt_results_all_alt_gp = []

min_trans = -0.14
max_trans = 0.14

for outer, test_absolute_movements in tqdm(enumerate(absolute_movements)):
    print("Initial motor positions are", test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    bounds_all_mots = []
    for m in test_absolute_movements:
        bounds_this = [min_trans - m - 0.02, max_trans - m + 0.02]
        bounds_all_mots.append(bounds_this)
    
    focusing_system, opt_results_inner, success = inner_opt(focusing_system, move_motors, bounds_all_mots, 5)
    
    overall_successes_alt_gp.append(success)
    centroid, out_beam, *_ = opt_common.get_centroid_distance(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    final_losses_alt_gp.append(centroid)
    final_out_beams_alt_gp.append(out_beam)
    opt_results_all_alt_gp.append(opt_results_inner)
    print(f'Test {outer} success {success} with final x {opt_results_inner[-1][-1].x} and final value {opt_results_inner[-1][-1].fun}')
# Out:
# 0it [00:00, ?it/s]
# Initial motor positions are [ 0.08153128 -0.04539434]
# Starting inner iteration 0, motor vkb_4 with bounds [-0.24153128, 0.07846872000000002].
# Initial loss is 0.09301584326050917
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# Loss is 0.045293046162746965 for x [-0.08205283996947671] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 0, motor hkb_4 with bounds [-0.11460566000000001, 0.20539434].
# Initial loss is 0.045293046162746965
# Loss is 0.002395459092562687 for x [0.047685249793558496] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 1, motor vkb_4 with bounds [-0.24153128, 0.07846872000000002].
# Initial loss is 0.0023954590925627443
# Loss is 0.01579713699260827 for x [-0.015015064215172846] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 1, motor hkb_4 with bounds [-0.11460566000000001, 0.20539434].
# Initial loss is 0.015797170904972492
# Loss is 0.01591724763846521 for x [-0.0054088929226236565] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 2, motor vkb_4 with bounds [-0.24153128, 0.07846872000000002].
# Initial loss is 0.01591724763846521
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# Loss is 0.0030558257844883756 for x [0.015499295711608102] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 2, motor hkb_4 with bounds [-0.11460566000000001, 0.20539434].
# Initial loss is 0.0030558257844883756
# Loss is 0.014320521998753598 for x [0.017408039212494827] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 3, motor vkb_4 with bounds [-0.24153128, 0.07846872000000002].
# Initial loss is 0.014320521998753586
# Loss is 0.0158910151220822 for x [-0.006856494614328995] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 3, motor hkb_4 with bounds [-0.11460566000000001, 0.20539434].
# Initial loss is 0.015891015122082193
# Loss is 0.008412388457661693 for x [-0.019181043059572092] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 4, motor vkb_4 with bounds [-0.24153128, 0.07846872000000002].
# Initial loss is 0.008412388457661693
# Loss is 0.010384479783182656 for x [-0.002280818034202353] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 4, motor hkb_4 with bounds [-0.11460566000000001, 0.20539434].
# Initial loss is 0.010384479783182656
# Loss is 0.013483188589317524 for x [0.014710235060147334] and min acceptable value is 0.001
# Solution is not acceptable.
# 1it [04:39, 279.30s/it]
# Test 0 success False with final x [0.014710235060147334] and final value 0.013483188589317524
# Initial motor positions are [-0.09036973 -0.08380041]
# Starting inner iteration 0, motor vkb_4 with bounds [-0.06963027000000002, 0.25036973].
# Initial loss is 0.12281321578194175
# Loss is 0.08363481049981152 for x [0.09020887299115518] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 0, motor hkb_4 with bounds [-0.07619959000000001, 0.24380041].
# Initial loss is 0.08363481049981152
# Loss is 0.003714886116495645 for x [0.08745423341477473] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 1, motor vkb_4 with bounds [-0.06963027000000002, 0.25036973].
# Initial loss is 0.0037148861164955083
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# Loss is 0.005023748193565592 for x [-0.003257038444443222] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 1, motor hkb_4 with bounds [-0.07619959000000001, 0.24380041].
# Initial loss is 0.005023748193565592
# Loss is 0.019311437487486937 for x [-0.02271375099365324] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 2, motor vkb_4 with bounds [-0.06963027000000002, 0.25036973].
# Initial loss is 0.019311262771560294
# Loss is 0.019961216509014754 for x [0.009375174655354007] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 2, motor hkb_4 with bounds [-0.07619959000000001, 0.24380041].
# Initial loss is 0.019961216509014765
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# Loss is 0.007894140521298523 for x [0.02403862930032423] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 3, motor vkb_4 with bounds [-0.06963027000000002, 0.25036973].
# Initial loss is 0.007894140521298523
# Loss is 0.016440956193408244 for x [-0.02152358262404796] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 3, motor hkb_4 with bounds [-0.07619959000000001, 0.24380041].
# Initial loss is 0.016440956193408247
# Loss is 0.015750709650117864 for x [-0.006810282335949047] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 4, motor vkb_4 with bounds [-0.06963027000000002, 0.25036973].
# Initial loss is 0.015750709650117864
# Loss is 0.013335060294573818 for x [0.0024129751754066314] and min acceptable value is 0.001
# Solution is not acceptable.
# Starting inner iteration 4, motor hkb_4 with bounds [-0.07619959000000001, 0.24380041].
# Initial loss is 0.01333506029457379
# Loss is 0.016577829398874123 for x [-0.0082349381389515] and min acceptable value is 0.001
# Solution is not acceptable.
# 2it [09:17, 278.65s/it]
# Test 1 success False with final x [-0.0082349381389515] and final value 0.016577829398874123
# Initial motor positions are [0.08939178 0.09628829]
# Starting inner iteration 0, motor vkb_4 with bounds [-0.24939178, 0.07060822000000001].
# Initial loss is 0.130914176391395
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID

# %%
opt_results_all_alt_gp
# Out:
# []

# %%
shutil.rmtree(temp_work_dir)
