# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from aps_ai.beamline34IDC.simulation.facade.focusing_optics_interface import Movement

from aps_ai.beamline34IDC.util.shadow.common import \
    plot_shadow_beam_spatial_distribution, get_shadow_beam_spatial_distribution,\
    load_shadow_beam, PreProcessorFiles, EmptyBeamException
import beamline34IDC.optimization.common as opt_common
import beamline34IDC.optimization.movers as movers
from aps_ai.beamline34IDC.util import clean_up
import matplotlib.pyplot as plt
import numpy as np
import scipy
from tqdm import tqdm
import shutil
import glob

# %%
# %matplotlib inline

# %%
DEFAULT_RANDOM_SEED = np.random.randint(100000)
print(DEFAULT_RANDOM_SEED)
# Out:
# 18415

# %%
base_dir = '/gpfs/fs1/home/skandel/code/oasys_ml/ML_Control_System/'
orig_work_dir = f'{base_dir}/work_directory'
temp_work_dir = f'{base_dir}/tmp_work_dir/{DEFAULT_RANDOM_SEED}'

# %%
os.mkdir(temp_work_dir)

# %%
dat_files = glob.glob(f'{orig_work_dir}/*.dat')
for df in dat_files:
    shutil.copy(df, temp_work_dir)

# %%
os.chdir(temp_work_dir)

# %%
input_beam_path = "primary_optics_system_beam.dat"

# %%
shutil.rmtree??

# %%
move_motors = ['vkb_q', 'hkb_q']

# %%
motors_str = move_motors[0] if len(move_motors) == 1 else '_'.join(move_motors)
fig_save_path = f'{orig_work_dir}/figures/{motors_str}/'
if not os.path.isdir(fig_save_path):
    os.mkdir(fig_save_path)

# %%
# Focusing Optics System -------------------------
focusing_system = opt_common.reinitialize(input_beam_path=input_beam_path)

# %%
centroid, out_beam, hist, dw = opt_common.get_centroid_distance(focusing_system=focusing_system, 
                                                                random_seed=DEFAULT_RANDOM_SEED)
print(centroid)
_ = plot_shadow_beam_spatial_distribution(out_beam)
# Out:
# 8.698542372776435e-05

# %%
initial_absolute_positions = np.array(movers.get_absolute_positions(focusing_system, move_motors))
print(initial_absolute_positions)
# Out:
# [221. 120.]

# %%
# check positive and negative movement
movers.move_motors(focusing_system, move_motors, [-100, -100], movement='relative')
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')

# %%
# check positive and negative movement
movers.move_motors(focusing_system, move_motors, [100, 100], movement='relative')
beam = opt_common.get_beam(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
plot_shadow_beam_spatial_distribution(beam)
movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')

# %%
# Plotting the loss function for a grid of values

# %%
move_motors
# Out:
# ['vkb_q', 'hkb_q']

# %%
test_hkb_q = np.linspace(-100, 100, 6)
test_vkb_q = test_hkb_q
fwhm_values = []
for v in tqdm(test_vkb_q):
    for h in (test_hkb_q):
        focusing_system = movers.move_motors(focusing_system, move_motors, [v, h], movement='relative')
        fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system=focusing_system, random_seed=DEFAULT_RANDOM_SEED)
        focusing_system = movers.move_motors(focusing_system, move_motors, initial_absolute_positions, movement='absolute')
        fwhm_values.append(fwhm)
# Out:
# 100%|██████████| 6/6 [01:52<00:00, 18.83s/it]

# %%
xvals, yvals
# Out:
# (array([ 20.,  60., 100., 140., 180., 220.]),
#  array([121., 161., 201., 241., 281., 321.]))

# %%
xx, yy = np.meshgrid(xvals, yvals)

# %%
fwhm_values
# Out:
# [0.15106488297111745,
#  0.06300348717569818,
#  0.0561387368794777,
#  0.05598188136659953,
#  0.05661840519824087,
#  0.057258149305061776,
#  0.14259228981613348,
#  0.03848896421068455,
#  0.025758895905025374,
#  0.025415198947745975,
#  0.026788152485250374,
#  0.028115066762730276,
#  0.14050900825787915,
#  0.02986002881238963,
#  0.008587192906527239,
#  0.007493535561295388,
#  0.011306009804811197,
#  0.014166076716666962,
#  0.14046275519951212,
#  0.029641616147676384,
#  0.007793962563593986,
#  0.006569430777282391,
#  0.01071588568115086,
#  0.01369971101235416,
#  0.14103165032000853,
#  0.03222989764759525,
#  0.014862259908753943,
#  0.014258272041672727,
#  0.01658225285679149,
#  0.01865001309901953,
#  0.14185431833210724,
#  0.035657924959058694,
#  0.02129807729619341,
#  0.020881083225997677,
#  0.022532031126150775,
#  0.02409448726468357]

# %%
xvals = test_hkb_q + initial_absolute_positions[1]
yvals = test_vkb_q + initial_absolute_positions[0]

#plt.plot(test_values + initial_absolute_positions[0], fwhm_values)
plt.pcolormesh(xx, yy, np.log(np.reshape(fwhm_values, (6,6))), shading='gouraud')
plt.xlabel('Position h')
plt.ylabel('Position V')
plt.colorbar()
plt.show()

# %%
# %%time
initial_losses = []
initial_out_beams = []
absolute_movements = []

start_guesses = []
overall_successes = []
final_losses = []
final_out_beams = []
opt_results_all_scipy = []

min_trans = -100
max_trans = 100

for outer in tqdm(range(1)):
    translations = np.random.uniform(min_trans, max_trans, size=2)
    test_absolute_movements = initial_absolute_positions + translations
    print("Initial motor positions are", test_absolute_movements)
    absolute_movements.append(test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    fwhm, out_beam, hist, dw = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    initial_losses.append(fwhm)
    initial_out_beams.append(out_beam)
    
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='fwhm',
                                              default_opt_params={'maxfev':100})
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=True, guess_min=min_trans, guess_max=max_trans)
    focusing_system = opt_trial.focusing_system
    
    start_guesses.append(guesses)
    overall_successes.append(success)
    fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    final_losses.append(fwhm)
    final_out_beams.append(out_beam)
    opt_results_all_scipy.append(opt_results)
    print(f'Test {outer} success {success} with final x {opt_results[-1].x} and final value {opt_results[-1].fun}')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Initial motor positions are [263.91719196  52.51985055]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.038522812072670255
# Initial loss is 0.038522812072670255
# motors ['vkb_q', 'hkb_q'] trans [20.36615317 37.33210346] current loss 0.017510430808014763
# motors ['vkb_q', 'hkb_q'] trans [21.38446083 37.33210346] current loss 0.017774947734353466
# motors ['vkb_q', 'hkb_q'] trans [20.36615317 39.19870864] current loss 0.0169708946982478
# motors ['vkb_q', 'hkb_q'] trans [19.34784551 39.19870864] current loss 0.01691809461632848
# motors ['vkb_q', 'hkb_q'] trans [18.32953785 40.13201122] current loss 0.016251399959589626
# motors ['vkb_q', 'hkb_q'] trans [18.32953785 41.9986164 ] current loss 0.01584828121639222
# motors ['vkb_q', 'hkb_q'] trans [17.31123019 44.33187286] current loss 0.0156320734340662
# motors ['vkb_q', 'hkb_q'] trans [15.27461488 45.26517545] current loss 0.015133850409570345
# motors ['vkb_q', 'hkb_q'] trans [12.72884573 48.29840886] current loss 0.01408728638305901
# motors ['vkb_q', 'hkb_q'] trans [11.71053807 52.4982705 ] current loss 0.013542189232229643
# motors ['vkb_q', 'hkb_q'] trans [ 8.40103818 58.68140013] current loss 0.012656072367599776
# motors ['vkb_q', 'hkb_q'] trans [ 3.81865372 62.64793613] current loss 0.011493721753398394
# motors ['vkb_q', 'hkb_q'] trans [-2.92763452 71.80596776] current loss 0.009917587054019836
# motors ['vkb_q', 'hkb_q'] trans [-7.25544207 82.18895903] current loss 0.009446086502007803
# motors ['vkb_q', 'hkb_q'] trans [-17.24758596  99.13423412] current loss 0.008768710845990955
# motors ['vkb_q', 'hkb_q'] trans [-28.57625866 112.25880175] current loss 0.008479310194385874
# motors ['vkb_q', 'hkb_q'] trans [-47.06490709 139.04750255] current loss 0.010748964792354793
# motors ['vkb_q', 'hkb_q'] trans [-42.89621011 139.58706811] current loss 0.010704509687328554
# motors ['vkb_q', 'hkb_q'] trans [-12.91977842  88.75124285] current loss 0.008757573873926325
# motors ['vkb_q', 'hkb_q'] trans [-24.24845111 101.87581047] current loss 0.007986719453307584
# motors ['vkb_q', 'hkb_q'] trans [-27.74888369 103.24659864] current loss 0.007623429090364526
# motors ['vkb_q', 'hkb_q'] trans [-43.40536394 126.75415754] current loss 0.009011011230433593
# motors ['vkb_q', 'hkb_q'] trans [-20.5411748   98.25197152] current loss 0.008162030056259206
# motors ['vkb_q', 'hkb_q'] trans [-19.71379982  89.23976842] current loss 0.007370457511852872
# motors ['vkb_q', 'hkb_q'] trans [-15.2825704   77.73025175] current loss 0.0073567548535889045
# motors ['vkb_q', 'hkb_q'] trans [-22.4902793   82.72487888] current loss 0.006069488145939117
# motors ['vkb_q', 'hkb_q'] trans [-23.46483155  74.96133256] current loss 0.005423004888433507
# motors ['vkb_q', 'hkb_q'] trans [-10.99851826  49.44498567] current loss 0.00977323236733372
# motors ['vkb_q', 'hkb_q'] trans [-23.56129233  89.7961954 ] current loss 0.006780434559412197
# motors ['vkb_q', 'hkb_q'] trans [-31.74355348  87.0272762 ] current loss 0.004970047632430953
# motors ['vkb_q', 'hkb_q'] trans [-39.97404502  91.67578843] current loss 0.0048208838183604365
# motors ['vkb_q', 'hkb_q'] trans [-39.87758423  76.84092558] current loss 0.0022488713367450107
# motors ['vkb_q', 'hkb_q'] trans [-48.03573018  70.36329068] current loss 0.0018024760975504763
# motors ['vkb_q', 'hkb_q'] trans [-64.54494365  87.07774654] current loss 0.008078103670917349
# motors ['vkb_q', 'hkb_q'] trans [-33.73485957  77.99043605] current loss 0.0035702965896542817
# motors ['vkb_q', 'hkb_q'] trans [-41.79654474  56.6779383 ] current loss 0.0029914069283140656
# motors ['vkb_q', 'hkb_q'] trans [-56.09741535  49.05079292] current loss 0.006808797044302448
# motors ['vkb_q', 'hkb_q'] trans [-39.32549852  70.75552527] current loss 0.0014775320648392984
# motors ['vkb_q', 'hkb_q'] trans [-45.56468396  84.44087764] current loss 0.0037191808333699753
# motors ['vkb_q', 'hkb_q'] trans [-42.73857955  63.61867314] current loss 0.0014150724501678208
# motors ['vkb_q', 'hkb_q'] trans [-34.02834788  64.01090773] current loss 0.0025866072253612894
# motors ['vkb_q', 'hkb_q'] trans [-44.53388461  68.77519494] current loss 0.0011675649927639412
# motors ['vkb_q', 'hkb_q'] trans [-47.94696563  61.63834281] current loss 0.0020813191247827387
# motors ['vkb_q', 'hkb_q'] trans [-41.4808653   68.47622966] current loss 0.0011818686074397283
# motors ['vkb_q', 'hkb_q'] trans [-43.27617036  73.63275146] current loss 0.0015354163658762145
# motors ['vkb_q', 'hkb_q'] trans [-42.87297725  66.12219272] current loss 0.0012948402838631784
# motors ['vkb_q', 'hkb_q'] trans [-43.14177266  71.12923188] current loss 0.0013400539331094048
# motors ['vkb_q', 'hkb_q'] trans [-42.9401761   67.37395251] current loss 0.0013061770886382774
# motors ['vkb_q', 'hkb_q'] trans [-43.00737495  68.6257123 ] current loss 0.0013174807635929597
# motors ['vkb_q', 'hkb_q'] trans [-43.70343093  67.44869383] current loss 0.001303221444651125
# motors ['vkb_q', 'hkb_q'] trans [-45.22994058  67.59817647] current loss 0.0014141368107808952
# motors ['vkb_q', 'hkb_q'] trans [-43.56301636  68.36882834] current loss 0.0011699939048820357
# motors ['vkb_q', 'hkb_q'] trans [-44.39347004  69.69532945] current loss 0.0013207802329583383
# motors ['vkb_q', 'hkb_q'] trans [-43.87594071  68.01035273] current loss 0.0011659251928804197
# motors ['vkb_q', 'hkb_q'] trans [-44.84680895  68.41671933] current loss 0.0011634948191155785
# motors ['vkb_q', 'hkb_q'] trans [-45.48870525  68.44066483] current loss 0.0012888718854821531
# motors ['vkb_q', 'hkb_q'] trans [-44.18886505  67.65187713] current loss 0.0013028559731817501
# motors ['vkb_q', 'hkb_q'] trans [-44.44762972  68.49436549] current loss 0.0011661588237989798
# motors ['vkb_q', 'hkb_q'] trans [-44.27511994  67.93270658] current loss 0.001304896981438245
# motors ['vkb_q', 'hkb_q'] trans [-44.40450227  68.35395076] current loss 0.0011654138753255194
# motors ['vkb_q', 'hkb_q'] trans [-45.37537052  68.76031736] current loss 0.0012915861506795584
# motors ['vkb_q', 'hkb_q'] trans [-44.25079816  68.19784389] current loss 0.0011652408752400266
# motors ['vkb_q', 'hkb_q'] trans [-44.69310484  68.26061246] current loss 0.001163280017148831
# motors ['vkb_q', 'hkb_q'] trans [-44.83740612  68.21394332] current loss 0.0011622289491141095
# motors ['vkb_q', 'hkb_q'] trans [-45.43341691  68.43281876] current loss 0.0012892522414775494
# motors ['vkb_q', 'hkb_q'] trans [-44.54645285  68.25658761] current loss 0.001164035580231745
# motors ['vkb_q', 'hkb_q'] trans [-45.13776223  68.37407504] current loss 0.0012909491569383584
# motors ['vkb_q', 'hkb_q'] trans [-44.69428019  68.28595947] current loss 0.0011634419969489395
# motors ['vkb_q', 'hkb_q'] trans [-44.68487736  68.08318345] current loss 0.0011621630587244156
# motors ['vkb_q', 'hkb_q'] trans [-44.60391156  67.91641551] current loss 0.0013031925694753478
# motors ['vkb_q', 'hkb_q'] trans [-44.82800329  68.0111673 ] current loss 0.0011608404836991992
# motors ['vkb_q', 'hkb_q'] trans [-44.89486484  67.87377121] current loss 0.001301395575047505
# motors ['vkb_q', 'hkb_q'] trans [-44.67547453  67.88040743] current loss 0.0013024849791739858
# motors ['vkb_q', 'hkb_q'] trans [-44.79692322  68.13055934] current loss 0.0011617998582200283
# motors ['vkb_q', 'hkb_q'] trans [-44.94004915  68.05854319] current loss 0.001160602228059723
# motors ['vkb_q', 'hkb_q'] trans [-45.06763505  68.04622307] current loss 0.0011597963217160028
# motors ['vkb_q', 'hkb_q'] trans [-45.09871511  67.92683102] current loss 0.0014176492949492848
# motors ['vkb_q', 'hkb_q'] trans [-44.8723712   68.07962726] current loss 0.0011611353574663423
# motors ['vkb_q', 'hkb_q'] trans [-45.02326714  67.9777631 ] current loss 0.0011595345124588601
# motors ['vkb_q', 'hkb_q'] trans [-45.09871511  67.92683102] current loss 0.0014176492949492848
# motors ['vkb_q', 'hkb_q'] trans [-45.2628989   68.01281887] current loss 0.0012878289502503606
# motors ['vkb_q', 'hkb_q'] trans [-44.93672719  68.01158019] current loss 0.0011602581385503072
# motors ['vkb_q', 'hkb_q'] trans [-45.154175    68.01240598] current loss 0.0012886176569986635
# motors ['vkb_q', 'hkb_q'] trans [-44.99108914  68.01178664] current loss 0.0011599365373073899
# motors ['vkb_q', 'hkb_q'] trans [-45.09981305  68.01219953] current loss 0.0012890057558314996
# motors ['vkb_q', 'hkb_q'] trans [-45.01827012  68.01188986] current loss 0.00115979374116173
# motors ['vkb_q', 'hkb_q'] trans [-44.97390221  67.9434299 ] current loss 0.0013016801912241016
# motors ['vkb_q', 'hkb_q'] trans [-45.04420184  68.02052477] current loss 0.0011597116003640912
# motors ['vkb_q', 'hkb_q'] trans [-45.04919886  67.98639801] current loss 0.0011594590662009022
# motors ['vkb_q', 'hkb_q'] trans [-45.06466323  67.97365209] current loss 0.0011592920741078673
# motors ['vkb_q', 'hkb_q'] trans [-45.04372853  67.93089042] current loss 0.0013012015064307943
# motors ['vkb_q', 'hkb_q'] trans [-45.04408351  67.99811618] current loss 0.0011595438202723356
# motors ['vkb_q', 'hkb_q'] trans [-45.04384686  67.95329901] current loss 0.0011592784027320132
# motors ['vkb_q', 'hkb_q'] trans [-45.04372853  67.93089042] current loss 0.0013012015064307943
# motors ['vkb_q', 'hkb_q'] trans [-45.08524295  67.949188  ] current loss 0.0014179412608213934
# motors ['vkb_q', 'hkb_q'] trans [-45.03876109  67.97061933] current loss 0.0011594101815001485
# motors ['vkb_q', 'hkb_q'] trans [-45.069749    67.95633177] current loss 0.0011591530003579613
# motors ['vkb_q', 'hkb_q'] trans [-45.08524295  67.949188  ] current loss 0.0013011755919408521
# motors ['vkb_q', 'hkb_q'] trans [-45.04893263  67.93597869] current loss 0.0013012252192215982
# motors ['vkb_q', 'hkb_q'] trans [-45.06073058  67.96423374] current loss 0.0011592434898241267
# 100%|██████████| 1/1 [05:21<00:00, 321.25s/it]
# Test 0 success True with final x [-45.069749    67.95633177] and final value 0.0011591530003579613
# CPU times: user 5min 5s, sys: 36.4 s, total: 5min 42s
# Wall time: 5min 21s

# %%
opt_results_all_scipy
# Out:
# [[ final_simplex: (array([[-45.069749  ,  67.95633177],
#          [-45.06073058,  67.96423374],
#          [-45.04384686,  67.95329901]]), array([0.00115915, 0.00115924, 0.00115928]))
#              fun: 0.0011591530003579613
#          message: 'Maximum number of function evaluations has been exceeded.'
#             nfev: 100
#              nit: 49
#           status: 1
#          success: False
#                x: array([-45.069749  ,  67.95633177])]]

# %%
initial_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in initial_out_beams]
initial_hists, initial_dws = zip(*initial_hists_dws)

# %%
initial_peaks = [dw.get_parameter('peak_intensity') for dw in initial_dws]
initial_h_fwhms = [dw.get_parameter('h_fwhm') for dw in initial_dws]
initial_v_fwhms = [dw.get_parameter('v_fwhm') for dw in initial_dws]

# %%
final_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams]
final_hists, final_dws = zip(*final_hists_dws)

# %%
final_peaks = [dw.get_parameter('peak_intensity') for dw in final_dws]
final_h_fwhms = [dw.get_parameter('h_fwhm') for dw in final_dws]
final_v_fwhms = [dw.get_parameter('v_fwhm') for dw in final_dws]

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes[0].plot(absolute_movements)
axes[0].set_ylabel('perturbation')

axes[1].plot(initial_losses)
axes[1].set_ylabel('v_centroid')

axes[2].plot(initial_peaks)
axes[2].set_ylabel('peak_intensity')

axes[3].plot(initial_h_fwhms)
axes[3].set_ylabel('h_fwhm')
axes[3].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[4].plot(initial_v_fwhms)
axes[4].set_ylabel('v_fwhm')
axes[4].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('Initial settings')
fig.savefig(f'{fig_save_path}/initial_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

axes[0].plot(final_losses)
axes[0].set_ylabel('Loss')

axes[1].plot(final_peaks)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(initial_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Initial beams')
fig.savefig(f'{fig_save_path}/initial_beams.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams.png', bbox_inches='tight')

# %%
# Test gaussian process optimization

# %%
import skopt

# %%
callback_y = skopt.callbacks.DeltaYStopper(1e-3)
callback_x = skopt.callbacks.DeltaXStopper(1e-1)

# %%
# %%time
initial_losses = []
initial_out_beams = []
absolute_movements = []

start_guesses = []
overall_successes = []
final_losses = []
final_out_beams = []
opt_results_all_gp = []

min_trans = -100.
max_trans = 100.

for outer in tqdm(range(10)):
    translations = np.random.uniform(min_trans, max_trans, size=1)
    test_absolute_movements = initial_absolute_positions + translations
    print("Initial motor positions are", test_absolute_movements)
    absolute_movements.append(test_absolute_movements)
    
    focusing_system = movers.move_motors(focusing_system, move_motors, 
                                         test_absolute_movements,
                                         movement='absolute')
    fwhm, out_beam, hist, dw = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    
    initial_losses.append(fwhm)
    initial_out_beams.append(out_beam)
    
    opt_trial = opt_common.OptimizationCommon(focusing_system, 
                                              motor_types=move_motors, 
                                              initial_motor_positions=test_absolute_movements, 
                                              random_seed=DEFAULT_RANDOM_SEED,
                                              loss_parameter='fwhm')
    opt_trial.set_gaussian_process_optimizer(bounds=[[min_trans, max_trans], [min_trans, max_trans]], 
                                                     callback=[callback_x, callback_y])
    
    opt_results, guesses, solution, success = opt_trial.trials(verbose=True, guess_min=0., guess_max=0.0)
    focusing_system = opt_trial.focusing_system
    
    start_guesses.append(guesses)
    overall_successes.append(success)
    fwhm, out_beam, *_ = opt_common.get_fwhm(focusing_system, random_seed=DEFAULT_RANDOM_SEED)
    if opt_results[-1].fun == 0:
        plot_s
    
    
    final_losses.append(fwhm)
    final_out_beams.append(out_beam)
    opt_results_all_gp.append(opt_results)
    print(f'Test {outer} success {success} with final x {opt_results[-1].x} and final value {opt_results[-1].fun}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Initial motor positions are [134.62188708  33.62188708]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.08681034539245913
# Initial loss is 0.08681034539245913
# motors ['vkb_q', 'hkb_q'] trans [91.62976572 24.00802345] current loss 0.03194053757514301
# motors ['vkb_q', 'hkb_q'] trans [ -7.95641785 -24.08542899] current loss 0.2405895886492268
# motors ['vkb_q', 'hkb_q'] trans [-69.3311169   85.66896773] current loss 0.1646058977940252
# motors ['vkb_q', 'hkb_q'] trans [  6.58240616 -40.39144119] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [61.75807607 49.87759493] current loss 0.015136397142731906
# motors ['vkb_q', 'hkb_q'] trans [-59.255862    89.37441474] current loss 0.13338721866452077
# /home/skandel/.conda/envs/oasys_env/lib/python3.7/site-packages/orangecontrib/shadow/widgets/special_elements/bl/hybrid_control.py:168: RankWarning: Polyfit may be poorly conditioned
#   hy_readfiles(input_parameters, calculation_parameters)	#Read shadow output files needed by HYBRID
# motors ['vkb_q', 'hkb_q'] trans [ 63.59022504 -27.25624074] current loss 0.005763300636785429
# motors ['vkb_q', 'hkb_q'] trans [-89.00695811 -86.91755557] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [-72.38219619  -3.44473767] current loss 0.19520687475363344
# motors ['vkb_q', 'hkb_q'] trans [-86.87598234   7.00756144] current loss 0.2557472645461058
# motors ['vkb_q', 'hkb_q'] trans [99.45745227 66.20196105] current loss 0.006855713268523683
# motors ['vkb_q', 'hkb_q'] trans [ 63.42141915 -26.78396876] current loss 0.007666349070255166
# motors ['vkb_q', 'hkb_q'] trans [ 54.93730046 -26.51266313] current loss 0.5470550401012436
# motors ['vkb_q', 'hkb_q'] trans [ 59.67830503 -26.87688599] current loss 0.7925370980852658
# motors ['vkb_q', 'hkb_q'] trans [-42.73745712 -23.58499044] current loss 0.2616405279549498
# motors ['vkb_q', 'hkb_q'] trans [ 60.52674974 -26.81207653] current loss 0.6011101090339892
# motors ['vkb_q', 'hkb_q'] trans [ 60.62070636 -26.81587779] current loss 0.34656825911349914
# Loss is 0.005763300636785429 and min acceptable value is 0.005
# Solution is not acceptable.
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.08681034539245913
# Initial loss is 0.08681034539245913
# motors ['vkb_q', 'hkb_q'] trans [70.98614002 20.77812461] current loss 0.035848166927999275
# motors ['vkb_q', 'hkb_q'] trans [78.22695037 17.86349531] current loss 0.039325111816074336
# motors ['vkb_q', 'hkb_q'] trans [  8.97530032 -77.16803274] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [ 68.8705131  -80.82439123] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [ 12.32295491 -59.55305505] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [-25.60229257  50.87753854] current loss 0.07172988861342887
# motors ['vkb_q', 'hkb_q'] trans [ 51.42682535 -10.86069441] current loss 0.12578998298800925
# motors ['vkb_q', 'hkb_q'] trans [-36.62066005  24.41031295] current loss 0.09230238898561523
# motors ['vkb_q', 'hkb_q'] trans [ 50.59660413 -95.28219574] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [-99.84446121 -24.00429991] current loss 0.4469110344777077
# motors ['vkb_q', 'hkb_q'] trans [-100.           92.72796827] current loss 0.3485211259103706
# motors ['vkb_q', 'hkb_q'] trans [-96.42684878 -22.80448476] current loss 0.40955329770868093
# motors ['vkb_q', 'hkb_q'] trans [-94.04023213 -22.12301175] current loss 0.3843348499291799
# motors ['vkb_q', 'hkb_q'] trans [100.          73.93837434] current loss 0.0049377692846695785
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.0046204934758827835
# motors ['vkb_q', 'hkb_q'] trans [100.           1.78926458] current loss 0.06955913605262723
# motors ['vkb_q', 'hkb_q'] trans [-100.           62.25306907] current loss 0.34859073650373623
# motors ['vkb_q', 'hkb_q'] trans [100.          38.52162082] current loss 0.019705900697032926
# motors ['vkb_q', 'hkb_q'] trans [100.          83.29949872] current loss 0.003820004689221979
# motors ['vkb_q', 'hkb_q'] trans [-100.          -4.6190494] current loss 0.36035984526060916
# motors ['vkb_q', 'hkb_q'] trans [-100.            9.18716267] current loss 0.3525703864959231
# motors ['vkb_q', 'hkb_q'] trans [100.          31.56732599] current loss 0.025060296999544405
# motors ['vkb_q', 'hkb_q'] trans [100.          56.93688146] current loss 0.010144654250043189
# motors ['vkb_q', 'hkb_q'] trans [-100.           78.63147997] current loss 0.34852338042347125
# motors ['vkb_q', 'hkb_q'] trans [100.          45.03200516] current loss 0.016016037122702737
# motors ['vkb_q', 'hkb_q'] trans [100.        -22.6106797] current loss 0.27977887840513277
# motors ['vkb_q', 'hkb_q'] trans [100.          67.48304082] current loss 0.006586754978873237
# motors ['vkb_q', 'hkb_q'] trans [100.          95.99380036] current loss 0.004169571405525311
# motors ['vkb_q', 'hkb_q'] trans [52.73554986 48.95744266] current loss 0.0176693479711773
# motors ['vkb_q', 'hkb_q'] trans [100.          11.73250633] current loss 0.04815903904881067
# motors ['vkb_q', 'hkb_q'] trans [-100.           34.88295361] current loss 0.3492201523101767
# motors ['vkb_q', 'hkb_q'] trans [100.          89.06279891] current loss 0.0037973098765473577
# motors ['vkb_q', 'hkb_q'] trans [-100.           70.67990802] current loss 0.3485443837422675
# motors ['vkb_q', 'hkb_q'] trans [100.          -7.17733959] current loss 0.10320398850674273
# motors ['vkb_q', 'hkb_q'] trans [-100.           41.97575327] current loss 0.3489444227383335
# motors ['vkb_q', 'hkb_q'] trans [-100.           98.69944251] current loss 0.3485272146869452
# motors ['vkb_q', 'hkb_q'] trans [-100.           14.80550615] current loss 0.35121558607870756
# motors ['vkb_q', 'hkb_q'] trans [-100.           86.03953245] current loss 0.348519315080227
# motors ['vkb_q', 'hkb_q'] trans [-100.            4.88039278] current loss 0.35391254516604465
# motors ['vkb_q', 'hkb_q'] trans [73.03485311 85.62613805] current loss 0.004274419449745055
# Loss is 0.0037973098765473577 and min acceptable value is 0.005
# Solution is acceptable.
#  10%|█         | 1/10 [03:37<32:38, 217.59s/it]
# Test 0 success True with final x [100.0, 89.06279891386905] and final value 0.0037973098765473577
# Initial motor positions are [244.97832235 143.97832235]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.00777292678610477
# Initial loss is 0.00777292678610477
# motors ['vkb_q', 'hkb_q'] trans [58.81503416 70.85820901] current loss 0.021976010247075847
# motors ['vkb_q', 'hkb_q'] trans [-31.91178653 -16.8698901 ] current loss 0.0030568698204581374
# motors ['vkb_q', 'hkb_q'] trans [-2.89792137  0.89745772] current loss 0.0073126131692876324
# motors ['vkb_q', 'hkb_q'] trans [ 12.58589582 -82.9283273 ] current loss 0.030039597827317133
# motors ['vkb_q', 'hkb_q'] trans [-69.38864402 -20.25467391] current loss 0.01759496819934611
# motors ['vkb_q', 'hkb_q'] trans [  0.18525975 -84.89755459] current loss 0.03099714828415124
# motors ['vkb_q', 'hkb_q'] trans [-30.14332097 -15.83897089] current loss 0.0026084595610449
# motors ['vkb_q', 'hkb_q'] trans [  9.18585601 -80.23639532] current loss 0.027495825083941765
# motors ['vkb_q', 'hkb_q'] trans [33.84872676 84.80299864] current loss 0.019261074359768923
# motors ['vkb_q', 'hkb_q'] trans [-50.85437577 -52.50105449] current loss 0.012903279993823876
# motors ['vkb_q', 'hkb_q'] trans [ 11.37631178 -26.08694652] current loss 0.008819124973764464
# motors ['vkb_q', 'hkb_q'] trans [ -7.4661526  -14.67071989] current loss 0.00502008632805458
# motors ['vkb_q', 'hkb_q'] trans [-50.59154096  20.71242004] current loss 0.011706727889740129
# motors ['vkb_q', 'hkb_q'] trans [ 99.81341128 -11.62954793] current loss 0.024143552910425227
# motors ['vkb_q', 'hkb_q'] trans [-34.42588533  -2.02044277] current loss 0.00539664032585817
# motors ['vkb_q', 'hkb_q'] trans [-100.  100.] current loss 0.0382667251950504
# motors ['vkb_q', 'hkb_q'] trans [ 100. -100.] current loss 0.056684391878735474
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.028374142640057925
# motors ['vkb_q', 'hkb_q'] trans [-14.6583228   56.38009291] current loss 0.011548788362585046
# motors ['vkb_q', 'hkb_q'] trans [99.97500669 39.39439319] current loss 0.026173428943837482
# motors ['vkb_q', 'hkb_q'] trans [-24.30280359 -30.87611301] current loss 0.002147717486555334
# motors ['vkb_q', 'hkb_q'] trans [-99.90609377  42.63000934] current loss 0.03677168786824589
# motors ['vkb_q', 'hkb_q'] trans [52.77195266 11.23593484] current loss 0.01816493020622358
# motors ['vkb_q', 'hkb_q'] trans [-25.4323045 -27.4734264] current loss 0.0013755040221567524
# motors ['vkb_q', 'hkb_q'] trans [ 65.2843701  -47.35350024] current loss 0.020446734786616884
# motors ['vkb_q', 'hkb_q'] trans [-55.603423    70.16336184] current loss 0.016697334523703932
# motors ['vkb_q', 'hkb_q'] trans [-99.77170655 -44.59494888] current loss 0.035744367745526064
# motors ['vkb_q', 'hkb_q'] trans [-24.54994739 -27.98219903] current loss 0.0015024387966986379
# motors ['vkb_q', 'hkb_q'] trans [20.75081591 41.12520402] current loss 0.015061358126103982
# motors ['vkb_q', 'hkb_q'] trans [ 99.57165123 -55.95646608] current loss 0.025950001985561837
# motors ['vkb_q', 'hkb_q'] trans [-24.30563918 -28.18618154] current loss 0.0014990490753533417
# motors ['vkb_q', 'hkb_q'] trans [52.96941535 99.54661562] current loss 0.022656306580726173
# motors ['vkb_q', 'hkb_q'] trans [-11.28539888 -51.80796307] current loss 0.00942515995519231
# motors ['vkb_q', 'hkb_q'] trans [-25.93500858 -26.49273161] current loss 0.0013888458307603053
# Loss is 0.0013755040221567524 and min acceptable value is 0.005
# Solution is acceptable.
#  20%|██        | 2/10 [05:52<22:33, 169.16s/it]
# Test 1 success True with final x [-25.432304503001063, -27.47342639693801] and final value 0.0013755040221567524
# Initial motor positions are [303.20549697 202.20549697]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.021432553307984027
# Initial loss is 0.021432553307984027
# motors ['vkb_q', 'hkb_q'] trans [-50.7977713   46.18490754] current loss 0.016840320295624746
# motors ['vkb_q', 'hkb_q'] trans [-3.67030696 41.88326818] current loss 0.02275926834400362
# motors ['vkb_q', 'hkb_q'] trans [-57.50750044 -58.8237235 ] current loss 0.007770675525732707
# motors ['vkb_q', 'hkb_q'] trans [96.91034489 91.72670975] current loss 0.03457428886576351
# motors ['vkb_q', 'hkb_q'] trans [ 31.54821262 -34.00703099] current loss 0.02396258615391543
# motors ['vkb_q', 'hkb_q'] trans [-38.52576778 -19.52771067] current loss 0.01455753482750166
# motors ['vkb_q', 'hkb_q'] trans [-77.8320151  -43.54599307] current loss 0.0069080406005173015
# motors ['vkb_q', 'hkb_q'] trans [98.15031698 38.98746075] current loss 0.03353429393333005
# motors ['vkb_q', 'hkb_q'] trans [44.34185856 76.0968956 ] current loss 0.02932197239875093
# motors ['vkb_q', 'hkb_q'] trans [-94.54278316  29.871364  ] current loss 0.014342695006999714
# motors ['vkb_q', 'hkb_q'] trans [-100. -100.] current loss 0.007650021727747927
# motors ['vkb_q', 'hkb_q'] trans [-33.38228723 -99.92700273] current loss 0.012888853531488154
# motors ['vkb_q', 'hkb_q'] trans [ -74.81715252 -100.        ] current loss 0.005477306183559183
# motors ['vkb_q', 'hkb_q'] trans [-76.95209292 -84.63686339] current loss 0.0017992560400023044
# motors ['vkb_q', 'hkb_q'] trans [ 99.15524651 -97.85555323] current loss 0.030779758553087865
# motors ['vkb_q', 'hkb_q'] trans [ -76.30017485 -100.        ] current loss 0.0053537437971202684
# motors ['vkb_q', 'hkb_q'] trans [-98.60725082  99.57000413] current loss 0.017612211141477395
# motors ['vkb_q', 'hkb_q'] trans [  0.23229765 -99.09412306] current loss 0.01882702569559985
# motors ['vkb_q', 'hkb_q'] trans [-97.28320806 -99.56475943] current loss 0.00685207063227652
# motors ['vkb_q', 'hkb_q'] trans [ -74.89274271 -100.        ] current loss 0.005477240714316365
# motors ['vkb_q', 'hkb_q'] trans [-31.76208957  99.91546932] current loss 0.02070505531213376
# motors ['vkb_q', 'hkb_q'] trans [ 56.38740404 -99.97140606] current loss 0.026328835864382682
# motors ['vkb_q', 'hkb_q'] trans [ -75.92801496 -100.        ] current loss 0.005412491242317876
# motors ['vkb_q', 'hkb_q'] trans [ -76.25758909 -100.        ] current loss 0.005412241108121722
# motors ['vkb_q', 'hkb_q'] trans [-95.95616264 -70.0127652 ] current loss 0.004879191423914638
# motors ['vkb_q', 'hkb_q'] trans [-99.64974857 -14.251675  ] current loss 0.011773214804505211
# motors ['vkb_q', 'hkb_q'] trans [ 98.82326746 -29.60952311] current loss 0.03161624776171474
# motors ['vkb_q', 'hkb_q'] trans [-78.89420419 -76.25647611] current loss 0.0018015970915644488
# motors ['vkb_q', 'hkb_q'] trans [-82.02465656 -81.65969682] current loss 0.0012947894864765175
# motors ['vkb_q', 'hkb_q'] trans [-99.48357133  64.29251455] current loss 0.016305166241671807
# motors ['vkb_q', 'hkb_q'] trans [-83.79146798 -82.30344999] current loss 0.001286087686378159
# motors ['vkb_q', 'hkb_q'] trans [-83.24612957 -81.86728346] current loss 0.0012915035037512133
# Loss is 0.001286087686378159 and min acceptable value is 0.005
# Solution is acceptable.
#  30%|███       | 3/10 [07:53<17:10, 147.18s/it]
# Test 2 success True with final x [-83.79146798353975, -82.30344998718924] and final value 0.001286087686378159
# Initial motor positions are [290.13009548 189.13009548]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.01867985014665032
# Initial loss is 0.01867985014665032
# motors ['vkb_q', 'hkb_q'] trans [-75.78254224  28.20972077] current loss 0.012530632438752236
# motors ['vkb_q', 'hkb_q'] trans [ 3.90925845 60.47863358] current loss 0.021860702507524366
# motors ['vkb_q', 'hkb_q'] trans [86.35745111 23.78312467] current loss 0.030321650892403386
# motors ['vkb_q', 'hkb_q'] trans [-65.87770586  -2.40298099] current loss 0.010298961201735925
# motors ['vkb_q', 'hkb_q'] trans [84.08749878 -5.81717574] current loss 0.028994846578704905
# motors ['vkb_q', 'hkb_q'] trans [  0.93236229 -89.3019546 ] current loss 0.017127891941498993
# motors ['vkb_q', 'hkb_q'] trans [-97.52841505 -79.7990355 ] current loss 0.010113561581365347
# motors ['vkb_q', 'hkb_q'] trans [ 93.41780504 -49.18043686] current loss 0.0290427686319722
# motors ['vkb_q', 'hkb_q'] trans [ 37.39534447 -18.54136492] current loss 0.02303867322056427
# motors ['vkb_q', 'hkb_q'] trans [  7.05766068 -21.66097067] current loss 0.01852076247929014
# motors ['vkb_q', 'hkb_q'] trans [-98.54227164  97.93604111] current loss 0.019350315868117546
# motors ['vkb_q', 'hkb_q'] trans [-61.17945932 -99.49452711] current loss 0.010185791741281723
# motors ['vkb_q', 'hkb_q'] trans [-74.17907226 -50.76284405] current loss 0.003848349631818662
# motors ['vkb_q', 'hkb_q'] trans [-100.          -35.09406736] current loss 0.012570596096196878
# motors ['vkb_q', 'hkb_q'] trans [-42.37912637  99.51204989] current loss 0.01782583848629702
# motors ['vkb_q', 'hkb_q'] trans [-99.50096412 -99.25522318] current loss 0.014560422310984764
# motors ['vkb_q', 'hkb_q'] trans [-40.90777603 -40.76555247] current loss 0.009093966474145516
# motors ['vkb_q', 'hkb_q'] trans [96.60560103 99.45775885] current loss 0.033301551372742925
# motors ['vkb_q', 'hkb_q'] trans [-42.22131918 -99.62806661] current loss 0.01188135468920379
# motors ['vkb_q', 'hkb_q'] trans [ 47.25014291 -99.94342605] current loss 0.025355739655499168
# motors ['vkb_q', 'hkb_q'] trans [30.38210557 99.89371666] current loss 0.026640920875808455
# motors ['vkb_q', 'hkb_q'] trans [-99.93162902   8.49214643] current loss 0.015607809548362807
# motors ['vkb_q', 'hkb_q'] trans [-36.53883754   7.05310671] current loss 0.013714448241776192
# motors ['vkb_q', 'hkb_q'] trans [ 99.10430651 -98.88835009] current loss 0.030675757099850515
# motors ['vkb_q', 'hkb_q'] trans [-65.9566365  -52.26743794] current loss 0.0035924789099508543
# motors ['vkb_q', 'hkb_q'] trans [-46.44556509  57.31318746] current loss 0.015926266986289097
# motors ['vkb_q', 'hkb_q'] trans [-69.72097554 -63.80657119] current loss 0.0015141212024819921
# motors ['vkb_q', 'hkb_q'] trans [-99.50989054  53.95229937] current loss 0.0181221476126694
# motors ['vkb_q', 'hkb_q'] trans [-68.00140354 -60.10532122] current loss 0.00215150813027679
# motors ['vkb_q', 'hkb_q'] trans [32.52159206 27.33239529] current loss 0.024467863417824424
# motors ['vkb_q', 'hkb_q'] trans [-37.88500166 -70.58418461] current loss 0.008104073081080116
# motors ['vkb_q', 'hkb_q'] trans [ 29.19922773 -61.32442154] current loss 0.020438140099915802
# motors ['vkb_q', 'hkb_q'] trans [-9.6447886  99.97195522] current loss 0.02153568144696898
# motors ['vkb_q', 'hkb_q'] trans [61.50285978 67.21212223] current loss 0.028956110984798143
# motors ['vkb_q', 'hkb_q'] trans [-67.91483993 -66.37760541] current loss 0.0013202665195539685
# motors ['vkb_q', 'hkb_q'] trans [-69.51726014 -69.62204869] current loss 0.0012826947949566973
# motors ['vkb_q', 'hkb_q'] trans [-71.02970626 -69.26208175] current loss 0.0012854637335836725
# Loss is 0.0012826947949566973 and min acceptable value is 0.005
# Solution is acceptable.
#  40%|████      | 4/10 [10:13<14:25, 144.33s/it]
# Test 3 success True with final x [-69.5172601433464, -69.62204868771609] and final value 0.0012826947949566973
# Initial motor positions are [231.97029552 130.97029552]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.003835380833961323
# Initial loss is 0.003835380833961323
# motors ['vkb_q', 'hkb_q'] trans [ 70.88526143 -75.1969699 ] current loss 0.03825796178242242
# motors ['vkb_q', 'hkb_q'] trans [-81.37809919  48.09504413] current loss 0.033189786699881665
# motors ['vkb_q', 'hkb_q'] trans [ 56.52900142 -30.90697534] current loss 0.016483675425891263
# motors ['vkb_q', 'hkb_q'] trans [ 51.02777609 -88.18333975] current loss 0.055306925432236746
# motors ['vkb_q', 'hkb_q'] trans [ 13.00841865 -67.12998454] current loss 0.026716905405995868
# motors ['vkb_q', 'hkb_q'] trans [-89.34298902  34.24785203] current loss 0.03843712887018016
# motors ['vkb_q', 'hkb_q'] trans [-50.43354832 -39.01831462] current loss 0.016983970847885235
# motors ['vkb_q', 'hkb_q'] trans [ 92.96977655 -83.49357947] current loss 0.04957879472343674
# motors ['vkb_q', 'hkb_q'] trans [-14.61117161  40.26060062] current loss 0.008486306982608122
# motors ['vkb_q', 'hkb_q'] trans [-37.15038377  47.56439183] current loss 0.01272439325196299
# motors ['vkb_q', 'hkb_q'] trans [43.95832069 58.35719673] current loss 0.016748059020024533
# motors ['vkb_q', 'hkb_q'] trans [62.7781167 17.4701822] current loss 0.01742158774157188
# motors ['vkb_q', 'hkb_q'] trans [-7.8496775  -8.29691006] current loss 0.0014514991929438393
# motors ['vkb_q', 'hkb_q'] trans [ -9.44281308 100.        ] current loss 0.013767342683735646
# motors ['vkb_q', 'hkb_q'] trans [9.03569635 3.06957827] current loss 0.005964652916404977
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.026204985162037675
# motors ['vkb_q', 'hkb_q'] trans [-100. -100.] current loss 0.09671836318672626
# motors ['vkb_q', 'hkb_q'] trans [ -4.10611079 -26.83120977] current loss 0.004952911109440712
# motors ['vkb_q', 'hkb_q'] trans [-20.365894    -5.30558253] current loss 0.00312207562211057
# motors ['vkb_q', 'hkb_q'] trans [-100.  100.] current loss 0.048378139676056295
# motors ['vkb_q', 'hkb_q'] trans [-14.74418039 -10.04764435] current loss 0.0017144445793244897
# motors ['vkb_q', 'hkb_q'] trans [-15.04381909 -12.16667812] current loss 0.0016962605307890277
# motors ['vkb_q', 'hkb_q'] trans [ -0.10592499 -13.02440407] current loss 0.0032899601889352574
# motors ['vkb_q', 'hkb_q'] trans [-16.822613   -13.39056192] current loss 0.0020821624234019028
# motors ['vkb_q', 'hkb_q'] trans [100.         -12.88999723] current loss 0.022333211518219508
# motors ['vkb_q', 'hkb_q'] trans [99.61613361 53.90457339] current loss 0.024490540063756176
# motors ['vkb_q', 'hkb_q'] trans [38.21732682 99.73490936] current loss 0.018168974743685867
# motors ['vkb_q', 'hkb_q'] trans [-15.00577345 -11.49329057] current loss 0.0017017611082527323
# Loss is 0.0014514991929438393 and min acceptable value is 0.005
# Solution is acceptable.
#  50%|█████     | 5/10 [11:59<10:51, 130.23s/it]
# Test 4 success True with final x [-7.849677504166181, -8.296910060974412] and final value 0.0014514991929438393
# Initial motor positions are [190.64120857  89.64120857]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.014698737617386411
# Initial loss is 0.014698737617386411
# motors ['vkb_q', 'hkb_q'] trans [-98.05113759 -34.84094342] current loss 0.10212184222193844
# motors ['vkb_q', 'hkb_q'] trans [-22.1003188   81.78164672] current loss 0.022783491124784238
# motors ['vkb_q', 'hkb_q'] trans [ 67.3166244  -23.99299431] current loss 0.026391137626056497
# motors ['vkb_q', 'hkb_q'] trans [ 32.34000368 -27.83770887] current loss 0.027886195874927498
# motors ['vkb_q', 'hkb_q'] trans [-80.80693759  25.00950789] current loss 0.06991361429620663
# motors ['vkb_q', 'hkb_q'] trans [-40.88090104  18.33256001] current loss 0.03236362834257425
# motors ['vkb_q', 'hkb_q'] trans [45.68547439 -7.12550154] current loss 0.013846885589645539
# motors ['vkb_q', 'hkb_q'] trans [-92.3662571   62.69143411] current loss 0.08606328482712149
# motors ['vkb_q', 'hkb_q'] trans [-82.1097867   27.68686626] current loss 0.07116184190732314
# motors ['vkb_q', 'hkb_q'] trans [ 88.94388792 -69.20472305] current loss 0.14224115689759254
# motors ['vkb_q', 'hkb_q'] trans [ 55.89963643 100.        ] current loss 0.012371000655280165
# motors ['vkb_q', 'hkb_q'] trans [   0.57603008 -100.        ] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [100.         -55.58746559] current loss 0.07497028073625765
# motors ['vkb_q', 'hkb_q'] trans [ 93.44816169 -67.90889535] current loss 0.1334844689866129
# motors ['vkb_q', 'hkb_q'] trans [100.          46.57121203] current loss 0.016353187463590522
# motors ['vkb_q', 'hkb_q'] trans [ 97.21031591 -66.11210936] current loss 0.12165570087081756
# motors ['vkb_q', 'hkb_q'] trans [ 93.1524824  -67.71820349] current loss 0.1315506326034835
# motors ['vkb_q', 'hkb_q'] trans [ 93.11863194 -67.72641993] current loss 0.13163255491076858
# Loss is 0.012371000655280165 and min acceptable value is 0.005
# Solution is not acceptable.
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.014698737617386411
# Initial loss is 0.014698737617386411
# motors ['vkb_q', 'hkb_q'] trans [ 66.04855342 -71.636936  ] current loss 0.16291592258936988
# motors ['vkb_q', 'hkb_q'] trans [-92.02130536 -61.48744375] current loss 0.12746938730377355
# motors ['vkb_q', 'hkb_q'] trans [ 14.96037304 -90.03070197] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [-76.23419098  57.77366641] current loss 0.06429913830607817
# motors ['vkb_q', 'hkb_q'] trans [-0.65759718 67.46611055] current loss 0.012659012694896608
# motors ['vkb_q', 'hkb_q'] trans [-24.6160193   44.54242927] current loss 0.022270623246826077
# motors ['vkb_q', 'hkb_q'] trans [20.80599299 -4.5664845 ] current loss 0.012340675936595314
# motors ['vkb_q', 'hkb_q'] trans [-52.6290109  -26.38176159] current loss 0.04927648698507461
# motors ['vkb_q', 'hkb_q'] trans [  9.84655477 -58.55483059] current loss 0.08460801149179838
# motors ['vkb_q', 'hkb_q'] trans [-49.94305216  59.11298763] current loss 0.038644441573181004
# motors ['vkb_q', 'hkb_q'] trans [ 63.02258734 -71.24725328] current loss 0.16015831139947004
# motors ['vkb_q', 'hkb_q'] trans [ 57.93014349 -70.66196574] current loss 0.15467913388957305
# motors ['vkb_q', 'hkb_q'] trans [ 62.36326482 -71.13773592] current loss 0.16189429468730643
# motors ['vkb_q', 'hkb_q'] trans [ 62.34518679 -71.13870197] current loss 0.16190939977464197
# Loss is 0.012340675936595314 and min acceptable value is 0.005
# Solution is not acceptable.
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.014698737617386411
# Initial loss is 0.014698737617386411
# motors ['vkb_q', 'hkb_q'] trans [-17.49717028  13.5458194 ] current loss 0.019310195089077466
# motors ['vkb_q', 'hkb_q'] trans [37.73361753 40.40183844] current loss 0.0028225601983541612
# motors ['vkb_q', 'hkb_q'] trans [-82.32881437 -81.22608873] current loss 0.0713721904963579
# motors ['vkb_q', 'hkb_q'] trans [-94.75029394 -23.12229218] current loss 0.09278218631952866
# motors ['vkb_q', 'hkb_q'] trans [ 7.20993045 99.10101964] current loss 0.012987591148385826
# motors ['vkb_q', 'hkb_q'] trans [-53.0796326 -69.5324784] current loss 0.15136178295336802
# motors ['vkb_q', 'hkb_q'] trans [-92.94463122  -6.5981018 ] current loss 0.08754694215951135
# motors ['vkb_q', 'hkb_q'] trans [-68.09472391 -36.57215185] current loss 0.0662101702353797
# motors ['vkb_q', 'hkb_q'] trans [-14.23788468  84.75539292] current loss 0.018954498729935584
# motors ['vkb_q', 'hkb_q'] trans [ 4.06675971 89.32683728] current loss 0.012874078849227444
# motors ['vkb_q', 'hkb_q'] trans [ 28.75837119 -35.87878866] current loss 0.0361726334349178
# motors ['vkb_q', 'hkb_q'] trans [44.07916204 83.15231057] current loss 0.00923662223093518
# motors ['vkb_q', 'hkb_q'] trans [ 99.94043984 -95.71370849] current loss 10000.0
# motors ['vkb_q', 'hkb_q'] trans [41.30597769 68.2967243 ] current loss 0.007400630136346018
# motors ['vkb_q', 'hkb_q'] trans [41.31876962 68.42153233] current loss 0.0074067268195580575
# motors ['vkb_q', 'hkb_q'] trans [41.34615569 68.6592641 ] current loss 0.0074185514529005025
# motors ['vkb_q', 'hkb_q'] trans [41.37406692 68.71744172] current loss 0.007421475005262593
# Loss is 0.0028225601983541612 and min acceptable value is 0.005
# Solution is acceptable.
#  60%|██████    | 6/10 [14:59<09:48, 147.15s/it]
# Test 5 success True with final x [37.73361753139085, 40.40183843697832] and final value 0.0028225601983541612
# Initial motor positions are [242.46318061 141.46318061]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.006873356493461455
# Initial loss is 0.006873356493461455
# motors ['vkb_q', 'hkb_q'] trans [-11.58156871 -64.13665146] current loss 0.016332879120218243
# motors ['vkb_q', 'hkb_q'] trans [ -7.07800765 -86.48135255] current loss 0.03520809032913798
# motors ['vkb_q', 'hkb_q'] trans [74.07448749 -2.81658225] current loss 0.02047082767147087
# motors ['vkb_q', 'hkb_q'] trans [-68.65775603 -21.58392056] current loss 0.018614450328195514
# motors ['vkb_q', 'hkb_q'] trans [ 55.75105368 -50.56876861] current loss 0.019692441300201945
# motors ['vkb_q', 'hkb_q'] trans [51.88343761 33.77879574] current loss 0.018612574763850014
# motors ['vkb_q', 'hkb_q'] trans [ 93.29131462 -64.44626959] current loss 0.027880417833422003
# motors ['vkb_q', 'hkb_q'] trans [-63.62312871 -93.80108408] current loss 0.0471055198713356
# motors ['vkb_q', 'hkb_q'] trans [-14.37122395 -85.27663052] current loss 0.03348302529509484
# motors ['vkb_q', 'hkb_q'] trans [53.02253788 35.83797891] current loss 0.01915499680878151
# motors ['vkb_q', 'hkb_q'] trans [-100.          -49.12574121] current loss 0.03849147017460606
# motors ['vkb_q', 'hkb_q'] trans [ -3.84428258 -14.12716228] current loss 0.005049237528513838
# motors ['vkb_q', 'hkb_q'] trans [-87.54634511 100.        ] current loss 0.03228015864086168
# motors ['vkb_q', 'hkb_q'] trans [-30.74621463  31.63752965] current loss 0.00896268353212165
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.027704989003661338
# motors ['vkb_q', 'hkb_q'] trans [-17.52110891   6.23235095] current loss 0.005430750577281119
# motors ['vkb_q', 'hkb_q'] trans [-19.24739068 -27.3198877 ] current loss 0.0017453530461986103
# motors ['vkb_q', 'hkb_q'] trans [  3.66957952 100.        ] current loss 0.01602475489686988
# motors ['vkb_q', 'hkb_q'] trans [-100.           33.51408538] current loss 0.03855431860492131
# motors ['vkb_q', 'hkb_q'] trans [ 4.12726806 53.0435813 ] current loss 0.012886182262569441
# motors ['vkb_q', 'hkb_q'] trans [-28.52997637 -19.49074942] current loss 0.002278280549101756
# motors ['vkb_q', 'hkb_q'] trans [-26.87550424 -31.25335436] current loss 0.003155613068245892
# motors ['vkb_q', 'hkb_q'] trans [99.82429114 42.60734956] current loss 0.025640620933484452
# motors ['vkb_q', 'hkb_q'] trans [-39.41942249  99.41054416] current loss 0.015344269562451244
# motors ['vkb_q', 'hkb_q'] trans [ 99.05951994 -98.60532181] current loss 0.0574202722650729
# motors ['vkb_q', 'hkb_q'] trans [52.30564662 99.71984523] current loss 0.02177342994247857
# motors ['vkb_q', 'hkb_q'] trans [-48.83312777  68.1223039 ] current loss 0.015223514758886983
# motors ['vkb_q', 'hkb_q'] trans [ 99.84680072 -19.59453474] current loss 0.023578238232610616
# motors ['vkb_q', 'hkb_q'] trans [-98.13602403 -99.75287173] current loss 0.0652253918532845
# motors ['vkb_q', 'hkb_q'] trans [-21.23783522 -21.2026792 ] current loss 0.0012916283177496816
# motors ['vkb_q', 'hkb_q'] trans [69.97905707 71.6008237 ] current loss 0.02310152168074226
# motors ['vkb_q', 'hkb_q'] trans [ 15.91293173 -36.42877815] current loss 0.010099434862705956
# motors ['vkb_q', 'hkb_q'] trans [-54.18434556  12.28065346] current loss 0.01313228385189527
# motors ['vkb_q', 'hkb_q'] trans [-21.25209364 -20.81819389] current loss 0.001295925963054453
# motors ['vkb_q', 'hkb_q'] trans [-20.87235239 -20.4211051 ] current loss 0.001300653082531791
# Loss is 0.0012916283177496816 and min acceptable value is 0.005
# Solution is acceptable.
#  70%|███████   | 7/10 [17:12<07:07, 142.53s/it]
# Test 6 success True with final x [-21.237835218782564, -21.20267919514626] and final value 0.0012916283177496816
# Initial motor positions are [241.66746274 140.66746274]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.00668170194277756
# Initial loss is 0.00668170194277756
# motors ['vkb_q', 'hkb_q'] trans [-30.42244512 -79.96344005] current loss 0.028884760755634974
# motors ['vkb_q', 'hkb_q'] trans [ 65.76173196 -84.19026691] current loss 0.03790778701134154
# motors ['vkb_q', 'hkb_q'] trans [-3.28325338 18.60232885] current loss 0.008117182137046864
# motors ['vkb_q', 'hkb_q'] trans [ 86.35073116 -19.6480611 ] current loss 0.022060295363957396
# motors ['vkb_q', 'hkb_q'] trans [73.915692   48.22809383] current loss 0.022606943558732568
# motors ['vkb_q', 'hkb_q'] trans [-16.48402838  81.60064475] current loss 0.01306411288003642
# motors ['vkb_q', 'hkb_q'] trans [ 21.04954775 -35.40600794] current loss 0.011176181306165855
# motors ['vkb_q', 'hkb_q'] trans [-79.63285327  -2.57750808] current loss 0.025036305020982426
# motors ['vkb_q', 'hkb_q'] trans [12.65783252 26.63781777] current loss 0.011581266353803845
# motors ['vkb_q', 'hkb_q'] trans [ 8.50051427 99.237682  ] current loss 0.016073426237228534
# motors ['vkb_q', 'hkb_q'] trans [   5.42818349 -100.        ] current loss 0.05762253210864492
# motors ['vkb_q', 'hkb_q'] trans [-100.          -55.04035435] current loss 0.040142536897376305
# motors ['vkb_q', 'hkb_q'] trans [ 1.84547574 -9.73585182] current loss 0.006293132036266227
# motors ['vkb_q', 'hkb_q'] trans [-89.12475232 100.        ] current loss 0.033607373278853055
# motors ['vkb_q', 'hkb_q'] trans [-24.67503788 -24.33247602] current loss 0.0017720344842758018
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.02741675267011885
# motors ['vkb_q', 'hkb_q'] trans [-31.7864442   -2.27236562] current loss 0.004894792390400814
# motors ['vkb_q', 'hkb_q'] trans [-13.55963827 -31.45788241] current loss 0.00347321845874491
# motors ['vkb_q', 'hkb_q'] trans [-53.75011429  48.58476775] current loss 0.015845487686376995
# motors ['vkb_q', 'hkb_q'] trans [-34.43298343 -31.76053046] current loss 0.005125755341346009
# motors ['vkb_q', 'hkb_q'] trans [ 99.70476916 -96.3017077 ] current loss 0.05550957380742163
# motors ['vkb_q', 'hkb_q'] trans [53.37139219 99.65311915] current loss 0.02195128283079721
# motors ['vkb_q', 'hkb_q'] trans [-19.79454636 -18.02650721] current loss 0.0011864429935031276
# motors ['vkb_q', 'hkb_q'] trans [-41.3344516   99.98152204] current loss 0.015668772522599565
# motors ['vkb_q', 'hkb_q'] trans [49.39331793 -4.61044113] current loss 0.016382917163651544
# motors ['vkb_q', 'hkb_q'] trans [-99.21531506 -99.28187336] current loss 0.06753230771182842
# motors ['vkb_q', 'hkb_q'] trans [99.61529347 27.11486975] current loss 0.024889545225307765
# motors ['vkb_q', 'hkb_q'] trans [-99.96288781  52.5973502 ] current loss 0.039924822500523656
# motors ['vkb_q', 'hkb_q'] trans [ 99.94491961 -55.17596541] current loss 0.02630627970811818
# motors ['vkb_q', 'hkb_q'] trans [21.09178906 62.59144348] current loss 0.015422719462220735
# motors ['vkb_q', 'hkb_q'] trans [-55.06098066 -43.8845555 ] current loss 0.014007166374980356
# motors ['vkb_q', 'hkb_q'] trans [99.82015409 70.87023945] current loss 0.026460846061945396
# motors ['vkb_q', 'hkb_q'] trans [ -4.66827602 -54.68901782] current loss 0.012321174750868996
# motors ['vkb_q', 'hkb_q'] trans [-20.72480263  41.00737989] current loss 0.009313544222046406
# motors ['vkb_q', 'hkb_q'] trans [ 58.06271796 -44.6155034 ] current loss 0.018887896696448046
# motors ['vkb_q', 'hkb_q'] trans [-41.40189103  16.67581909] current loss 0.009511563369940069
# motors ['vkb_q', 'hkb_q'] trans [-20.06410028 -19.06971213] current loss 0.001306848184445101
# motors ['vkb_q', 'hkb_q'] trans [-59.16640348  77.95818514] current loss 0.01885380892374393
# motors ['vkb_q', 'hkb_q'] trans [-20.03127944 -18.85001321] current loss 0.00117953708505793
# motors ['vkb_q', 'hkb_q'] trans [-99.20463452 -25.50990708] current loss 0.0375304655836941
# motors ['vkb_q', 'hkb_q'] trans [61.95350978 20.36913688] current loss 0.01947143242208837
# motors ['vkb_q', 'hkb_q'] trans [-22.22655862 -18.46948163] current loss 0.001311833635450677
# Loss is 0.00117953708505793 and min acceptable value is 0.005
# Solution is acceptable.
#  80%|████████  | 8/10 [19:54<04:57, 148.97s/it]
# Test 7 success True with final x [-20.03127943565255, -18.850013207063583] and final value 0.00117953708505793
# Initial motor positions are [245.50206458 144.50206458]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.007951668611414246
# Initial loss is 0.007951668611414246
# motors ['vkb_q', 'hkb_q'] trans [-18.16788104  69.69539525] current loss 0.012384165331337793
# motors ['vkb_q', 'hkb_q'] trans [ 4.35186978 36.99106949] current loss 0.011851931398200947
# motors ['vkb_q', 'hkb_q'] trans [54.68086974 67.68259417] current loss 0.021291132567056267
# motors ['vkb_q', 'hkb_q'] trans [-42.82574531 -41.06933921] current loss 0.007553314873115905
# motors ['vkb_q', 'hkb_q'] trans [73.7388054  33.11743018] current loss 0.022288762350239737
# motors ['vkb_q', 'hkb_q'] trans [-14.10138477  -3.87108986] current loss 0.004729058606318065
# motors ['vkb_q', 'hkb_q'] trans [-96.55479476  59.44936755] current loss 0.035071770264747865
# motors ['vkb_q', 'hkb_q'] trans [-40.4791844    0.07051418] current loss 0.0070481533139010915
# motors ['vkb_q', 'hkb_q'] trans [19.64388372 69.56890837] current loss 0.016387619935862692
# motors ['vkb_q', 'hkb_q'] trans [-22.28238736   1.32981172] current loss 0.004988154687686262
# motors ['vkb_q', 'hkb_q'] trans [  14.19756945 -100.        ] current loss 0.050860753612417986
# motors ['vkb_q', 'hkb_q'] trans [-100. -100.] current loss 0.06109088749986031
# motors ['vkb_q', 'hkb_q'] trans [100.          -0.54754112] current loss 0.024811369386477253
# motors ['vkb_q', 'hkb_q'] trans [100. 100.] current loss 0.028413298748421762
# motors ['vkb_q', 'hkb_q'] trans [-42.93875599 100.        ] current loss 0.015869129478524896
# motors ['vkb_q', 'hkb_q'] trans [ 99.6688208 -97.1647838] current loss 0.051210242130297304
# motors ['vkb_q', 'hkb_q'] trans [-24.27948814 -23.68882941] current loss 0.0012978390064714092
# motors ['vkb_q', 'hkb_q'] trans [ 28.94314277 -36.5938286 ] current loss 0.013217074203843927
# motors ['vkb_q', 'hkb_q'] trans [-99.15963477 -22.83020809] current loss 0.03482547894590668
# motors ['vkb_q', 'hkb_q'] trans [-99.65980616  99.35477431] current loss 0.03844289734632262
# motors ['vkb_q', 'hkb_q'] trans [18.43809615 99.9157177 ] current loss 0.01811104389464962
# motors ['vkb_q', 'hkb_q'] trans [-16.85778882 -27.96769168] current loss 0.0022593670167150243
# motors ['vkb_q', 'hkb_q'] trans [38.14133972 -1.02961909] current loss 0.015211849232941471
# motors ['vkb_q', 'hkb_q'] trans [ 97.08926847 -50.12214509] current loss 0.024906176949725675
# motors ['vkb_q', 'hkb_q'] trans [99.5984209  56.90983553] current loss 0.026816050718046366
# motors ['vkb_q', 'hkb_q'] trans [-24.94045481 -22.2581593 ] current loss 0.0013132209380154834
# motors ['vkb_q', 'hkb_q'] trans [-28.17387399 -24.34030657] current loss 0.0015598845579925474
# motors ['vkb_q', 'hkb_q'] trans [-47.14198275  44.97599061] current loss 0.012896628524907165
# motors ['vkb_q', 'hkb_q'] trans [-45.2353487  -99.44887041] current loss 0.049207226378122984
# motors ['vkb_q', 'hkb_q'] trans [-24.58004359 -21.10946282] current loss 0.0013283785599164325
# Loss is 0.0012978390064714092 and min acceptable value is 0.005
# Solution is acceptable.
#  90%|█████████ | 9/10 [21:49<02:18, 138.10s/it]
# Test 8 success True with final x [-24.279488141141783, -23.688829409766456] and final value 0.0012978390064714092
# Initial motor positions are [261.07892407 160.07892407]
# motors ['vkb_q', 'hkb_q'] trans [0. 0.] current loss 0.012055735308051171
# Initial loss is 0.012055735308051171
# motors ['vkb_q', 'hkb_q'] trans [ 31.84998487 -74.33717757] current loss 0.019766063166461033
# motors ['vkb_q', 'hkb_q'] trans [-33.9323621  -97.64554134] current loss 0.027381773679481754
# motors ['vkb_q', 'hkb_q'] trans [-18.48785952 -98.06898909] current loss 0.028167096773040898
# motors ['vkb_q', 'hkb_q'] trans [-16.04042538  28.26609093] current loss 0.011994194624233673
# motors ['vkb_q', 'hkb_q'] trans [-37.6326905    0.89303532] current loss 0.006962492228436835
# motors ['vkb_q', 'hkb_q'] trans [-81.81805983  24.76796901] current loss 0.0185613644302893
# motors ['vkb_q', 'hkb_q'] trans [14.07277864 41.24214351] current loss 0.01713735102370328
# motors ['vkb_q', 'hkb_q'] trans [ 89.37485308 -47.44804925] current loss 0.02474207641294732
# motors ['vkb_q', 'hkb_q'] trans [-49.21480381  98.26141083] current loss 0.01537362982400632
# motors ['vkb_q', 'hkb_q'] trans [-51.01821379 -69.87774614] current loss 0.010337922887631858
# motors ['vkb_q', 'hkb_q'] trans [-5.83290417 -2.46451542] current loss 0.010668111523708165
# motors ['vkb_q', 'hkb_q'] trans [72.60692911  4.05623258] current loss 0.023609545865779836
# motors ['vkb_q', 'hkb_q'] trans [-60.34508915  -7.09136068] current loss 0.009015617318511897
# motors ['vkb_q', 'hkb_q'] trans [-79.276034   -47.26462144] current loss 0.014544074597475221
# motors ['vkb_q', 'hkb_q'] trans [ 81.28047057 100.        ] current loss 0.028021801526348512
# motors ['vkb_q', 'hkb_q'] trans [-98.250359    71.52408944] current loss 0.027990356166397074
# motors ['vkb_q', 'hkb_q'] trans [-22.8760387   11.56598217] current loss 0.009518535273914901
# motors ['vkb_q', 'hkb_q'] trans [-21.29497933 -43.1056311 ] current loss 0.005149278990948936
# motors ['vkb_q', 'hkb_q'] trans [ 4.91371627 99.13691514] current loss 0.018781755448728357
# motors ['vkb_q', 'hkb_q'] trans [ 99.29728271 -98.31731984] current loss 0.03807609960110433
# motors ['vkb_q', 'hkb_q'] trans [-99.07643019 -98.48451291] current loss 0.03728054578074552
# motors ['vkb_q', 'hkb_q'] trans [-40.40641674 -36.58980255] current loss 0.0013296459046766161
# motors ['vkb_q', 'hkb_q'] trans [-44.71821421 -40.68050557] current loss 0.0017001734437319161
# motors ['vkb_q', 'hkb_q'] trans [99.47529821 47.43785072] current loss 0.028523658229279405
# motors ['vkb_q', 'hkb_q'] trans [-47.89469658  57.52178435] current loss 0.012601351636542787
# motors ['vkb_q', 'hkb_q'] trans [-41.33070319 -31.96780987] current loss 0.0019310627338910912
# motors ['vkb_q', 'hkb_q'] trans [ 34.81574811 -29.48022107] current loss 0.01705861982628308
# motors ['vkb_q', 'hkb_q'] trans [-40.08740531 -39.73605141] current loss 0.0012923732878414931
# motors ['vkb_q', 'hkb_q'] trans [-99.71455074 -13.61542006] current loss 0.025666515656807075
# motors ['vkb_q', 'hkb_q'] trans [53.68292989 68.64317856] current loss 0.024248974514820925
# motors ['vkb_q', 'hkb_q'] trans [-40.21361637 -39.89598312] current loss 0.0012904858205330257
# Loss is 0.0012904858205330257 and min acceptable value is 0.005
# Solution is acceptable.
# 100%|██████████| 10/10 [23:46<00:00, 142.66s/it]
# Test 9 success True with final x [-40.21361636758651, -39.89598311761081] and final value 0.0012904858205330257
# CPU times: user 27min 49s, sys: 39min 25s, total: 1h 7min 14s
# Wall time: 23min 46s

# %%
initial_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in initial_out_beams]
initial_hists, initial_dws = zip(*initial_hists_dws)

# %%
initial_peaks = [dw.get_parameter('peak_intensity') for dw in initial_dws]
initial_h_fwhms = [dw.get_parameter('h_fwhm') for dw in initial_dws]
initial_v_fwhms = [dw.get_parameter('v_fwhm') for dw in initial_dws]

# %%
final_hists_dws = [get_shadow_beam_spatial_distribution(ob) for ob in final_out_beams]
final_hists, final_dws = zip(*final_hists_dws)

# %%
final_peaks = [dw.get_parameter('peak_intensity') for dw in final_dws]
final_h_fwhms = [dw.get_parameter('h_fwhm') for dw in final_dws]
final_v_fwhms = [dw.get_parameter('v_fwhm') for dw in final_dws]

# %%
fig, axes = plt.subplots(1, 5, figsize=[15,3], constrained_layout=True)

axes[0].plot(absolute_movements)
axes[0].set_ylabel('perturbation')

#axes[1].plot(initial_centroids)
#axes[1].set_ylabel('v_centroid')

axes[2].plot(initial_peaks)
axes[2].set_ylabel('peak_intensity')

axes[3].plot(initial_h_fwhms)
axes[3].set_ylabel('h_fwhm')
axes[3].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[4].plot(initial_v_fwhms)
axes[4].set_ylabel('v_fwhm')
axes[4].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('Initial settings')
fig.savefig(f'{fig_save_path}/initial_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(1, 4, figsize=[12,3], constrained_layout=True)

#axes[0].plot(final_centroids)
#axes[0].set_ylabel('v_centroid')

axes[1].plot(final_peaks)
axes[1].set_ylabel('peak_intensity')

axes[2].plot(final_h_fwhms)
axes[2].set_ylabel('h_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))


axes[3].plot(final_v_fwhms)
axes[3].set_ylabel('v_fwhm')
axes[2].ticklabel_format(style='sci', scilimits=(-3, -5))

fig.suptitle('final settings')
fig.savefig(f'{fig_save_path}/final_metrics.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(initial_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Initial beams')
fig.savefig(f'{fig_save_path}/initial_beams.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 5, figsize=[15,6], constrained_layout=True)

axes_flat = axes.flatten()
for ix, h in enumerate(final_hists):
    axes_flat[ix].pcolormesh(h.hh, h.vv, h.data_2D)
    
    
fig.suptitle('Final beams')
fig.savefig(f'{fig_save_path}/final_beams.png', bbox_inches='tight')

# %%
_ = plot_shadow_beam_spatial_distribution(final_out_beams[0])

# %%
(0.04**2 + 0.06**2)**0.5
# Out:
# 0.07211102550927978

# %%
clean_up()

# %%
shutil.rmtree(temp_work_dir)
